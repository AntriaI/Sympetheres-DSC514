# %% [markdown]
# # Detection of Movie Spoilers in Reviews

# %% [markdown]
# ### ***Import essential libraries***

# %%
import pandas as pd
import numpy as np
import re, string, nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import itertools
import spacy
from collections import Counter
from nltk.stem import WordNetLemmatizer


nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ### Understanding the data

# %% [markdown]
# Apories:
# 1. what is rating_x, rating_y IMDB???
# 2. maybe convert duration to minutes would be better to compare

# %%
# Load the dataset
original_data = pd.read_csv('movie_spoiler_sample.csv')

# %%
# First view of the dataset
original_data.head(5)
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0318649  Master explorer and former US Navy Seal Dirk P...   2h 4min
# 1  tt0803096  When the world of the Orcs of Draenor is being...   2h 3min
# 2  tt0425112  Top London cop, PC Nicholas Angel is good. Too...   2h 1min
# 3  tt0327056  In the summer of 1975 in a neighborhood in Bos...  2h 18min
# 4  tt0259711  Incarcerated and charged with murder, David Aa...  2h 16min
#
#                                 genre  rating_x release_date  \
# 0   ['Action', 'Adventure', 'Comedy']       6.0   2005-04-08
# 1  ['Action', 'Adventure', 'Fantasy']       6.9   2016-06-10
# 2                ['Action', 'Comedy']       7.9   2007-04-20
# 3       ['Crime', 'Drama', 'Mystery']       8.0   2003-10-15
# 4   ['Fantasy', 'Mystery', 'Romance']       6.9   2001-12-14
#
#                                        plot_synopsis      review_date  \
# 0  The film begins with a prologue set in Richmon...      27 May 2005
# 1  For ages in the region of Middle Earth, humans...     20 June 2016
# 2  Nicholas Angel (Simon Pegg) is undoubtedly Lon...     11 June 2007
# 3  Three young boys, all the best of friends, are...  5 November 2015
# 4  David Aames (Tom Cruise) drives to work, he fi...   12 August 2016
#
#       user_id  is_spoiler                                        review_text  \
# 0   ur3270789       False  The film starts in the Richmond battle (1865) ...
# 1  ur47788388        True  I saw the movie with six friends and we all lo...
# 2  ur14440242        True  I enjoyed this movie very much, but it being l...
# 3  ur63623011       False  What you get here is no more than Clint eastwo...
# 4   ur2781970       False  I think the first time I saw this movie, I did...
#
#    rating_y                                     review_summary
# 0         7  Splendid adventure film with mesmerizing deser...
# 1        10                   Epic movie for fans and non fans
# 2         8                    once again a funny British film
# 3         1               For he made a 'plot twist' out of it
# 4        10                     As brilliant as I recalled it!

# %% [markdown]
# The dataset is very large and run time error occurs therefore we decided to use undersampling to obtain a balanced sample of the data.

# %%
# Check the count per movie id
original_data['movie_id'].value_counts()
# Out:
# movie_id
# tt0468569    643
# tt0111161    565
# tt0167260    328
# tt0137523    272
# tt0110912    265
#             ...
# tt0383534      3
# tt0110989      2
# tt5580036      2
# tt0107719      1
# tt0374887      1
# Name: count, Length: 1339, dtype: int64

# %%
# Check how many unique movies we have
len(original_data['movie_id'].value_counts())
# Out:
# 1339

# %% [markdown]
# For the above reason we decided to take a sample of at most 4 reviews per movie (or less if they don't have enough reviews).

# %%
# Sample each movie's reviews based on the given criteria
sampled_data = original_data.groupby('movie_id', group_keys=False, as_index=False).apply(
    lambda movie_df: movie_df if len(movie_df) <= 4 else pd.concat([
        movie_df[movie_df['is_spoiler'] == True].sample(n=min(2, len(movie_df[movie_df['is_spoiler'] == True])), random_state=42),
        movie_df[movie_df['is_spoiler'] == False].sample(n=min(2, len(movie_df[movie_df['is_spoiler'] == False])), random_state=42)
    ])
).reset_index(drop=True)

sampled_data.head()
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 1  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 2  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 3  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 4  tt0017136  Sometime in the future, the city of Metropolis...  2h 33min
#
#                               genre  rating_x release_date  \
# 0  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 1  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 2  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 3  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 4               ['Drama', 'Sci-Fi']       8.3   1927-03-13
#
#                                        plot_synopsis      review_date  \
# 0  It is in the middle of the Gold Rush. A Lone P...  1 February 2006
# 1  It is in the middle of the Gold Rush. A Lone P...   11 August 2005
# 2  It is in the middle of the Gold Rush. A Lone P...     22 June 2000
# 3  It is in the middle of the Gold Rush. A Lone P...     9 March 2009
# 4  The film is set in the year 2026, in the extra...     7 March 2015
#
#       user_id  is_spoiler                                        review_text  \
# 0   ur5945598        True  Oh where can I start on why alleged comedians ...
# 1   ur5805910        True  We follow "the little fellow" (Chaplin), in hi...
# 2   ur0773000       False  I recently saw this movie with a live orchestr...
# 3   ur0361658       False  The Gold Rush (1925) was a big undertaking for...
# 4  ur13977076        True  This sci-fi classic is set in a future where t...
#
#    rating_y                                     review_summary
# 0        10                        Chaplin strikes comic gold!
# 1        10          Chaplin's delightful bonhomie & innocence
# 2         9  As fresh, funny, and moving as the day it was ...
# 3        10       The Cinema of Charles Chaplin: The Gold Rush
# 4        10                          A science fiction classic

# %%
# Number of records and features for the dataset
sampled_data.shape
# Out:
# (5335, 13)

# %%
# Check if the sample is balanced
sampled_data['is_spoiler'].value_counts()
# Out:
# is_spoiler
# False    2677
# True     2658
# Name: count, dtype: int64

# %% [markdown]
# The target variable is balanced.

# %%
sampled_data['whole_review'] = sampled_data['review_text'] + sampled_data['review_summary']

# %%
# View the columns of the dataset
sampled_data.columns
# Out:
# Index(['movie_id', 'plot_summary', 'duration', 'genre', 'rating_x',
#        'release_date', 'plot_synopsis', 'review_date', 'user_id', 'is_spoiler',
#        'review_text', 'rating_y', 'review_summary', 'whole_review'],
#       dtype='object')

# %%
sampled_data['whole_plot'] = sampled_data['plot_synopsis'] + sampled_data['plot_summary']

# %% [markdown]
# The target variable is balanced.

# %%
# Check for duplicated records
sampled_data.duplicated().any()
# Out:
# False

# %% [markdown]
# There are no duplicated records.

# %%
# Check the data types
sampled_data.dtypes
# Out:
# movie_id           object
# plot_summary       object
# duration           object
# genre              object
# rating_x          float64
# release_date       object
# plot_synopsis      object
# review_date        object
# user_id            object
# is_spoiler           bool
# review_text        object
# rating_y            int64
# review_summary     object
# whole_review       object
# whole_plot         object
# dtype: object

# %%
# Save the sampled data as a csv
sampled_data.to_csv("sampled_data.csv", index=False)

# %% [markdown]
# ### Named entity Recognition on the plot synopsis and review to find the main characters

# %%
#This must be run every time before NER, we may put this in the beginning of the notebook
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.8 MB 3.9 MB/s eta 0:00:04
#      ------ --------------------------------- 2.1/12.8 MB 4.1 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 4.4 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.8 MB 4.7 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.2/12.8 MB 4.6 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.8 MB 4.6 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.1/12.8 MB 4.6 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 4.6 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.8 MB 4.7 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 4.7 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 4.6 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 4.5 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from collections import Counter

# Load spaCy model
nlp = spacy.load("en_core_web_sm")  

# Group reviews by movie_id
grouped_reviews = sampled_data.groupby("movie_id")["whole_plot"].apply(lambda x: " ".join(x))

# Dictionaries to store PERSON and ORGANIZATION entity counts per movie
person_entities_by_movie = {}
organization_entities_by_movie = {}

# Process each movie's reviews separately
for movie_id, text in grouped_reviews.items():
    doc = nlp(text)  # Apply spaCy NER directly without tokenization
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]  
    organization_entities = [ent.text for ent in doc.ents if ent.label_ == "ORG"]

    # Count occurrences
    person_counts = Counter(person_entities)
    organization_counts = Counter(organization_entities)

    # Store results
    person_entities_by_movie[movie_id] = person_counts
    organization_entities_by_movie[movie_id] = organization_counts

# Print the most common PERSON entities per movie
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"Movie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):  # Top 5 most common PERSON names
        print(f"{entity}: {count} times")
    print("\n" + "="*40 + "\n")  # Separator for readability

# Print the most common ORGANIZATION entities per movie
for movie_id, organization_counts in organization_entities_by_movie.items():
    print(f"Movie ID: {movie_id} - Most Common ORGANIZATION Entities:")
    for entity, count in organization_counts.most_common(5):  # Top 5 most common ORGANIZATION names
        print(f"{entity}: {count} times")
    print("\n" + "="*40 + "\n")  # Separator for readability
# Out:
# Movie ID: tt0015864 - Most Common PERSON Entities:
# Jack: 40 times
# Jim: 32 times
# Larsen: 16 times
# Black Larsen: 8 times
# Charlie Chaplin: 4 times
#
# ========================================
#
# Movie ID: tt0017136 - Most Common PERSON Entities:
# Maria: 48 times
# Rotwang: 36 times
# Metropolis: 16 times
# Fredersen: 16 times
# Freder: 12 times
#
# ========================================
#
# Movie ID: tt0017925 - Most Common PERSON Entities:
# Johnnie: 256 times
# Anderson: 24 times
# Johnnie Gray: 4 times
# Buster Keaton: 4 times
# Frank Barnes: 4 times
#
# ========================================
#
# Movie ID: tt0018455 - Most Common PERSON Entities:
# Margaret Livingston: 4 times
# George O'Brien: 4 times
# Janet Gaynor: 4 times
# Indre: 4 times
#
# ========================================
#
# Movie ID: tt0019254 - Most Common PERSON Entities:
# Joan: 20 times
# Jeanne D'Arc: 4 times
# Jeanne: 4 times
#
# ========================================
#
# Movie ID: tt0021749 - Most Common PERSON Entities:
# Millionaire: 16 times
# Grandmother: 12 times
# Girl: 4 times
# Virginia Cherrill: 4 times
# Harry Myers: 4 times
#
# ========================================
#
# Movie ID: tt0022100 - Most Common PERSON Entities:
# Beckert: 60 times
# Hans Beckert: 8 times
# Ariston: 8 times
# Schränker: 8 times
# Morder: 4 times
#
# ========================================
#
# Movie ID: tt0025316 - Most Common PERSON Entities:
# Andrews: 44 times
# Warne: 44 times
# King Westley: 8 times
# Peter Warne: 8 times
# Ellie Andrews: 4 times
#
# ========================================
#
# Movie ID: tt0031381 - Most Common PERSON Entities:
# Scarlett: 504 times
# Rhett: 260 times
# Ashley: 176 times
# Melanie: 172 times
# Tara: 60 times
#
# ========================================
#
# Movie ID: tt0031679 - Most Common PERSON Entities:
# Smith: 56 times
# Taylor: 32 times
# Paine: 28 times
# Jim Taylor: 8 times
# Jefferson Smith: 8 times
#
# ========================================
#
# Movie ID: tt0032138 - Most Common PERSON Entities:
# Dorothy: 152 times
# Toto: 40 times
# Miss Gulch: 16 times
# Marvel: 12 times
# Uncle Henry: 8 times
#
# ========================================
#
# Movie ID: tt0032551 - Most Common PERSON Entities:
# Tom: 40 times
# Casy: 12 times
# Tom Joad: 8 times
# Grandpa: 4 times
# Grandma: 4 times
#
# ========================================
#
# Movie ID: tt0032553 - Most Common PERSON Entities:
# Hannah: 56 times
# Barber: 52 times
# Schultz: 32 times
# Hynkel: 20 times
# Jaeckel: 8 times
#
# ========================================
#
# Movie ID: tt0032976 - Most Common PERSON Entities:
# Maxim: 32 times
# Danvers: 24 times
# Manderley: 20 times
# Monte Carlo: 8 times
# Jack Favell: 8 times
#
# ========================================
#
# Movie ID: tt0033467 - Most Common PERSON Entities:
# Kane: 168 times
# Thatcher: 56 times
# Susan: 44 times
# Raymond: 16 times
# Charles Foster Kane: 8 times
#
# ========================================
#
# Movie ID: tt0033870 - Most Common PERSON Entities:
# Gutman: 60 times
# Brigid O'Shaughnessy: 52 times
# Thursby: 48 times
# Archer: 40 times
# Spade: 32 times
#
# ========================================
#
# Movie ID: tt0034583 - Most Common PERSON Entities:
# Rick: 132 times
# Ilsa: 28 times
# Sam: 24 times
# Strasser: 20 times
# Laszlo: 20 times
#
# ========================================
#
# Movie ID: tt0036775 - Most Common PERSON Entities:
# Phyllis: 48 times
# Neff: 36 times
# Lola: 32 times
# Keyes: 12 times
# Walter Neff: 8 times
#
# ========================================
#
# Movie ID: tt0036868 - Most Common PERSON Entities:
# Fred: 48 times
# Marie: 32 times
# Peggy: 32 times
# Al: 20 times
# Fred Derry: 8 times
#
# ========================================
#
# Movie ID: tt0038650 - Most Common PERSON Entities:
# George: 292 times
# Harry: 48 times
# Potter: 48 times
# Bedford Falls: 32 times
# Gower: 28 times
#
# ========================================
#
# Movie ID: tt0040522 - Most Common PERSON Entities:
# Antonio: 44 times
# Antonio Ricci: 4 times
# Maria: 4 times
# Antonio walks: 4 times
# Bruno: 4 times
#
# ========================================
#
# Movie ID: tt0040897 - Most Common PERSON Entities:
# Gold Hat: 20 times
# Howard: 16 times
# Bob Curtin: 8 times
# Cody: 8 times
# Humphrey Bogart: 4 times
#
# ========================================
#
# Movie ID: tt0041959 - Most Common PERSON Entities:
# Harry: 444 times
# Holly: 292 times
# Anna: 176 times
# Kurtz: 96 times
# Paine: 28 times
#
# ========================================
#
# Movie ID: tt0042192 - Most Common PERSON Entities:
# Eve: 104 times
# Karen: 68 times
# Bill: 32 times
# Lloyd: 16 times
# Eve Harrington: 8 times
#
# ========================================
#
# Movie ID: tt0042876 - Most Common PERSON Entities:
# bush: 8 times
# Rashômon: 8 times
# Takashi Shimura: 4 times
# Minoru Chiaki: 4 times
# Daisuke Kato: 4 times
#
# ========================================
#
# Movie ID: tt0043014 - Most Common PERSON Entities:
# Joe: 100 times
# Norma: 80 times
# Max: 40 times
# DeMille: 16 times
# Betty Schaefer: 12 times
#
# ========================================
#
# Movie ID: tt0045152 - Most Common PERSON Entities:
# Don: 56 times
# Kathy: 44 times
# Don Lockwood: 9 times
# R.F. Simpson: 8 times
# Monumental: 8 times
#
# ========================================
#
# Movie ID: tt0046268 - Most Common PERSON Entities:
# Jo: 208 times
# Mario: 144 times
# Luigi: 84 times
# O'Brien: 36 times
# Smerloff: 28 times
#
# ========================================
#
# Movie ID: tt0046438 - Most Common PERSON Entities:
# Shige: 20 times
# Noriko: 20 times
# Koichi: 12 times
# Kyoko: 8 times
# Grandma: 8 times
#
# ========================================
#
# Movie ID: tt0046911 - Most Common PERSON Entities:
# Michel: 44 times
# Nicole: 24 times
# Delassalle: 8 times
# Christina: 8 times
# Alfred: 8 times
#
# ========================================
#
# Movie ID: tt0046912 - Most Common PERSON Entities:
# Tony: 196 times
# Mark: 100 times
# Hubbard: 16 times
# Tony Wendice: 8 times
# Mark Halliday: 8 times
#
# ========================================
#
# Movie ID: tt0047296 - Most Common PERSON Entities:
# Terry: 508 times
# Johnny: 256 times
# Barry: 152 times
# Edie: 132 times
# Joey: 76 times
#
# ========================================
#
# Movie ID: tt0047396 - Most Common PERSON Entities:
# Lisa: 56 times
# Jeff: 36 times
# Stella: 24 times
# Thorwald: 12 times
# James Stewart: 4 times
#
# ========================================
#
# Movie ID: tt0047478 - Most Common PERSON Entities:
# Kambei: 60 times
# Katsushir: 16 times
# Kyz: 16 times
# Shino: 8 times
# Colin Tinto: 4 times
#
# ========================================
#
# Movie ID: tt0050083 - Most Common PERSON Entities:
# Juror 4: 32 times
# Juror 8: 16 times
# Juror 5: 12 times
# Juror 3: 8 times
# Juror 9: 8 times
#
# ========================================
#
# Movie ID: tt0050212 - Most Common PERSON Entities:
# Saito: 60 times
# Nicholson: 56 times
# Shears: 44 times
# Joyce: 28 times
# Warden: 24 times
#
# ========================================
#
# Movie ID: tt0050783 - Most Common PERSON Entities:
# Giorgio: 12 times
# Oscar: 9 times
# Lazzari: 6 times
# Giulietta Masina: 3 times
# Wanda: 3 times
#
# ========================================
#
# Movie ID: tt0050825 - Most Common PERSON Entities:
# Mireau: 168 times
# Dax: 52 times
# Broulard: 32 times
# Ferol: 24 times
# Cpl: 16 times
#
# ========================================
#
# Movie ID: tt0050976 - Most Common PERSON Entities:
# JOF: 40 times
# Jof: 28 times
# KNIGHT: 20 times
# Death: 16 times
# Mikael: 12 times
#
# ========================================
#
# Movie ID: tt0050986 - Most Common PERSON Entities:
# Marianne: 64 times
# Sara: 36 times
# Evald: 24 times
# Sigfrid: 24 times
# Agda: 16 times
#
# ========================================
#
# Movie ID: tt0051201 - Most Common PERSON Entities:
# Wilfred: 24 times
# Christine Vole: 16 times
# Leonard: 16 times
# Leonard Vole: 8 times
# Emily French: 8 times
#
# ========================================
#
# Movie ID: tt0052311 - Most Common PERSON Entities:
# Quinlan: 136 times
# Vargas: 96 times
# Grandi: 60 times
# Susan: 52 times
# Gould: 12 times
#
# ========================================
#
# Movie ID: tt0052357 - Most Common PERSON Entities:
# Scottie: 200 times
# Madeleine: 200 times
# Judy: 88 times
# Midge: 48 times
# Gavin: 24 times
#
# ========================================
#
# Movie ID: tt0052618 - Most Common PERSON Entities:
# Judah: 132 times
# Messala: 60 times
# Jesus: 16 times
# Judah Ben-Hur: 12 times
# Judea: 8 times
#
# ========================================
#
# Movie ID: tt0053125 - Most Common PERSON Entities:
# Roger: 452 times
# Eve: 140 times
# Kaplan: 108 times
# Leonard: 84 times
# Thornhill: 40 times
#
# ========================================
#
# Movie ID: tt0053291 - Most Common PERSON Entities:
# Joe: 244 times
# Jerry: 212 times
# Osgood: 68 times
# Spats: 52 times
# Josephine: 20 times
#
# ========================================
#
# Movie ID: tt0053604 - Most Common PERSON Entities:
# Baxter: 72 times
# Kubelik: 64 times
# Fran Kubelik: 8 times
# Jack Lemmon: 4 times
# Shirley MacLaine: 4 times
#
# ========================================
#
# Movie ID: tt0054215 - Most Common PERSON Entities:
# Norman: 220 times
# Sam: 112 times
# Marion: 84 times
# Lila: 80 times
# Mother: 20 times
#
# ========================================
#
# Movie ID: tt0055031 - Most Common PERSON Entities:
# Haywood: 28 times
# Dan Haywood: 8 times
# Ernst Janning: 8 times
# Bertholt: 8 times
# Hitler: 8 times
#
# ========================================
#
# Movie ID: tt0055630 - Most Common PERSON Entities:
# Ushitora: 132 times
# Gonji: 96 times
# Inokichi: 36 times
# Sanjuro: 20 times
# Tokuemon: 16 times
#
# ========================================
#
# Movie ID: tt0056172 - Most Common PERSON Entities:
# Lawrence: 104 times
# Faisal: 20 times
# Sherif Ali: 16 times
# Brighton: 12 times
# Allenby: 12 times
#
# ========================================
#
# Movie ID: tt0056592 - Most Common PERSON Entities:
# Jem: 132 times
# Tom: 48 times
# Scout: 40 times
# Bob Ewell: 32 times
# Dill: 20 times
#
# ========================================
#
# Movie ID: tt0057012 - Most Common PERSON Entities:
# Ripper: 68 times
# Mandrake: 20 times
# Turgidson: 16 times
# Strangelove: 16 times
# Jack D. Ripper: 8 times
#
# ========================================
#
# Movie ID: tt0057115 - Most Common PERSON Entities:
# Bartlett: 80 times
# Werner: 24 times
# Danny: 20 times
# Mac: 20 times
# Willie: 12 times
#
# ========================================
#
# Movie ID: tt0059578 - Most Common PERSON Entities:
# Mortimer: 76 times
# Monco: 72 times
# Groggy: 16 times
# Indio: 12 times
# Douglas Mortimer: 8 times
#
# ========================================
#
# Movie ID: tt0060107 - Most Common PERSON Entities:
# Andrei: 56 times
# Danila: 20 times
# Kirill: 20 times
# Vladimir: 8 times
# Boris: 8 times
#
# ========================================
#
# Movie ID: tt0060196 - Most Common PERSON Entities:
# Tuco: 128 times
# Angel Eyes: 40 times
# Blondie: 20 times
# Bill Carson: 20 times
# Carson: 12 times
#
# ========================================
#
# Movie ID: tt0060827 - Most Common PERSON Entities:
# Alma: 104 times
# Elisabet Vogler: 12 times
# Vogler: 12 times
# Elisabeth: 12 times
# Bergman: 4 times
#
# ========================================
#
# Movie ID: tt0061512 - Most Common PERSON Entities:
# Luke: 176 times
# Dragline: 80 times
# Lucas Jackson: 4 times
# Paul Newman: 4 times
# Sargeant: 4 times
#
# ========================================
#
# Movie ID: tt0062622 - Most Common PERSON Entities:
# Dave: 108 times
# Frank: 60 times
# Hal: 56 times
# Floyd: 44 times
# Johann Strauss': 8 times
#
# ========================================
#
# Movie ID: tt0064115 - Most Common PERSON Entities:
# Butch: 76 times
# Etta: 12 times
# Garris: 8 times
# Butch Cassidy: 4 times
# Paul Newman: 4 times
#
# ========================================
#
# Movie ID: tt0064116 - Most Common PERSON Entities:
# Frank: 248 times
# Jill: 116 times
# Cheyenne: 108 times
# Harmonica: 96 times
# Morton: 88 times
#
# ========================================
#
# Movie ID: tt0066921 - Most Common PERSON Entities:
# Alex: 420 times
# Alexander: 60 times
# Dim: 24 times
# Georgie: 20 times
# Joe: 16 times
#
# ========================================
#
# Movie ID: tt0068646 - Most Common PERSON Entities:
# Michael: 228 times
# Sonny: 116 times
# Don: 88 times
# Sollozzo: 68 times
# Connie: 48 times
#
# ========================================
#
# Movie ID: tt0070510 - Most Common PERSON Entities:
# Addie: 168 times
# Moze: 40 times
# Essie May: 8 times
# Pearl: 8 times
# Essie May Loggins: 4 times
#
# ========================================
#
# Movie ID: tt0070735 - Most Common PERSON Entities:
# Lonnegan: 84 times
# Gondorff: 56 times
# Luther: 32 times
# Snyder: 24 times
# Doyle Lonnegan: 8 times
#
# ========================================
#
# Movie ID: tt0071315 - Most Common PERSON Entities:
# Evelyn: 104 times
# Jake: 60 times
# Mulwray: 44 times
# Evelyn Mulwray: 28 times
# Mulvihill: 16 times
#
# ========================================
#
# Movie ID: tt0071562 - Most Common PERSON Entities:
# Michael: 280 times
# Roth: 76 times
# Johnny Ola: 36 times
# Hyman Roth: 32 times
# Frank Pentangeli: 28 times
#
# ========================================
#
# Movie ID: tt0071853 - Most Common PERSON Entities:
# Arthur: 268 times
# Robin: 80 times
# Bedevere: 48 times
# Herbert: 36 times
# Lancelot: 32 times
#
# ========================================
#
# Movie ID: tt0072684 - Most Common PERSON Entities:
# Barry: 280 times
# Bullingdon: 68 times
# Lady Lyndon: 52 times
# Bryan: 28 times
# Quin: 20 times
#
# ========================================
#
# Movie ID: tt0072890 - Most Common PERSON Entities:
# Sonny: 144 times
# Sal: 40 times
# Leon: 28 times
# Sheldon: 20 times
# Mulvaney: 12 times
#
# ========================================
#
# Movie ID: tt0073195 - Most Common PERSON Entities:
# Quint: 80 times
# Brody: 72 times
# Hooper: 64 times
# Michael: 28 times
# Ellen: 24 times
#
# ========================================
#
# Movie ID: tt0073486 - Most Common PERSON Entities:
# McMurphy: 80 times
# Billy: 36 times
# Mac: 32 times
# Candy: 8 times
# Ratched: 8 times
#
# ========================================
#
# Movie ID: tt0074958 - Most Common PERSON Entities:
# Schumacher: 24 times
# Christensen: 24 times
# Jensen: 16 times
# Howard Beale: 12 times
# Hackett: 12 times
#
# ========================================
#
# Movie ID: tt0075148 - Most Common PERSON Entities:
# Rocky: 104 times
# Paulie: 92 times
# Mick: 88 times
# Gazzo: 76 times
# Spider: 20 times
#
# ========================================
#
# Movie ID: tt0075314 - Most Common PERSON Entities:
# Travis: 144 times
# Iris: 44 times
# Betsy: 36 times
# Wizard: 16 times
# Palantine: 12 times
#
# ========================================
#
# Movie ID: tt0075686 - Most Common PERSON Entities:
# Annie Hall: 16 times
# Annie: 16 times
# Alvy Singer: 12 times
# Woody Allen: 4 times
# Diane Keaton: 4 times
#
# ========================================
#
# Movie ID: tt0076759 - Most Common PERSON Entities:
# Luke: 432 times
# Vader: 68 times
# Owen: 44 times
# Tarkin: 28 times
# Rebel: 24 times
#
# ========================================
#
# Movie ID: tt0077416 - Most Common PERSON Entities:
# Mike: 144 times
# Steven: 52 times
# Nick: 28 times
# Linda: 28 times
# Stan: 24 times
#
# ========================================
#
# Movie ID: tt0078748 - Most Common PERSON Entities:
# Kane: 132 times
# Lambert: 80 times
# Ash: 64 times
# Brett: 48 times
# Jones: 44 times
#
# ========================================
#
# Movie ID: tt0078788 - Most Common PERSON Entities:
# Willard: 108 times
# Kurtz: 84 times
# Viet Cong: 12 times
# Lucas: 8 times
# Clean: 8 times
#
# ========================================
#
# Movie ID: tt0079470 - Most Common PERSON Entities:
# Brian: 60 times
# Jesus: 16 times
# Judith: 12 times
# Nazareth: 8 times
# Brian Cohen: 4 times
#
# ========================================
#
# Movie ID: tt0079944 - Most Common PERSON Entities:
# Writer: 8 times
# Wallace: 4 times
# Alisa Frejndlikh: 4 times
# Aleksandr Kajdanovsky: 4 times
# Anatoli Solonitsyn: 4 times
#
# ========================================
#
# Movie ID: tt0080678 - Most Common PERSON Entities:
# Merrick: 36 times
# Bytes: 8 times
# John Merrick: 8 times
# Kendal: 8 times
# Frederick Treves: 4 times
#
# ========================================
#
# Movie ID: tt0080684 - Most Common PERSON Entities:
# Luke: 244 times
# Vader: 48 times
# Yoda: 32 times
# Darth Vader: 20 times
# Rebel: 16 times
#
# ========================================
#
# Movie ID: tt0081398 - Most Common PERSON Entities:
# Joey: 52 times
# Vickie: 28 times
# Salvy: 20 times
# Jake LaMotta: 12 times
# Jake: 12 times
#
# ========================================
#
# Movie ID: tt0081505 - Most Common PERSON Entities:
# Jack: 228 times
# Danny: 156 times
# Wendy: 100 times
# Dick: 32 times
# Jack Torrance: 8 times
#
# ========================================
#
# Movie ID: tt0082096 - Most Common PERSON Entities:
# Werner: 64 times
# Johann: 40 times
# Thomsen: 16 times
# Otto Sander: 4 times
# Jürgen Prochnow: 4 times
#
# ========================================
#
# Movie ID: tt0082971 - Most Common PERSON Entities:
# Indy: 176 times
# Ark: 44 times
# Marion: 36 times
# Sallah: 24 times
# Jones: 20 times
#
# ========================================
#
# Movie ID: tt0083658 - Most Common PERSON Entities:
# Roy: 132 times
# Deckard: 116 times
# Rachael: 104 times
# Leon: 56 times
# Sebastian: 52 times
#
# ========================================
#
# Movie ID: tt0083987 - Most Common PERSON Entities:
# Gandhi: 140 times
# Dyer: 8 times
# Godse: 8 times
# Mohandas K. "Mahatma" Gandhi: 4 times
# Daniel Day-Lewis: 4 times
#
# ========================================
#
# Movie ID: tt0084787 - Most Common PERSON Entities:
# Blair: 36 times
# Mac: 24 times
# Garry: 20 times
# Clark: 20 times
# Norris: 20 times
#
# ========================================
#
# Movie ID: tt0086190 - Most Common PERSON Entities:
# Luke: 264 times
# Jabba: 80 times
# Vader: 40 times
# Rebel: 36 times
# Jedi: 24 times
#
# ========================================
#
# Movie ID: tt0086250 - Most Common PERSON Entities:
# Tony: 480 times
# Sosa: 116 times
# Manny: 100 times
# Frank: 84 times
# Gina: 64 times
#
# ========================================
#
# Movie ID: tt0086879 - Most Common PERSON Entities:
# Mozart: 116 times
# Salieri: 8 times
# Constanze: 8 times
# Leopold: 8 times
# Joseph: 4 times
#
# ========================================
#
# Movie ID: tt0087843 - Most Common PERSON Entities:
# Noodles: 148 times
# Max: 140 times
# Deborah: 36 times
# Patsy: 28 times
# Jimmy: 28 times
#
# ========================================
#
# Movie ID: tt0087884 - Most Common PERSON Entities:
# Travis: 124 times
# Hunter: 96 times
# Jane: 76 times
# Walt: 72 times
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0088247 - Most Common PERSON Entities:
# Sarah: 240 times
# Kyle: 48 times
# Ginger: 32 times
# Sarah Connor: 24 times
# John: 16 times
#
# ========================================
#
# Movie ID: tt0088763 - Most Common PERSON Entities:
# Marty: 820 times
# George: 228 times
# Lorraine: 208 times
# Doc: 164 times
# Jennifer: 64 times
#
# ========================================
#
# Movie ID: tt0089881 - Most Common PERSON Entities:
# Saburo: 12 times
# Hidetora Ichimonji: 4 times
# Tatsuya Nakadai: 4 times
# Saburo Naotora Ichimonji: 4 times
# Daisuke Ryu: 4 times
#
# ========================================
#
# Movie ID: tt0090605 - Most Common PERSON Entities:
# Newt: 164 times
# Burke: 108 times
# Aliens: 76 times
# Hudson: 44 times
# Alien: 28 times
#
# ========================================
#
# Movie ID: tt0091763 - Most Common PERSON Entities:
# Taylor: 160 times
# Elias: 40 times
# Rhah: 24 times
# Francis: 24 times
# Bunny: 16 times
#
# ========================================
#
# Movie ID: tt0092005 - Most Common PERSON Entities:
# Gordie: 108 times
# Chris: 68 times
# Teddy: 44 times
# Vern: 24 times
# Ray: 16 times
#
# ========================================
#
# Movie ID: tt0092067 - Most Common PERSON Entities:
# Sheeta: 544 times
# Dola: 140 times
# Goliath: 84 times
# Pazu: 44 times
# Uncle Pom: 20 times
#
# ========================================
#
# Movie ID: tt0093058 - Most Common PERSON Entities:
# Joker: 196 times
# Hartman: 60 times
# Pyle: 56 times
# Rafterman: 12 times
# Leanne Hong: 8 times
#
# ========================================
#
# Movie ID: tt0093779 - Most Common PERSON Entities:
# Westley: 140 times
# Buttercup: 116 times
# Fezzik: 92 times
# Rugen: 40 times
# Count Rugen: 36 times
#
# ========================================
#
# Movie ID: tt0095016 - Most Common PERSON Entities:
# Gruber: 92 times
# McClane: 88 times
# Holly: 48 times
# Powell: 28 times
# Karl: 24 times
#
# ========================================
#
# Movie ID: tt0095327 - Most Common PERSON Entities:
# Setsuko: 48 times
# Tsutomu Tatsumi: 4 times
# J. Robert Spencer: 4 times
# Ayano Shiraishi: 4 times
# Rhoda Chrosite: 4 times
#
# ========================================
#
# Movie ID: tt0095765 - Most Common PERSON Entities:
# Salvatore: 44 times
# Toto: 12 times
# Alfredo: 4 times
# Elena: 4 times
# Clarisse P. DIRECTOR'S: 3 times
#
# ========================================
#
# Movie ID: tt0096283 - Most Common PERSON Entities:
# Mei: 144 times
# Satsuki: 88 times
# Tatsuo: 28 times
# Granny: 28 times
# Kanta: 28 times
#
# ========================================
#
# Movie ID: tt0097165 - Most Common PERSON Entities:
# Keating: 172 times
# Neil: 108 times
# Knox: 36 times
# Todd: 32 times
# Charlie: 28 times
#
# ========================================
#
# Movie ID: tt0097576 - Most Common PERSON Entities:
# Indy: 224 times
# Henry: 76 times
# Elsa: 68 times
# Donovan: 56 times
# Sallah: 20 times
#
# ========================================
#
# Movie ID: tt0098966 - Most Common PERSON Entities:
# Mary: 28 times
# Sylvia: 28 times
# Edward: 20 times
# Peter: 16 times
# Jack: 12 times
#
# ========================================
#
# Movie ID: tt0099052 - Most Common PERSON Entities:
# Ross: 164 times
# Metcalf: 48 times
# Jerry: 44 times
# Margaret: 24 times
# Delbert: 24 times
#
# ========================================
#
# Movie ID: tt0099077 - Most Common PERSON Entities:
# Leonard: 24 times
# Malcolm Sayer: 8 times
# Lowe: 8 times
# Paula: 8 times
# Robin Williams: 4 times
#
# ========================================
#
# Movie ID: tt0099088 - Most Common PERSON Entities:
# Marty: 500 times
# Doc: 248 times
# Clara: 124 times
# Buford: 84 times
# Jennifer: 24 times
#
# ========================================
#
# Movie ID: tt0099253 - Most Common PERSON Entities:
# Andy: 84 times
# Kyle: 40 times
# Phil: 20 times
# Joanne: 16 times
# Simpson: 8 times
#
# ========================================
#
# Movie ID: tt0099329 - Most Common PERSON Entities:
# Allison: 144 times
# Baldwin: 72 times
# Vernon-Williams: 32 times
# Lenora: 28 times
# Drape: 20 times
#
# ========================================
#
# Movie ID: tt0099348 - Most Common PERSON Entities:
# Dunbar: 28 times
# Kicking Bird: 20 times
# Fambrough: 8 times
# Fort Sedgwick: 8 times
# Lakota: 8 times
#
# ========================================
#
# Movie ID: tt0099365 - Most Common PERSON Entities:
# Julie: 68 times
# Westlake: 32 times
# Strack: 32 times
# Rick: 12 times
# Paulie: 12 times
#
# ========================================
#
# Movie ID: tt0099422 - Most Common PERSON Entities:
# Tracy: 256 times
# Big Boy: 24 times
# Keys: 20 times
# 88 Keys: 16 times
# Dick Tracy: 12 times
#
# ========================================
#
# Movie ID: tt0099423 - Most Common PERSON Entities:
# McClane: 264 times
# Stuart: 108 times
# Miller: 104 times
# Esperanza: 72 times
# Trudeau: 72 times
#
# ========================================
#
# Movie ID: tt0099487 - Most Common PERSON Entities:
# Edward: 136 times
# Kim: 52 times
# Jim: 44 times
# Peg: 24 times
# Joyce: 16 times
#
# ========================================
#
# Movie ID: tt0099566 - Most Common PERSON Entities:
# Bull: 3 times
# Kathy Li Couple: 2 times
# Kathy Li: 1 times
#
# ========================================
#
# Movie ID: tt0099582 - Most Common PERSON Entities:
# Nelson: 168 times
# David: 84 times
# Rachel: 40 times
# Joe: 32 times
# Billy Mahoney: 20 times
#
# ========================================
#
# Movie ID: tt0099653 - Most Common PERSON Entities:
# Sam: 108 times
# Carl: 68 times
# Molly: 64 times
# Ode Mae: 16 times
# Molly Jensen: 8 times
#
# ========================================
#
# Movie ID: tt0099674 - Most Common PERSON Entities:
# Michael: 236 times
# Vincent: 80 times
# Kay: 32 times
# Mary: 32 times
# Corleone: 28 times
#
# ========================================
#
# Movie ID: tt0099685 - Most Common PERSON Entities:
# Henry: 176 times
# Jimmy: 68 times
# Karen: 60 times
# Tommy: 48 times
# Jimmy Conway: 28 times
#
# ========================================
#
# Movie ID: tt0099731 - Most Common PERSON Entities:
# Kate: 249 times
# Moira: 45 times
# Serena: 27 times
# Janine: 24 times
# Ofglen: 21 times
#
# ========================================
#
# Movie ID: tt0099739 - Most Common PERSON Entities:
# Andy: 24 times
# Trent: 20 times
# O'Malley: 12 times
# Jack Axel: 8 times
# Max: 8 times
#
# ========================================
#
# Movie ID: tt0099785 - Most Common PERSON Entities:
# Kevin: 80 times
# Buzz: 24 times
# Harry: 20 times
# Marley: 20 times
# Peter: 12 times
#
# ========================================
#
# Movie ID: tt0099810 - Most Common PERSON Entities:
# Ryan: 264 times
# Ramius: 224 times
# Mancuso: 124 times
# Putin: 48 times
# Jonesy: 36 times
#
# ========================================
#
# Movie ID: tt0099871 - Most Common PERSON Entities:
# Jacob: 140 times
# Sarah: 12 times
# Paul: 12 times
# Jacob Singer: 8 times
# Frank: 8 times
#
# ========================================
#
# Movie ID: tt0099938 - Most Common PERSON Entities:
# John: 64 times
# Joyce: 16 times
# Crisp: 16 times
# Rachel: 12 times
# John Kimble: 8 times
#
# ========================================
#
# Movie ID: tt0100029 - Most Common PERSON Entities:
# LH: 36 times
# Joshua: 20 times
# Cynthia: 20 times
# Attila: 20 times
# Leon: 8 times
#
# ========================================
#
# Movie ID: tt0100140 - Most Common PERSON Entities:
# Rachel: 12 times
# Rachel Flax: 8 times
# Kate: 8 times
# Joe: 8 times
# Lou: 4 times
#
# ========================================
#
# Movie ID: tt0100150 - Most Common PERSON Entities:
# Tom: 432 times
# Bernie: 268 times
# Leo: 180 times
# Tommy: 64 times
# Verna: 32 times
#
# ========================================
#
# Movie ID: tt0100157 - Most Common PERSON Entities:
# Annie: 76 times
# Paul: 64 times
# Paul Sheldon: 8 times
# James Caan: 4 times
# Lauren Bacall: 4 times
#
# ========================================
#
# Movie ID: tt0100403 - Most Common PERSON Entities:
# Harrigan: 116 times
# Danny: 60 times
# Jerry: 52 times
# Keyes: 44 times
# Leona: 20 times
#
# ========================================
#
# Movie ID: tt0100404 - Most Common PERSON Entities:
# Sabich: 84 times
# Horgan: 28 times
# Barbara: 20 times
# Stern: 20 times
# Rusty: 16 times
#
# ========================================
#
# Movie ID: tt0100405 - Most Common PERSON Entities:
# Edward: 60 times
# Vivienne: 40 times
# Philip: 16 times
# Edward Lewis: 12 times
# Vivian Ward: 8 times
#
# ========================================
#
# Movie ID: tt0100419 - Most Common PERSON Entities:
# Ben: 80 times
# Beck: 40 times
# Flo: 36 times
# Big Ben: 12 times
# Roy: 12 times
#
# ========================================
#
# Movie ID: tt0100502 - Most Common PERSON Entities:
# Murphy: 32 times
# Lewis: 16 times
# Alex Murphy: 4 times
# Juliette Faxx: 4 times
# Anne Lewis: 4 times
#
# ========================================
#
# Movie ID: tt0100507 - Most Common PERSON Entities:
# Tommy: 48 times
# Rocky: 32 times
# Robert: 20 times
# Balboa: 20 times
# Mickey: 20 times
#
# ========================================
#
# Movie ID: tt0100758 - Most Common PERSON Entities:
# Splinter: 92 times
# Danny: 72 times
# Raphael: 68 times
# Shredder: 40 times
# Casey: 36 times
#
# ========================================
#
# Movie ID: tt0100802 - Most Common PERSON Entities:
# Cohaagen: 68 times
# Quaid: 40 times
# Lori: 36 times
# Edgemar: 32 times
# Benny: 24 times
#
# ========================================
#
# Movie ID: tt0100814 - Most Common PERSON Entities:
# Val: 32 times
# Earl: 20 times
# Rhonda: 16 times
# Walter: 8 times
# Kevin Bacon: 4 times
#
# ========================================
#
# Movie ID: tt0100935 - Most Common PERSON Entities:
# Sailor: 100 times
# Lula: 80 times
# Bobby: 28 times
# Farragut: 24 times
# Reindeer: 12 times
#
# ========================================
#
# Movie ID: tt0101272 - Most Common PERSON Entities:
# Fester: 56 times
# Gomez: 52 times
# Abigail: 40 times
# Gordon: 36 times
# Morticia: 24 times
#
# ========================================
#
# Movie ID: tt0101316 - Most Common PERSON Entities:
# Chinaman: 36 times
# Jeanne Moreau's: 4 times
# Tony Leung Ka Fai: 4 times
# Morris Leon-Bollet: 4 times
# Duras: 4 times
#
# ========================================
#
# Movie ID: tt0101393 - Most Common PERSON Entities:
# Brian: 304 times
# Steven: 140 times
# Tim: 32 times
# Ronald: 32 times
# Jennifer: 24 times
#
# ========================================
#
# Movie ID: tt0101410 - Most Common PERSON Entities:
# Charlie: 24 times
# Lipnick: 20 times
# Earle: 16 times
# Fink: 16 times
# Charlie Meadows: 12 times
#
# ========================================
#
# Movie ID: tt0101414 - Most Common PERSON Entities:
# Belle: 80 times
# Beast: 68 times
# Maurice: 60 times
# Gaston: 56 times
# Potts: 4 times
#
# ========================================
#
# Movie ID: tt0101507 - Most Common PERSON Entities:
# Ricky: 148 times
# Tre: 112 times
# Furious: 56 times
# Dough: 44 times
# Rick: 32 times
#
# ========================================
#
# Movie ID: tt0101516 - Most Common PERSON Entities:
# Ben: 152 times
# Siegel: 76 times
# Cohen: 56 times
# Dragna: 28 times
# Tibbett: 12 times
#
# ========================================
#
# Movie ID: tt0101540 - Most Common PERSON Entities:
# Max: 152 times
# Sam: 136 times
# Leigh: 20 times
# Kersek: 16 times
# Sam Bowden: 12 times
#
# ========================================
#
# Movie ID: tt0101545 - Most Common PERSON Entities:
# Jim: 136 times
# Josie: 40 times
# Josey: 12 times
# McClelland: 8 times
# Jim Dodge: 4 times
#
# ========================================
#
# Movie ID: tt0101587 - Most Common PERSON Entities:
# Mitch: 188 times
# Ed: 64 times
# Phil: 64 times
# Norman: 32 times
# Jeff: 16 times
#
# ========================================
#
# Movie ID: tt0101635 - Most Common PERSON Entities:
# Grey: 16 times
# Curly Sue: 12 times
# Bill: 8 times
# Arnold: 4 times
# william dancer.he: 4 times
#
# ========================================
#
# Movie ID: tt0101745 - Most Common PERSON Entities:
# Ben: 140 times
# Lou: 48 times
# Hogue: 16 times
# Hank: 12 times
# Benjamin Stone: 8 times
#
# ========================================
#
# Movie ID: tt0101757 - Most Common PERSON Entities:
# Sue Ellen: 68 times
# Sturak: 36 times
# Crandell: 20 times
# Bryan: 20 times
# Rose: 20 times
#
# ========================================
#
# Movie ID: tt0101761 - Most Common PERSON Entities:
# Jim: 256 times
# Pamela: 48 times
# Ray: 20 times
# Kennealy: 20 times
# Jim Morrison: 16 times
#
# ========================================
#
# Movie ID: tt0101775 - Most Common PERSON Entities:
# Elizabeth: 33 times
# Fred: 28 times
# Charles: 24 times
# Tim Matheson: 4 times
# Janey: 4 times
#
# ========================================
#
# Movie ID: tt0101862 - Most Common PERSON Entities:
# George: 40 times
# Bryan: 36 times
# Annie: 28 times
# John: 8 times
# Steve Martin: 4 times
#
# ========================================
#
# Movie ID: tt0101889 - Most Common PERSON Entities:
# Jack: 348 times
# Parry: 248 times
# Anne: 80 times
# Jack Lucas: 8 times
# Jeff Bridges: 4 times
#
# ========================================
#
# Movie ID: tt0102057 - Most Common PERSON Entities:
# Peter: 248 times
# Jack: 64 times
# Maggie: 36 times
# Wendy: 36 times
# Hook: 28 times
#
# ========================================
#
# Movie ID: tt0102070 - Most Common PERSON Entities:
# Hudson: 232 times
# Kaplan: 68 times
# Baragli: 48 times
# Tommy: 44 times
# Alfred: 36 times
#
# ========================================
#
# Movie ID: tt0102138 - Most Common PERSON Entities:
# Garrison: 144 times
# Kennedy: 68 times
# Oswald: 52 times
# Ferrie: 20 times
# Liz: 20 times
#
# ========================================
#
# Movie ID: tt0102388 - Most Common PERSON Entities:
# Dani: 16 times
# Elvis: 4 times
# Dad: 4 times
# Court Foster: 4 times
#
# ========================================
#
# Movie ID: tt0102492 - Most Common PERSON Entities:
# Vada: 24 times
# Vada Sultenfuss: 8 times
# Anna Chlumsky: 8 times
# Dan Aykroyd: 8 times
# Harry: 8 times
#
# ========================================
#
# Movie ID: tt0102511 - Most Common PERSON Entities:
# Bill: 132 times
# Joan: 40 times
# Tom: 24 times
# Clark-Nova: 12 times
# Hans: 12 times
#
# ========================================
#
# Movie ID: tt0102526 - Most Common PERSON Entities:
# Scotty: 40 times
# Pookie: 40 times
# Gee Money: 32 times
# Carter: 12 times
# Frankie: 8 times
#
# ========================================
#
# Movie ID: tt0102536 - Most Common PERSON Entities:
# Corky: 16 times
# Winona Ryder: 4 times
# Victoria Snelling: 4 times
# Helmut Grokenberger: 4 times
# Armin Mueller-Stahl: 4 times
#
# ========================================
#
# Movie ID: tt0102558 - Most Common PERSON Entities:
# Chris: 60 times
# Diane: 32 times
# Reeve: 20 times
# Renalda: 16 times
# Fausto: 12 times
#
# ========================================
#
# Movie ID: tt0102685 - Most Common PERSON Entities:
# Johnny: 48 times
# Rosie: 20 times
# Roach: 12 times
# Johnny Utah: 8 times
# Tyler: 8 times
#
# ========================================
#
# Movie ID: tt0102744 - Most Common PERSON Entities:
# Quigley: 112 times
# Cora: 52 times
# Roy: 20 times
# Marston: 12 times
# Major: 8 times
#
# ========================================
#
# Movie ID: tt0102782 - Most Common PERSON Entities:
# Richard: 144 times
# Lilli: 72 times
# Sarah: 60 times
# Sylvia: 28 times
# heathens: 4 times
#
# ========================================
#
# Movie ID: tt0102798 - Most Common PERSON Entities:
# Robin: 72 times
# Richard: 16 times
# Mortianna: 12 times
# Maid Marian: 12 times
# Peter: 8 times
#
# ========================================
#
# Movie ID: tt0102803 - Most Common PERSON Entities:
# Jenny: 152 times
# Peevy: 40 times
# Malcolm: 28 times
# Zeppelin: 28 times
# Howard Hughes: 24 times
#
# ========================================
#
# Movie ID: tt0102926 - Most Common PERSON Entities:
# Lecter: 76 times
# Buffalo Bill: 28 times
# Hannibal Lecter: 12 times
# Catherine Martin: 12 times
# Starling: 12 times
#
# ========================================
#
# Movie ID: tt0102975 - Most Common PERSON Entities:
# Kirk: 192 times
# Spock: 68 times
# Chang: 56 times
# Gorkon: 48 times
# Kronos: 44 times
#
# ========================================
#
# Movie ID: tt0103060 - Most Common PERSON Entities:
# Shredder: 24 times
# Splinter: 20 times
# Keno: 20 times
# Perry: 12 times
# Tokka: 8 times
#
# ========================================
#
# Movie ID: tt0103064 - Most Common PERSON Entities:
# John: 660 times
# Sarah: 540 times
# Miles: 152 times
# Silberman: 44 times
# Dyson: 36 times
#
# ========================================
#
# Movie ID: tt0103074 - Most Common PERSON Entities:
# Louise: 224 times
# Thelma: 156 times
# Darryl: 60 times
# Jimmy: 56 times
# JD: 40 times
#
# ========================================
#
# Movie ID: tt0103639 - Most Common PERSON Entities:
# Jasmine: 80 times
# Jafar: 52 times
# Genie: 52 times
# Raja: 8 times
# Kassim: 4 times
#
# ========================================
#
# Movie ID: tt0103644 - Most Common PERSON Entities:
# Alien: 180 times
# Aaron: 84 times
# Morse: 64 times
# Andrews: 60 times
# Newt: 44 times
#
# ========================================
#
# Movie ID: tt0103772 - Most Common PERSON Entities:
# Catherine: 24 times
# Curran: 16 times
# Beth: 16 times
# Johnny Boz: 12 times
# Beth Garner: 8 times
#
# ========================================
#
# Movie ID: tt0103776 - Most Common PERSON Entities:
# Catwoman: 28 times
# Bruce Wayne: 24 times
# Gotham: 20 times
# Max: 20 times
# Bruce: 16 times
#
# ========================================
#
# Movie ID: tt0103855 - Most Common PERSON Entities:
# Frank: 24 times
# Rachel: 20 times
# Rachel Marron: 8 times
# Frank Farmer: 8 times
# Whitney Houston: 4 times
#
# ========================================
#
# Movie ID: tt0103873 - Most Common PERSON Entities:
# Paquita: 64 times
# Stewart: 24 times
# Rita: 24 times
# Uncle Les: 20 times
# Vera: 8 times
#
# ========================================
#
# Movie ID: tt0103874 - Most Common PERSON Entities:
# Dracula: 132 times
# Lucy: 72 times
# Jonathan: 68 times
# Van Helsing: 52 times
# Mina: 32 times
#
# ========================================
#
# Movie ID: tt0103893 - Most Common PERSON Entities:
# Merrick: 12 times
# Kristy Swanson: 4 times
# Merrick the Watcher: 4 times
# Donald Sutherland: 4 times
# Luke Perry: 4 times
#
# ========================================
#
# Movie ID: tt0103919 - Most Common PERSON Entities:
# Helen: 140 times
# Candyman: 84 times
# Bernie: 40 times
# Trevor: 36 times
# Anthony: 16 times
#
# ========================================
#
# Movie ID: tt0103939 - Most Common PERSON Entities:
# Charlie: 48 times
# Chaplin: 29 times
# Charles Chaplin: 24 times
# Sydney: 12 times
# Charles: 8 times
#
# ========================================
#
# Movie ID: tt0104036 - Most Common PERSON Entities:
# Jude: 60 times
# Jody: 48 times
# Jimmie: 40 times
# Ferguson: 8 times
# Jodie: 8 times
#
# ========================================
#
# Movie ID: tt0104070 - Most Common PERSON Entities:
# Madeline: 108 times
# Ernest: 84 times
# Helen: 52 times
# Lisle: 20 times
# Jim Morrison: 12 times
#
# ========================================
#
# Movie ID: tt0104257 - Most Common PERSON Entities:
# Dawson: 68 times
# Kendrick: 68 times
# Santiago: 52 times
# Kaffee: 48 times
# Galloway: 44 times
#
# ========================================
#
# Movie ID: tt0104348 - Most Common PERSON Entities:
# Levene: 124 times
# Williamson: 108 times
# Moss: 28 times
# Lingk: 20 times
# Shelley Levene: 8 times
#
# ========================================
#
# Movie ID: tt0104389 - Most Common PERSON Entities:
# Claire: 508 times
# Michael: 192 times
# Mott: 136 times
# Emma: 128 times
# Solomon: 128 times
#
# ========================================
#
# Movie ID: tt0104431 - Most Common PERSON Entities:
# Kevin: 200 times
# Harry: 28 times
# Duncan: 16 times
# Buzz: 12 times
# McCallister: 8 times
#
# ========================================
#
# Movie ID: tt0104691 - Most Common PERSON Entities:
# Hawkeye: 92 times
# Cora: 60 times
# Duncan: 56 times
# Chingachgook: 52 times
# Munroe: 40 times
#
# ========================================
#
# Movie ID: tt0104694 - Most Common PERSON Entities:
# Kit: 164 times
# Dottie: 136 times
# Jimmy: 92 times
# Mae: 72 times
# Marla: 56 times
#
# ========================================
#
# Movie ID: tt0104714 - Most Common PERSON Entities:
# Murtaugh: 184 times
# Riggs: 112 times
# Travis: 80 times
# Darryl: 72 times
# Rianne: 36 times
#
# ========================================
#
# Movie ID: tt0104779 - Most Common PERSON Entities:
# Oscar: 64 times
# Mimi: 48 times
# Fiona: 24 times
# Nigel: 24 times
# Nigel Dobson: 8 times
#
# ========================================
#
# Movie ID: tt0104797 - Most Common PERSON Entities:
# Malcolm: 404 times
# Muhammad: 32 times
# Elijah Muhammad: 24 times
# Johnson: 20 times
# Rudy: 16 times
#
# ========================================
#
# Movie ID: tt0104940 - Most Common PERSON Entities:
# Ebenezer Scrooge: 8 times
# Fozzie: 4 times
# Charles Dicken's: 4 times
# Jim Henson's: 4 times
# Michael Caine: 4 times
#
# ========================================
#
# Movie ID: tt0104952 - Most Common PERSON Entities:
# Vinny: 176 times
# Billy: 56 times
# Stan: 48 times
# Lisa: 44 times
# Haller: 32 times
#
# ========================================
#
# Movie ID: tt0104990 - Most Common PERSON Entities:
# Jack: 160 times
# David: 76 times
# Pulitzer: 40 times
# Denton: 40 times
# Bryan Denton: 20 times
#
# ========================================
#
# Movie ID: tt0105112 - Most Common PERSON Entities:
# Ryan: 120 times
# Miller: 116 times
# Holmes: 60 times
# Cathy: 44 times
# Sally: 32 times
#
# ========================================
#
# Movie ID: tt0105156 - Most Common PERSON Entities:
# Georgie: 64 times
# Darrel: 8 times
# Fred: 8 times
# Melissa Gilbert: 4 times
# Drew Barrymore: 4 times
#
# ========================================
#
# Movie ID: tt0105236 - Most Common PERSON Entities:
# Joe: 60 times
# White: 52 times
# Pink: 48 times
# Joe Cabot: 32 times
# Eddie: 32 times
#
# ========================================
#
# Movie ID: tt0105265 - Most Common PERSON Entities:
# Norman: 36 times
# Paul: 24 times
# Craig Sheffer: 4 times
# Brad Pitt: 4 times
# Jessie Burns: 4 times
#
# ========================================
#
# Movie ID: tt0105275 - Most Common PERSON Entities:
# Hando: 56 times
# Gabrielle: 28 times
# Martin: 8 times
# Davey: 8 times
# Footscray: 4 times
#
# ========================================
#
# Movie ID: tt0105323 - Most Common PERSON Entities:
# Charlie: 152 times
# Slade: 128 times
# George: 32 times
# Frank: 16 times
# Baird: 12 times
#
# ========================================
#
# Movie ID: tt0105327 - Most Common PERSON Entities:
# David: 68 times
# Greene: 28 times
# Van Kelt: 20 times
# Rosh Hashanah: 8 times
# David Greene: 4 times
#
# ========================================
#
# Movie ID: tt0105417 - Most Common PERSON Entities:
# Vince: 56 times
# Deloris: 36 times
# Mary Clarence: 20 times
# Souther: 16 times
# Joey: 12 times
#
# ========================================
#
# Movie ID: tt0105629 - Most Common PERSON Entities:
# Leslie: 108 times
# Patrick: 52 times
# Zevo Toys: 20 times
# Kenneth: 20 times
# Alsatia: 12 times
#
# ========================================
#
# Movie ID: tt0105665 - Most Common PERSON Entities:
# Laura: 304 times
# Jacques: 40 times
# Desmond: 36 times
# BOB: 36 times
# Donna: 36 times
#
# ========================================
#
# Movie ID: tt0105690 - Most Common PERSON Entities:
# Krill: 32 times
# Ryback: 20 times
# Casey Ryback: 8 times
# Adams: 8 times
# Jordan Tate: 8 times
#
# ========================================
#
# Movie ID: tt0105695 - Most Common PERSON Entities:
# Munny: 148 times
# Ned: 52 times
# Bill: 36 times
# Mike: 32 times
# Delilah: 24 times
#
# ========================================
#
# Movie ID: tt0105698 - Most Common PERSON Entities:
# Deveraux: 124 times
# Roberts: 48 times
# Scott: 16 times
# Gregor: 16 times
# Unisol: 8 times
#
# ========================================
#
# Movie ID: tt0106220 - Most Common PERSON Entities:
# Fester: 52 times
# Gomez: 32 times
# Morticia: 24 times
# Gary: 12 times
# Joel: 12 times
#
# ========================================
#
# Movie ID: tt0106308 - Most Common PERSON Entities:
# Arthur: 36 times
# Ash: 28 times
# Sheila: 12 times
# Linda: 8 times
# Duke Henry: 8 times
#
# ========================================
#
# Movie ID: tt0106489 - Most Common PERSON Entities:
# De Niro: 8 times
# Robert De Niro: 4 times
# Goodfellas: 4 times
# Lillo Brancato: 4 times
# Francis Capra: 4 times
#
# ========================================
#
# Movie ID: tt0106519 - Most Common PERSON Entities:
# Carlito: 112 times
# Benny: 24 times
# Tony: 24 times
# Gail: 20 times
# Vinnie: 12 times
#
# ========================================
#
# Movie ID: tt0106582 - Most Common PERSON Entities:
# Hal: 84 times
# Jessie: 68 times
# Qualen: 64 times
# Sarah: 44 times
# Matheson: 24 times
#
# ========================================
#
# Movie ID: tt0106611 - Most Common PERSON Entities:
# Irv: 48 times
# Blitzer: 20 times
# Bevil: 20 times
# Irving Blitzer: 12 times
# Yul: 12 times
#
# ========================================
#
# Movie ID: tt0106697 - Most Common PERSON Entities:
# Simon Phoenix: 16 times
# Huxley: 16 times
# John Spartan: 12 times
# Lenina Huxley: 12 times
# Cryoprison: 8 times
#
# ========================================
#
# Movie ID: tt0106701 - Most Common PERSON Entities:
# George: 30 times
# Switchblade Sam: 15 times
# Dennis: 15 times
# Alice: 6 times
# Sam: 6 times
#
# ========================================
#
# Movie ID: tt0106856 - Most Common PERSON Entities:
# William: 12 times
# Michael Douglas: 8 times
# Robert Duvall: 8 times
# Whammy Burger: 4 times
# Frederic Forrest: 4 times
#
# ========================================
#
# Movie ID: tt0106977 - Most Common PERSON Entities:
# Sam: 324 times
# Kimble: 192 times
# Charlie: 76 times
# Newman: 36 times
# Lentz: 36 times
#
# ========================================
#
# Movie ID: tt0107034 - Most Common PERSON Entities:
# Mark: 12 times
# Henry: 8 times
# Roy C.: 4 times
# Sam Comments: 3 times
# Sam: 1 times
#
# ========================================
#
# Movie ID: tt0107048 - Most Common PERSON Entities:
# Rita: 40 times
# Phil: 28 times
# Punxsutawney: 16 times
# Phil Connors: 4 times
# Bill Murray: 4 times
#
# ========================================
#
# Movie ID: tt0107050 - Most Common PERSON Entities:
# John: 124 times
# Ariel: 108 times
# Max: 96 times
# Jacob: 20 times
# Chuck: 16 times
#
# ========================================
#
# Movie ID: tt0107120 - Most Common PERSON Entities:
# Max: 144 times
# Dani: 116 times
# Alison: 92 times
# Winnie: 56 times
# Sanderson: 48 times
#
# ========================================
#
# Movie ID: tt0107207 - Most Common PERSON Entities:
# Gerry: 200 times
# Giuseppe: 48 times
# Paul: 40 times
# Gerry Conlon: 16 times
# Dickson: 16 times
#
# ========================================
#
# Movie ID: tt0107290 - Most Common PERSON Entities:
# Malcolm: 16 times
# Arnold: 16 times
# Sattler: 12 times
# Tim: 12 times
# John Hammond: 8 times
#
# ========================================
#
# Movie ID: tt0107362 - Most Common PERSON Entities:
# Slater: 208 times
# Danny: 184 times
# Jack: 80 times
# Benedict: 76 times
# Ripper: 64 times
#
# ========================================
#
# Movie ID: tt0107614 - Most Common PERSON Entities:
# Daniel: 84 times
# Doubtfire: 52 times
# Miranda: 48 times
# Lundy: 16 times
# Chris: 12 times
#
# ========================================
#
# Movie ID: tt0107616 - Most Common PERSON Entities:
# Claudio: 27 times
# Don John: 18 times
# Benedick: 18 times
# Don Pedro: 12 times
# Robert Sean Leonard: 3 times
#
# ========================================
#
# Movie ID: tt0107688 - Most Common PERSON Entities:
# Jack: 64 times
# Sally: 40 times
# Sandy Claws: 24 times
# Oogie Boogie: 12 times
# Jack Skellington: 8 times
#
# ========================================
#
# Movie ID: tt0107719 - Most Common PERSON Entities:
# Marie: 23 times
# Drosselmeyer: 7 times
# Mouse King: 4 times
# Fritz: 3 times
# Stahlbaum: 1 times
#
# ========================================
#
# Movie ID: tt0107808 - Most Common PERSON Entities:
# Butch: 200 times
# Philip: 140 times
# Buzz: 88 times
# Terry: 72 times
# Sally: 52 times
#
# ========================================
#
# Movie ID: tt0107818 - Most Common PERSON Entities:
# Miller: 44 times
# Beckett: 44 times
# Andrew Beckett: 8 times
# Joe Miller: 8 times
# Wheeler: 8 times
#
# ========================================
#
# Movie ID: tt0107822 - Most Common PERSON Entities:
# Ada: 84 times
# Flora: 28 times
# George: 12 times
# Stewart: 8 times
# Piano: 4 times
#
# ========================================
#
# Movie ID: tt0107943 - Most Common PERSON Entities:
# Stevens: 68 times
# Kenton: 16 times
# Lewis: 16 times
# Darlington: 8 times
# Anthony Hopkins: 4 times
#
# ========================================
#
# Movie ID: tt0107977 - Most Common PERSON Entities:
# Robin: 112 times
# Richard: 20 times
# John: 20 times
# Prince John: 16 times
# Blinkin: 16 times
#
# ========================================
#
# Movie ID: tt0108002 - Most Common PERSON Entities:
# Rudy: 16 times
# Rudy Ruettiger: 4 times
# Sean Astin: 4 times
# Pete: 4 times
# Christopher Reed: 4 times
#
# ========================================
#
# Movie ID: tt0108037 - Most Common PERSON Entities:
# Benny: 32 times
# Mertle: 20 times
# Babe Ruth: 12 times
# Scotty Smalls: 8 times
# Bill: 8 times
#
# ========================================
#
# Movie ID: tt0108052 - Most Common PERSON Entities:
# Schindler: 64 times
# Göth: 32 times
# Oskar Schindler: 16 times
# Ben Kingsley: 8 times
# Liam Neeson: 4 times
#
# ========================================
#
# Movie ID: tt0108071 - Most Common PERSON Entities:
# Mary: 168 times
# Colin: 92 times
# Dickon: 32 times
# Martha: 12 times
# Mary Lennox: 8 times
#
# ========================================
#
# Movie ID: tt0108160 - Most Common PERSON Entities:
# Sam: 144 times
# Jonah: 84 times
# Annie: 72 times
# Walter: 32 times
# Fieldstone: 20 times
#
# ========================================
#
# Movie ID: tt0108333 - Most Common PERSON Entities:
# D'Artagnan: 148 times
# Richelieu: 32 times
# Cardinal Richelieu: 16 times
# Gérard: 12 times
# Musketeer: 8 times
#
# ========================================
#
# Movie ID: tt0108358 - Most Common PERSON Entities:
# Wyatt: 24 times
# Wyatt Earp: 20 times
# Doc Holliday: 20 times
# Virgil: 12 times
# Morgan: 12 times
#
# ========================================
#
# Movie ID: tt0108399 - Most Common PERSON Entities:
# Elliot: 28 times
# Clifford: 16 times
# Dick: 12 times
# Dimes: 12 times
# Lee: 12 times
#
# ========================================
#
# Movie ID: tt0108550 - Most Common PERSON Entities:
# Gilbert: 108 times
# Arnie: 100 times
# Bonnie: 24 times
# Amy: 16 times
# Ellen: 16 times
#
# ========================================
#
# Movie ID: tt0109040 - Most Common PERSON Entities:
# Ace: 52 times
# Melissa: 48 times
# Dan Marino: 24 times
# Roger Podacter: 20 times
# Roger: 20 times
#
# ========================================
#
# Movie ID: tt0109254 - Most Common PERSON Entities:
# Foley: 28 times
# DeWald: 24 times
# Todd: 16 times
# Uncle Dave: 16 times
# Axel Foley: 8 times
#
# ========================================
#
# Movie ID: tt0109424 - Most Common PERSON Entities:
# Qiwu: 8 times
# Faye: 8 times
# He Qiwu: 4 times
# Brigitte Lin: 4 times
# Thom Baker: 4 times
#
# ========================================
#
# Movie ID: tt0109444 - Most Common PERSON Entities:
# Ryan: 32 times
# Jack Ryan: 8 times
# Ernesto Escobedo: 4 times
# Jim Greer: 4 times
# Felix Cortez: 4 times
#
# ========================================
#
# Movie ID: tt0109445 - Most Common PERSON Entities:
# Dante: 192 times
# Caitlin: 44 times
# Randal: 32 times
# Jay: 12 times
# Randal Graves: 8 times
#
# ========================================
#
# Movie ID: tt0109506 - Most Common PERSON Entities:
# Eric: 176 times
# Shelly: 68 times
# Sarah: 68 times
# Eric Draven: 12 times
# Darla: 12 times
#
# ========================================
#
# ...
#
# Movie ID: tt2488496 - Most Common ORGANIZATION Entities:
# Force: 32 times
# Falcon: 28 times
# Leia: 16 times
# First Order: 12 times
# Lukes: 8 times
#
# ========================================
#
# Movie ID: tt2527336 - Most Common ORGANIZATION Entities:
# Kylo: 64 times
# Leia: 24 times
# Force: 24 times
# Snoke: 20 times
# TIE: 16 times
#
# ========================================
#
# Movie ID: tt2543164 - Most Common ORGANIZATION Entities:
# Halpern: 4 times
#
# ========================================
#
# Movie ID: tt2554274 - Most Common ORGANIZATION Entities:
# Lucille: 20 times
# Crimson Peak: 12 times
# Edith: 8 times
# Edith Cushing: 4 times
# Cushing: 4 times
#
# ========================================
#
# Movie ID: tt2562232 - Most Common ORGANIZATION Entities:
# Lesley: 40 times
# Birdman: 16 times
# Raymond Carver's: 8 times
# Rope: 4 times
# St. James Theater: 4 times
#
# ========================================
#
# Movie ID: tt2582782 - Most Common ORGANIZATION Entities:
# Toby: 172 times
# Marcus: 28 times
# Texas Midlands: 16 times
# Comanche: 8 times
# Post: 8 times
#
# ========================================
#
# Movie ID: tt2582802 - Most Common ORGANIZATION Entities:
# Whiplash: 8 times
# Terence Fletcher: 4 times
# Terence: 4 times
# Sean: 4 times
# JVC: 4 times
#
# ========================================
#
# Movie ID: tt2582846 - Most Common ORGANIZATION Entities:
# Frannie: 36 times
# ICU: 16 times
# the Literal Heart: 8 times
# Van Houten's: 8 times
# the "Dutch Tulip Man: 4 times
#
# ========================================
#
# Movie ID: tt2632424 - Most Common ORGANIZATION Entities:
# Klaus: 16 times
# The Vampire Diaries: 4 times
# Elijah (Daniel Gillies: 4 times
#
# ========================================
#
# Movie ID: tt2660888 - Most Common ORGANIZATION Entities:
# Franklin: 28 times
# Krall: 28 times
# Kirk: 20 times
# Enterprise: 12 times
# Teenaxi: 8 times
#
# ========================================
#
# Movie ID: tt2661044 - Most Common ORGANIZATION Entities:
# Wells: 24 times
# Bell: 8 times
# Mt: 4 times
# Spacewalker: 4 times
# Cain: 4 times
#
# ========================================
#
# Movie ID: tt2674426 - Most Common ORGANIZATION Entities:
# Treena: 24 times
# Camilla: 20 times
# Traynors: 20 times
# Nathan: 16 times
# Traynor: 8 times
#
# ========================================
#
# Movie ID: tt2692250 - Most Common ORGANIZATION Entities:
# Tablet: 80 times
# McPhee: 20 times
# Nick: 16 times
# the Museum of Natural History: 12 times
# the British Museum: 12 times
#
# ========================================
#
# Movie ID: tt2713180 - Most Common ORGANIZATION Entities:
# Collier: 140 times
# Fury: 12 times
# US Army: 8 times
# SS: 8 times
# Baker Company: 8 times
#
# ========================================
#
# Movie ID: tt2719848 - Most Common ORGANIZATION Entities:
# Scott: 20 times
# Adventure Consultants: 8 times
# Mountain Madness: 8 times
# Guy Cotter: 4 times
# Base Camp to: 4 times
#
# ========================================
#
# Movie ID: tt2802144 - Most Common ORGANIZATION Entities:
# Eggsy: 116 times
# SIM: 12 times
# Lancelot: 8 times
# Roxy: 8 times
# HIM: 4 times
#
# ========================================
#
# Movie ID: tt2820852 - Most Common ORGANIZATION Entities:
# Shaw: 52 times
# Dom: 32 times
# Hobbs: 32 times
# Elena: 20 times
# Jakande: 20 times
#
# ========================================
#
# Movie ID: tt2848292 - Most Common ORGANIZATION Entities:
# Kommissar: 16 times
# Bumper: 16 times
# Lilly: 8 times
# Snoop: 8 times
# Copenhagen: 8 times
#
# ========================================
#
# Movie ID: tt2872718 - Most Common ORGANIZATION Entities:
# Loder: 12 times
# Video Production News: 8 times
# Channel 6: 4 times
# Channel 2: 4 times
# Frontieri: 4 times
#
# ========================================
#
# Movie ID: tt2872732 - Most Common ORGANIZATION Entities:
# Choi: 4 times
# Caroline: 4 times
# Del Rio: 4 times
#
# ========================================
#
# Movie ID: tt2911666 - Most Common ORGANIZATION Entities:
# Viggo: 68 times
# Marcus: 16 times
# Iosef: 12 times
# the Continental Hotel: 8 times
# Continental: 8 times
#
# ========================================
#
# Movie ID: tt2948356 - Most Common ORGANIZATION Entities:
# Nick: 108 times
# Zootopia: 28 times
# Otterton: 12 times
# Gazelle (Shakira: 8 times
# fox: 8 times
#
# ========================================
#
# Movie ID: tt2975590 - Most Common ORGANIZATION Entities:
# Batman: 36 times
# LexCorp: 8 times
# Finch: 8 times
# Daily Planet: 4 times
# Cyborg: 4 times
#
# ========================================
#
# Movie ID: tt2980516 - Most Common ORGANIZATION Entities:
#
# ========================================
#
# Movie ID: tt3076658 - Most Common ORGANIZATION Entities:
# Bianca: 32 times
# Apollo: 24 times
# Donnie: 12 times
# Apollo Creed: 8 times
# Rocky and Donnie: 8 times
#
# ========================================
#
# Movie ID: tt3079380 - Most Common ORGANIZATION Entities:
# Ford: 72 times
# Cooper: 68 times
# CIA: 28 times
# Crocker: 16 times
# Fine: 12 times
#
# ========================================
#
# Movie ID: tt3152624 - Most Common ORGANIZATION Entities:
# Nikki: 12 times
# LeBron: 8 times
# Amar'e: 8 times
# Mets: 4 times
# the Knick City Dancers: 4 times
#
# ========================================
#
# Movie ID: tt3170832 - Most Common ORGANIZATION Entities:
# Nick: 28 times
# Explorer: 4 times
# Stupid: 4 times
# Time: 4 times
#
# ========================================
#
# Movie ID: tt3183660 - Most Common ORGANIZATION Entities:
# Credence: 36 times
# Modesty: 16 times
# Shaw: 12 times
# Macy: 8 times
# Modesty (Faith Wood-Blagrove: 4 times
#
# ========================================
#
# Movie ID: tt3205802 - Most Common ORGANIZATION Entities:
# Laurel Castillo: 4 times
# Sams: 4 times
# Annelise: 4 times
#
# ========================================
#
# Movie ID: tt3235888 - Most Common ORGANIZATION Entities:
# Paul: 4 times
#
# ========================================
#
# Movie ID: tt3315342 - Most Common ORGANIZATION Entities:
# Logan: 73 times
# Reavers: 40 times
# Pierce: 24 times
# Transigen: 16 times
# the X-Men: 12 times
#
# ========================================
#
# Movie ID: tt3322364 - Most Common ORGANIZATION Entities:
# NFL: 28 times
# CTE: 16 times
# Prema: 12 times
# the Pittsburgh Steelers: 4 times
# Gracie: 4 times
#
# ========================================
#
# Movie ID: tt3332064 - Most Common ORGANIZATION Entities:
# Blackbeard: 36 times
# Nibs: 20 times
# Bishop: 8 times
# the Lambert Home For Boys: 4 times
# Royal Army: 4 times
#
# ========================================
#
# Movie ID: tt3385516 - Most Common ORGANIZATION Entities:
# Nightcrawler: 48 times
# Apocalypse: 48 times
# Scott: 44 times
# Cerebro: 16 times
# Storm: 12 times
#
# ========================================
#
# Movie ID: tt3397884 - Most Common ORGANIZATION Entities:
# CIA: 12 times
# FBI: 8 times
# Delta Force: 8 times
# SWAT: 4 times
# American FBI: 4 times
#
# ========================================
#
# Movie ID: tt3402236 - Most Common ORGANIZATION Entities:
# Arbuthnot: 28 times
# the Orient Express: 12 times
# Debenham: 12 times
# Cassetti: 12 times
# Orient Express: 8 times
#
# ========================================
#
# Movie ID: tt3416742 - Most Common ORGANIZATION Entities:
# Deacon: 28 times
# Nick: 4 times
#
# ========================================
#
# Movie ID: tt3460252 - Most Common ORGANIZATION Entities:
# Minnie: 40 times
# Domergue: 40 times
# Warren: 36 times
# O.B.: 20 times
# Mobray: 16 times
#
# ========================================
#
# Movie ID: tt3464902 - Most Common ORGANIZATION Entities:
# Hotel: 40 times
# the Heartless Woman: 12 times
# the Biscuit Woman: 8 times
# the Nosebleed Woman: 8 times
# the Short-Sighted Woman: 8 times
#
# ========================================
#
# Movie ID: tt3470600 - Most Common ORGANIZATION Entities:
# Nana: 20 times
# Rosita: 16 times
# Lance: 12 times
# Meena: 8 times
# Tori Kelly: 4 times
#
# ========================================
#
# Movie ID: tt3498820 - Most Common ORGANIZATION Entities:
# Falcon: 44 times
# Vision: 28 times
# Bucky: 28 times
# Zemo: 20 times
# Avengers: 16 times
#
# ========================================
#
# Movie ID: tt3501632 - Most Common ORGANIZATION Entities:
# Odin: 40 times
# Hulk: 40 times
# Loki: 28 times
# Surtur: 24 times
# Korg: 12 times
#
# ========================================
#
# Movie ID: tt3521164 - Most Common ORGANIZATION Entities:
# Moana: 56 times
# Tala: 16 times
# Sina: 8 times
# Temuera Morrison: 4 times
# be?Moana: 4 times
#
# ========================================
#
# Movie ID: tt3530002 - Most Common ORGANIZATION Entities:
# Red Bull: 4 times
# FAO Schwartz: 4 times
# N64: 4 times
# Miley: 4 times
# Isaac: 4 times
#
# ========================================
#
# Movie ID: tt3532216 - Most Common ORGANIZATION Entities:
# CIA: 24 times
# Contras: 20 times
# DEA: 16 times
# Pablo Escobar: 8 times
# Seals: 8 times
#
# ========================================
#
# Movie ID: tt3631112 - Most Common ORGANIZATION Entities:
# Scott: 44 times
# XXXXX: 4 times
# Google Images: 4 times
# Time: 4 times
#
# ========================================
#
# Movie ID: tt3640424 - Most Common ORGANIZATION Entities:
# S.O.E.: 4 times
# Hobar: 4 times
# Royal Canadian Air Force: 4 times
# Parisian Marianne Beauséjour: 4 times
# the French Resistance: 4 times
#
# ========================================
#
# Movie ID: tt3647998 - Most Common ORGANIZATION Entities:
# the East India Company: 8 times
#
# ========================================
#
# Movie ID: tt3659388 - Most Common ORGANIZATION Entities:
# NASA: 100 times
# Watney: 44 times
# MAV: 28 times
# Sanders: 12 times
# Purnell: 8 times
#
# ========================================
#
# Movie ID: tt3682448 - Most Common ORGANIZATION Entities:
# CIA: 24 times
# Powers: 12 times
# Gamber: 4 times
# FBI: 4 times
# the Peshawar Air Station: 4 times
#
# ========================================
#
# Movie ID: tt3741834 - Most Common ORGANIZATION Entities:
# Guddu: 24 times
# Calcutta: 20 times
# Shekila: 16 times
# Rawa: 12 times
# Ganestalay: 8 times
#
# ========================================
#
# Movie ID: tt3748528 - Most Common ORGANIZATION Entities:
# Imperial: 8 times
# the Rebel Alliance: 8 times
# Jyn: 4 times
# Krennic: 4 times
# the Ring of Kafrene: 4 times
#
# ========================================
#
# Movie ID: tt3783958 - Most Common ORGANIZATION Entities:
# MIA & SEBASTIAN'S: 12 times
# Warner Bros.: 12 times
# jargon: 8 times
# Lighthouse: 8 times
# CINEMASCOPE: 4 times
#
# ========================================
#
# Movie ID: tt3850590 - Most Common ORGANIZATION Entities:
# Chrissy: 4 times
#
# ========================================
#
# Movie ID: tt3896198 - Most Common ORGANIZATION Entities:
# Guardians: 44 times
# Meredith: 20 times
# Rocket: 20 times
# Sovereign: 12 times
# Ravagers: 12 times
#
# ========================================
#
# Movie ID: tt4016934 - Most Common ORGANIZATION Entities:
# Hideko: 116 times
# Lady Hideko: 12 times
# Sook-Hee: 8 times
# Count: 8 times
# the Lady Hideko: 4 times
#
# ========================================
#
# Movie ID: tt4034228 - Most Common ORGANIZATION Entities:
# Sandy: 56 times
# Patrick: 20 times
# Lees: 8 times
# Minnetonka: 4 times
#
# ========================================
#
# Movie ID: tt4046784 - Most Common ORGANIZATION Entities:
# Gladers: 24 times
# Jorge: 20 times
# WCKD: 20 times
# Cranks: 16 times
# Crank: 16 times
#
# ========================================
#
# Movie ID: tt4263482 - Most Common ORGANIZATION Entities:
# Katherine: 12 times
# Mercy: 12 times
# Jonas: 4 times
# Peek-A-Boo: 4 times
# Witch: 4 times
#
# ========================================
#
# Movie ID: tt4501244 - Most Common ORGANIZATION Entities:
# Facetime: 4 times
# Applebee: 4 times
# Stephanie: 4 times
# Justine (Kaley Cuoco: 4 times
# Barb and Scotty: 4 times
#
# ========================================
#
# Movie ID: tt4550098 - Most Common ORGANIZATION Entities:
# Edward Sheffield: 4 times
# Columbia: 4 times
# Yale: 4 times
# REVENGE: 4 times
#
# ========================================
#
# Movie ID: tt4555426 - Most Common ORGANIZATION Entities:
# Churchill: 40 times
# Halifax: 36 times
# Dunkirk: 24 times
# Parliament: 20 times
# Chamberlain: 16 times
#
# ========================================
#
# Movie ID: tt4574334 - Most Common ORGANIZATION Entities:
# Dustin: 188 times
# Hopper: 184 times
# Lucas: 60 times
# El: 48 times
# Lonnie: 24 times
#
# ========================================
#
# Movie ID: tt4622512 - Most Common ORGANIZATION Entities:
# Billie Jean: 36 times
# Billie Jean's: 12 times
# the Pacific Southwest Open: 4 times
# the U.S. Lawn Tennis Association: 4 times
# Virginia Slims: 4 times
#
# ========================================
#
# Movie ID: tt4649466 - Most Common ORGANIZATION Entities:
# Eggsy: 72 times
# the Glastonbury Music Festival: 8 times
# Saville Row: 4 times
# K: 4 times
# SIM: 4 times
#
# ========================================
#
# Movie ID: tt4651520 - Most Common ORGANIZATION Entities:
# PTA: 24 times
# Kiki: 20 times
# Dylan (Emjay Anthony: 4 times
# Stacy: 4 times
# ISIS: 4 times
#
# ========================================
#
# Movie ID: tt4682786 - Most Common ORGANIZATION Entities:
# Brigitte: 80 times
# Time: 28 times
# Howard: 16 times
# Howards: 4 times
# OmniCorp: 4 times
#
# ========================================
#
# Movie ID: tt4731136 - Most Common ORGANIZATION Entities:
# Lockhart: 52 times
# Pembroke: 20 times
# Volmer: 16 times
# Caretaker: 8 times
# SEC: 4 times
#
# ========================================
#
# Movie ID: tt4765284 - Most Common ORGANIZATION Entities:
# Lilly: 4 times
# USO: 4 times
# Stacie: 4 times
# Fergus: 4 times
# Pimp-Lo: 2 times
#
# ========================================
#
# Movie ID: tt4846340 - Most Common ORGANIZATION Entities:
# NASA: 48 times
# Katherine: 32 times
# IBM: 32 times
# Vivian: 20 times
# FORTRAN: 20 times
#
# ========================================
#
# Movie ID: tt4925292 - Most Common ORGANIZATION Entities:
# Miguel: 4 times
# Lucas Hedges: 4 times
# Julie's: 4 times
# NY: 4 times
# University of Davis: 4 times
#
# ========================================
#
# Movie ID: tt4972582 - Most Common ORGANIZATION Entities:
# Skype: 4 times
# Orwell: 4 times
#
# ========================================
#
# Movie ID: tt4975722 - Most Common ORGANIZATION Entities:
# Chiron: 232 times
# ChironSkipping: 4 times
# BlackThe: 4 times
# black-American Chiron: 4 times
#
# ========================================
#
# Movie ID: tt5013056 - Most Common ORGANIZATION Entities:
# Dunkirk: 20 times
# Channel: 4 times
# Mole: 4 times
# the Royal Navy: 4 times
# Red Cross: 4 times
#
# ========================================
#
# Movie ID: tt5027774 - Most Common ORGANIZATION Entities:
# Dixon: 28 times
# Mildred: 28 times
# Red: 12 times
# Academy Award: 8 times
# Red Welby: 4 times
#
# ========================================
#
# Movie ID: tt5052448 - Most Common ORGANIZATION Entities:
# TSA: 8 times
# TING TING TING: 8 times
# MMA: 4 times
#
# ========================================
#
# Movie ID: tt5074352 - Most Common ORGANIZATION Entities:
# Omkar: 12 times
# NSA: 8 times
# Spoiler: 4 times
# Young Omkar Ritvik Sahore / Elder: 4 times
# the True Story: 4 times
#
# ========================================
#
# Movie ID: tt5109784 - Most Common ORGANIZATION Entities:
# Oldest Son: 12 times
# Woman: 8 times
# Herald: 8 times
# The Herald: 4 times
# SWAT: 4 times
#
# ========================================
#
# Movie ID: tt5311514 - Most Common ORGANIZATION Entities:
# Taki: 252 times
# Mitsuha: 128 times
# Itomori: 28 times
# Takis: 8 times
# Mitsuha Miyamizu: 4 times
#
# ========================================
#
# Movie ID: tt5362988 - Most Common ORGANIZATION Entities:
# FBI: 16 times
# Cory: 12 times
# Wyoming Wilderness: 4 times
# Wildlife Department: 4 times
# Martin: 4 times
#
# ========================================
#
# Movie ID: tt5439796 - Most Common ORGANIZATION Entities:
# Speedway: 20 times
# Sadie: 12 times
# the Charlotte Motor Speedway: 8 times
# the Motor Speedway: 4 times
# Moody (David Denman: 4 times
#
# ========================================
#
# Movie ID: tt5519340 - Most Common ORGANIZATION Entities:
# Jakoby: 144 times
# Ward: 88 times
# Tikka: 36 times
# Poison: 12 times
# FBI: 8 times
#
# ========================================
#
# Movie ID: tt5580036 - Most Common ORGANIZATION Entities:
# LaVona: 28 times
# Paul Walter Hauser: 2 times
# MN: 2 times
# Dody Teachman: 2 times
# Nancy: 2 times
#
# ========================================
#
# Movie ID: tt5580390 - Most Common ORGANIZATION Entities:
# Asset: 32 times
# Brewster: 8 times
# the Occam Aerospace Research Center: 4 times
# Morgan Kelly: 4 times
# Fox Searchlight Pictures: 4 times
#
# ========================================
#
# Movie ID: tt5726616 - Most Common ORGANIZATION Entities:
# Bergamo: 8 times
# Greco-Roman: 4 times
# Sony Pictures Classics: 4 times
#
# ========================================

# %%
import spacy
from collections import Counter
import pandas as pd

# Load spaCy model
nlp = spacy.load("en_core_web_sm")  

# POS Tagging on 'whole_review' column
pos_tags_by_movie = {}
for movie_id, text in sampled_data.groupby("movie_id")["whole_review"].apply(lambda x: " ".join(x)).items():
    doc = nlp(text)  
    pos_tags = [(token.text, token.pos_) for token in doc]  
    pos_counts = Counter(pos_tags)  
    pos_tags_by_movie[movie_id] = pos_counts

# NER for PERSON and ORGANIZATION in 'whole_plot' column
person_entities_by_movie = {}
organization_entities_by_movie = {}

for movie_id, text in sampled_data.groupby("movie_id")["whole_plot"].apply(lambda x: " ".join(x)).items():
    doc = nlp(text)  
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
    organization_entities = [ent.text for ent in doc.ents if ent.label_ == "ORG"]

    # Count occurrences
    person_counts = Counter(person_entities)
    organization_counts = Counter(organization_entities)

    # Store results
    person_entities_by_movie[movie_id] = person_counts
    organization_entities_by_movie[movie_id] = organization_counts

# Display Results
# POS Tagging
print("POS Tagging Results:")
for movie_id, pos_counts in pos_tags_by_movie.items():
    print(f"\nMovie ID: {movie_id} - Most Common POS Tags:")
    for (word, pos), count in pos_counts.most_common(10):  
        print(f"{word} ({pos}): {count} times")
    print("\n" + "="*40)

# PERSON Entities
print("\nPERSON Entity Results:")
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"\nMovie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):
        print(f"{entity}: {count} times")
    print("\n" + "="*40)

# ORGANIZATION Entities
print("\nORGANIZATION Entity Results:")
for movie_id, organization_counts in organization_entities_by_movie.items():
    print(f"\nMovie ID: {movie_id} - Most Common ORGANIZATION Entities:")
    for entity, count in organization_counts.most_common(5):
        print(f"{entity}: {count} times")
    print("\n" + "="*40)

# %% [markdown]
# ##### The small model gives accurate results but we may also use the large one in a similar manner - for runtime purposes I will not run the following cells.

# %%
#!python -m spacy download en_core_web_lg

# %%
'''
# Load spaCy model
nlp = spacy.load("en_core_web_lg")  # Changed to a larger model for better accuracy

# Group reviews by movie_id
grouped_reviews = sampled_data.groupby("movie_id")["plot_summary"].apply(lambda x: " ".join(x))

# Dictionary to store PERSON entity counts per movie
person_entities_by_movie = {}

# Process each movie's reviews separately
for movie_id, text in grouped_reviews.items():
    doc = nlp(text)  # Apply spaCy NER directly without tokenization
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]  # Extract only PERSON entities
    
    # Count occurrences of each PERSON entity
    person_counts = Counter(person_entities)
    
    # Store results
    person_entities_by_movie[movie_id] = person_counts

# Print the most common PERSON entities per movie
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"Movie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):  # Top 5 most common PERSON names
        print(f"{entity}: {count} times")
    print("\n" + "="*40 + "\n")  # Separator for readability
'''

# %%
#remove starting and trailing white spaces from strings
columns_to_strip = ['movie_id','plot_summary','duration','genre','release_date','plot_synopsis',
                            'review_date','user_id','review_text','review_summary']
sampled_data[columns_to_strip] = original_data[columns_to_strip].apply(lambda col: col.str.strip())

# %%
# Check for missing values
sampled_data.isna().any()

# %% [markdown]
# There are no missing values.

# %%
# Check for empty strings
(sampled_data == '').sum()

# %% [markdown]
# There are no empty strings.

# %%
genre = sampled_data['genre']
genre

# %%
# Check if every element of genre feature is a string in order to make them lists
sampled_data['genre'].apply(lambda x: isinstance(x, str)).all()

# %%
# split the genres and remove the "[" "]" characters
sampled_data["genre"] = sampled_data["genre"].str.split(",")

sampled_data_exploded = sampled_data.explode('genre')
sampled_data_exploded['genre'] = sampled_data_exploded['genre'].str.replace(r"[\[\]' ]", "", regex=True)

# Apply one-hot encoding using get_dummies
sampled_data_encoded = pd.get_dummies(sampled_data_exploded['genre'])

# merge with the original dataframe
sampled_data_final = sampled_data.merge(sampled_data_encoded.groupby(sampled_data_exploded.index).sum(), left_index= True, right_index = True)

#  Drop the original 'genre' column if it's no longer needed
sampled_data_final = sampled_data_final.drop(columns=['genre'])
sampled_data = sampled_data_final

sampled_data

# %%
sampled_data.columns

# %% [markdown]
# The number of records does not change.

# %%
# Convert duration to minutes

def convert_to_minutes(duration):
    parts = duration.replace("h", "").replace("min", "").strip().split()
    
    hours = int(parts[0]) if "h" in duration else 0
    minutes = int(parts[1]) if len(parts) > 1 else 0
    
    return hours * 60 + minutes

sampled_data['duration_minutes'] = sampled_data['duration'].apply(convert_to_minutes)
sampled_data

# %%
sampled_data.columns

# %%
# Rename rating_x, rating_y
sampled_data.rename(columns={'rating_x': 'IMDB_rating', 'rating_y': 'user_rating'}, inplace=True)

# %%
# Create new features that only have the year of release and the year of the review

sampled_data['release_year'] = sampled_data['release_date'].str[:4]
sampled_data['review_year'] = sampled_data['review_date'].str[-4:]

sampled_data

# %%
# Convert True to 1 and False to 0 in the response variable
sampled_data['is_spoiler'] = sampled_data['is_spoiler'].astype(int)
sampled_data['is_spoiler']

# %% [markdown]
# ### Text Pre-processing

# %%
# Create new dataframe for spoiler and not spoiler class
df_spoiler = sampled_data[sampled_data['is_spoiler'] == 1]
df_not_spoiler = sampled_data[sampled_data['is_spoiler'] == 0]

# %% [markdown]
# #### Uncontract

# %%
# Define the uncontract function which converts short forms to the full word. For example: 'isn't' to 'is not'.
def uncontract(text):
    text = re.sub(r"(\b)([Aa]re|[Cc]ould|[Dd]id|[Dd]oes|[Dd]o|[Hh]ad|[Hh]as|[Hh]ave|[Ii]s|[Mm]ight|[Mm]ust|[Ss]hould|[Ww]ere|[Ww]ould)n't", r"\1\2 not", text)
    text = re.sub(r"(\b)([Hh]e|[Ii]|[Ss]he|[Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Yy]ou)'ll", r"\1\2 will", text)
    text = re.sub(r"(\b)([Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Yy]ou)'re", r"\1\2 are", text)
    text = re.sub(r"(\b)([Ii]|[Ss]hould|[Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Ww]ould|[Yy]ou)'ve", r"\1\2 have", text)

    text = re.sub(r"(\b)([Cc]a)n't", r"\1\2n not", text)
    text = re.sub(r"(\b)([Ii])'m", r"\1\2 am", text)
    text = re.sub(r"(\b)([Ll]et)'s", r"\1\2 us", text)
    text = re.sub(r"(\b)([Tt]here)'s", r"\1\2 is", text)
    text = re.sub(r"(\b)([Ww])on't", r"\1\2ill not", text)
    text = re.sub(r"(\b)([Ss])han't", r"\1\2hall not", text)
    text = re.sub(r"(\b)([Yy])(?:'all|a'll)", r"\1\2ou all", text)

    return text

# %%
sampled_data['review_text'] = [uncontract(t) for t in sampled_data['review_text']]
sampled_data['review_summary'] = [uncontract(t) for t in sampled_data['review_summary']]

# %%
# Create new dataframe for spoiler and not spoiler class
df_spoiler = sampled_data[sampled_data['is_spoiler'] == 1]
df_not_spoiler = sampled_data[sampled_data['is_spoiler'] == 0]

# %% [markdown]
# #### Tokenization

# %%
spoiler_tokens = [word_tokenize(t) for t in df_spoiler['whole_review']]

not_spoiler_tokens = [word_tokenize(t) for t in df_not_spoiler['whole_review']]

# %%
# Convert to a single list
spoiler_tokens = list(itertools.chain.from_iterable(spoiler_tokens))

not_spoiler_tokens = list(itertools.chain.from_iterable(not_spoiler_tokens))

# %%
# Check the number of unique tokens
print('Number of Unique Spoiler Tokens:', len(set(spoiler_tokens)))
print('Number of Unique Non-spoiler Tokens:', len(set(not_spoiler_tokens)))
# Out:
# Number of Unique Spoiler Tokens: 50505
# Number of Unique Non-spoiler Tokens: 40262

# %%
# Check the most frequent tokens for Spoilers and Non-spoilers
print('Spoiler Tokens:\n')

for t, f in Counter(spoiler_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
#------------------------------------
print('Non Spoiler Tokens:\n')

for t, f in Counter(not_spoiler_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Tokens:
#
# the                       46382
# ,                         42739
# .                         34238
# and                       25402
# a                         23422
# to                        21460
# of                        21416
# is                        17486
# in                        13383
# that                      11254
#
# Non Spoiler Tokens:
#
# the                       32025
# ,                         30217
# .                         25088
# and                       18750
# a                         16877
# of                        15589
# to                        14373
# is                        13083
# I                         9328
# in                        9128

# %%
def dimensionality_info(spoilertext ,nonspoilertext):

    print('Number of Spoiler Tokens:    ', len(spoilertext),     '/', len(spoiler_tokens))
    print('Number of Non Spoiler Tokens:', len(nonspoilertext), '/', len(not_spoiler_tokens))

    print()

    print('Number of Unique Spoiler Tokens:    ', len(set(spoilertext)),     '/', len(spoiler_tokens))
    print('Number of Unique Non Spoiler Tokens:', len(set(nonspoilertext)), '/', len(not_spoiler_tokens))

    print()
    print('|V|/|Tokens|:            ', len(set(spoilertext)) / len(set(spoiler_tokens)))
    print('|V|/|Tokens|:            ', len(set(nonspoilertext)) / len(set(not_spoiler_tokens)))

# %% [markdown]
# We observe that the most frequent tokens are stopwords. For that reason we will remvove them to get more informative result.

# %% [markdown]
# #### Remove Punctuation and Stopwords

# %% [markdown]
# ##### Remove Punctuation

# %%
spoiler_punctuations = list(
    filter(
        lambda t: all(c.isdigit() or c in string.punctuation for c in t),
        spoiler_tokens
    )
)
#--------------------------------------
non_spoiler_punctuations = list(
    filter(
        lambda t: all(c.isdigit() or c in string.punctuation for c in t),
        not_spoiler_tokens
    )
)

# %%
spoiler_punctuations = set(spoiler_punctuations)

non_spoiler_punctuations = set(non_spoiler_punctuations)

# %%
# Remove punctuation
spoiler_clean_tokens = [t for t in spoiler_tokens if t not in spoiler_punctuations]

non_spoiler_clean_tokens = [t for t in not_spoiler_tokens if t not in non_spoiler_punctuations]

# %% [markdown]
# ##### Remove Stopwords

# %%
stop_word_regex = '|'.join(['^{}$'.format(s) for s in stopwords.words('english')])

stop_word_regex = re.compile(stop_word_regex)

# %%
spoiler_stop_words = list(filter(stop_word_regex.match, spoiler_clean_tokens))

non_spoiler_stop_words = list(filter(stop_word_regex.match, non_spoiler_clean_tokens))
#----------------------------------------------------
spoiler_stop_words = set(spoiler_stop_words)

non_spoiler_stop_words = set(non_spoiler_stop_words)

# %%
# Remove stopwords
spoiler_clean_tokens = [t for t in spoiler_clean_tokens if t not in spoiler_stop_words]

non_spoiler_clean_tokens = [t for t in non_spoiler_clean_tokens if t not in non_spoiler_stop_words]

# %% [markdown]
# Check the most frequent tokens after removing punctuation and stopwords.

# %%
# Check again the most frequent tokens for Spoilers and Non-spoilers
print('Clean Spoiler Tokens:\n')

for t, f in Counter(spoiler_clean_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
#------------------------------------
print('Clean Non Spoiler Tokens:\n')

for t, f in Counter(non_spoiler_clean_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Clean Spoiler Tokens:
#
# I                         10988
# 's                        9686
# movie                     6808
# The                       5916
# film                      5624
# n't                       4986
# one                       3203
# like                      2896
# It                        2405
# good                      2063
#
# Clean Non Spoiler Tokens:
#
# I                         9328
# 's                        6743
# movie                     6358
# film                      4835
# The                       4344
# n't                       3787
# one                       2588
# like                      2148
# It                        2076
# good                      1843

# %% [markdown]
# We can observe that the possesive s does not give much information. Therefore we decided to consider it as a stopword and remove it.

# %%
spoiler_clean_tokens = [t for t in spoiler_clean_tokens if t != "'s"]

non_spoiler_clean_tokens = [t for t in non_spoiler_clean_tokens if t != "'s"]

# %% [markdown]
# #### Normalization

# %% [markdown]
# ##### Lowercasing

# %%
spoiler_clean_tokens     = [t.lower() for t in spoiler_clean_tokens]

non_spoiler_clean_tokens     = [t.lower() for t in non_spoiler_clean_tokens]

# %% [markdown]
# ##### Stemming

# %%
ps = PorterStemmer()

stems_spoiler = [ps.stem(t) for t in spoiler_clean_tokens]
stems_non_spoiler = [ps.stem(t) for t in non_spoiler_clean_tokens]

# %%
print('Spoiler Stems:\n')

for t, f in Counter(stems_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
#-----------------------------
print('Non Spoiler Stems:\n')

for t, f in Counter(stems_non_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Stems:
#
# i                         10989
# movi                      8033
# film                      6683
# the                       6046
# n't                       5004
# one                       3643
# like                      3454
# charact                   2712
# it                        2548
# time                      2453
#
# Non Spoiler Stems:
#
# i                         9329
# movi                      7570
# film                      5814
# the                       4448
# n't                       3799
# one                       2917
# like                      2581
# it                        2175
# charact                   2047
# good                      1966

# %%
dimensionality_info(stems_spoiler, stems_non_spoiler)
# Out:
# Number of Spoiler Tokens:     506174 / 1021153
# Number of Non Spoiler Tokens: 364236 / 730968
#
# Number of Unique Spoiler Tokens:     33314 / 1021153
# Number of Unique Non Spoiler Tokens: 26725 / 730968
#
# |V|/|Tokens|:             0.6596178596178596
# |V|/|Tokens|:             0.6637772589538523

# %% [markdown]
# ##### Lemmatizing

# %%
lemmatizer = WordNetLemmatizer()

lemmas_spoiler = [lemmatizer.lemmatize(t) for t in spoiler_clean_tokens]
lemmas_non_spoiler = [lemmatizer.lemmatize(t) for t in non_spoiler_clean_tokens]

# %%
print('Spoiler Lemmas:\n')

for t, f in Counter(lemmas_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
#-----------------------------
print('Non Spoiler Lemmas:\n')

for t, f in Counter(lemmas_non_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Lemmas:
#
# i                         10988
# movie                     8033
# film                      6599
# the                       6046
# n't                       5004
# one                       3643
# like                      3082
# character                 2712
# it                        2548
# time                      2428
#
# Non Spoiler Lemmas:
#
# i                         9328
# movie                     7570
# film                      5718
# the                       4448
# n't                       3799
# one                       2917
# like                      2290
# it                        2175
# character                 2047
# good                      1952

# %%
dimensionality_info(lemmas_spoiler, lemmas_non_spoiler)
# Out:
# Number of Spoiler Tokens:     506174 / 1021153
# Number of Non Spoiler Tokens: 364236 / 730968
#
# Number of Unique Spoiler Tokens:     40430 / 1021153
# Number of Unique Non Spoiler Tokens: 32250 / 730968
#
# |V|/|Tokens|:             0.8005148005148005
# |V|/|Tokens|:             0.8010034275495505

# %%
#Many of the spoiler and non-spoiler most common words are the same - therefore we can try to isolate the 
#most common words that appear *only* in spoiler reviews and *only* in negative reviews

# %%
##############################################
# Define an informative function to view the #
# information of frequencies between the two #
# sets of tokens passed as input.            #
##############################################

def comparison_info(spoiler, nonspoiler, desc=None, n=10):

    print(f'{desc.capitalize()} only in Spoiler reviews:')
    print()

    spoilerfreq = dict(Counter(spoiler))
    nonspoilerfreq = dict(Counter(nonspoiler))

    onlyspoiler = set(spoilerfreq).difference(set(nonspoilerfreq))
    onlynonspoiler = set(nonspoilerfreq).difference(set(spoilerfreq))
    common   = set(spoilerfreq).intersection(set(nonspoilerfreq))

    for u in sorted(onlyspoiler, key=lambda t: spoilerfreq[t], reverse=True)[:n]: print('- {0:35} {1}'.format(u, spoilerfreq[u]))

    print()
    print(f'{desc.capitalize()} only in Non-Spoiler Reviews:')
    print()

    for u in sorted(onlynonspoiler, key=lambda t: nonspoilerfreq[t], reverse=True)[:n]: print('- {0:35} {1}'.format(u, nonspoilerfreq[u]))

    print()
    print(f'{desc.capitalize()} common in Spoiler and Non spoiler reviews:')
    print()

    print('{0:37} {1:10} {2:10}'.format('Token', 'Spoiler', 'Non Spoiler'))
    print('------------------------------------------------------------')

    for u in sorted(common, key=lambda t: spoilerfreq[t] + nonspoilerfreq[t], reverse=True)[:n]:

        print('- {0:35} {1:<10} {2:<10}'.format(u, spoilerfreq[u], nonspoilerfreq[u]))

# %%
comparison_info(
  lemmas_spoiler,
  lemmas_non_spoiler,
  desc = 'Lemmas',
  n    = 10
)
# Out:
# Lemmas only in Spoiler reviews:
#
# - dir                                 30
# - edmond                              26
# - ant                                 25
# - sheeta                              21
# - pazu                                19
# - backdraft                           19
# - atticus                             18
# - susanna                             17
# - nzt                                 16
# - alvy                                16
#
# Lemmas only in Non-Spoiler Reviews:
#
# - algren                              15
# - spiderwick                          12
# - harding                             11
# - ivy                                 10
# - shu                                 10
# - percy                               10
# - feig                                9
# - drillbit                            9
# - katsumoto                           9
# - tadashi                             9
#
# Lemmas common in Spoiler and Non spoiler reviews:
#
# Token                                 Spoiler    Non Spoiler
# ------------------------------------------------------------
# - i                                   10988      9328
# - movie                               8033       7570
# - film                                6599       5718
# - the                                 6046       4448
# - n't                                 5004       3799
# - one                                 3643       2917
# - like                                3082       2290
# - character                           2712       2047
# - it                                  2548       2175
# - time                                2428       1874

# %% [markdown]
# Comment: mallon ta results pano ennen toso useful : perhaps removing ALL common words in both spoiler and non spoiler is a bit harsh and removes way too many words/ much info.
#
# Another approach we can follow is:, we remove the top 10 common in both lemmas (ie movie, a, film, the, i, good, great etc. since they dont give much information on whether a review contains a spoiler or not.
#
# After doing so we can check the results and filter more words out if needed.
