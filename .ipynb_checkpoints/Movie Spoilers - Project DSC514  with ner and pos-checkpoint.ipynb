# %% [markdown]
# # Detection of Movie Spoilers in Reviews

# %% [markdown]
# ### ***Import essential libraries***

# %%
import pandas as pd
import numpy as np
import re, string, nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import itertools
import spacy
from collections import Counter
from nltk.stem import WordNetLemmatizer


nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\evich\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ### Understanding the data

# %% [markdown]
# Apories:
# 1. what is rating_x, rating_y IMDB???
# 2. maybe convert duration to minutes would be better to compare

# %%
# Load the dataset
original_data = pd.read_csv('movie_spoiler_sample.csv')

# %%
# First view of the dataset
original_data.head(5)
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0318649  Master explorer and former US Navy Seal Dirk P...   2h 4min
# 1  tt0803096  When the world of the Orcs of Draenor is being...   2h 3min
# 2  tt0425112  Top London cop, PC Nicholas Angel is good. Too...   2h 1min
# 3  tt0327056  In the summer of 1975 in a neighborhood in Bos...  2h 18min
# 4  tt0259711  Incarcerated and charged with murder, David Aa...  2h 16min
#
#                                 genre  rating_x release_date  \
# 0   ['Action', 'Adventure', 'Comedy']       6.0   2005-04-08
# 1  ['Action', 'Adventure', 'Fantasy']       6.9   2016-06-10
# 2                ['Action', 'Comedy']       7.9   2007-04-20
# 3       ['Crime', 'Drama', 'Mystery']       8.0   2003-10-15
# 4   ['Fantasy', 'Mystery', 'Romance']       6.9   2001-12-14
#
#                                        plot_synopsis      review_date  \
# 0  The film begins with a prologue set in Richmon...      27 May 2005
# 1  For ages in the region of Middle Earth, humans...     20 June 2016
# 2  Nicholas Angel (Simon Pegg) is undoubtedly Lon...     11 June 2007
# 3  Three young boys, all the best of friends, are...  5 November 2015
# 4  David Aames (Tom Cruise) drives to work, he fi...   12 August 2016
#
#       user_id  is_spoiler                                        review_text  \
# 0   ur3270789       False  The film starts in the Richmond battle (1865) ...
# 1  ur47788388        True  I saw the movie with six friends and we all lo...
# 2  ur14440242        True  I enjoyed this movie very much, but it being l...
# 3  ur63623011       False  What you get here is no more than Clint eastwo...
# 4   ur2781970       False  I think the first time I saw this movie, I did...
#
#    rating_y                                     review_summary
# 0         7  Splendid adventure film with mesmerizing deser...
# 1        10                   Epic movie for fans and non fans
# 2         8                    once again a funny British film
# 3         1               For he made a 'plot twist' out of it
# 4        10                     As brilliant as I recalled it!

# %% [markdown]
# The dataset is very large and run time error occurs therefore we decided to use undersampling to obtain a balanced sample of the data.

# %%
# Check the count per movie id
original_data['movie_id'].value_counts()
# Out:
# movie_id
# tt0468569    643
# tt0111161    565
# tt0167260    328
# tt0137523    272
# tt0110912    265
#             ...
# tt0383534      3
# tt0110989      2
# tt5580036      2
# tt0107719      1
# tt0374887      1
# Name: count, Length: 1339, dtype: int64

# %%
# Check how many unique movies we have
len(original_data['movie_id'].value_counts())
# Out:
# 1339

# %% [markdown]
# For the above reason we decided to take a sample of at most 4 reviews per movie (or less if they don't have enough reviews).

# %%
# Sample each movie's reviews based on the given criteria
sampled_data = original_data.groupby('movie_id', group_keys=False, as_index=False).apply(
    lambda movie_df: movie_df if len(movie_df) <= 4 else pd.concat([
        movie_df[movie_df['is_spoiler'] == True].sample(n=min(2, len(movie_df[movie_df['is_spoiler'] == True])), random_state=42),
        movie_df[movie_df['is_spoiler'] == False].sample(n=min(2, len(movie_df[movie_df['is_spoiler'] == False])), random_state=42)
    ])
).reset_index(drop=True)

sampled_data.head()
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 1  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 2  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 3  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 4  tt0017136  Sometime in the future, the city of Metropolis...  2h 33min
#
#                               genre  rating_x release_date  \
# 0  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 1  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 2  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 3  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 4               ['Drama', 'Sci-Fi']       8.3   1927-03-13
#
#                                        plot_synopsis      review_date  \
# 0  It is in the middle of the Gold Rush. A Lone P...  1 February 2006
# 1  It is in the middle of the Gold Rush. A Lone P...   11 August 2005
# 2  It is in the middle of the Gold Rush. A Lone P...     22 June 2000
# 3  It is in the middle of the Gold Rush. A Lone P...     9 March 2009
# 4  The film is set in the year 2026, in the extra...     7 March 2015
#
#       user_id  is_spoiler                                        review_text  \
# 0   ur5945598        True  Oh where can I start on why alleged comedians ...
# 1   ur5805910        True  We follow "the little fellow" (Chaplin), in hi...
# 2   ur0773000       False  I recently saw this movie with a live orchestr...
# 3   ur0361658       False  The Gold Rush (1925) was a big undertaking for...
# 4  ur13977076        True  This sci-fi classic is set in a future where t...
#
#    rating_y                                     review_summary
# 0        10                        Chaplin strikes comic gold!
# 1        10          Chaplin's delightful bonhomie & innocence
# 2         9  As fresh, funny, and moving as the day it was ...
# 3        10       The Cinema of Charles Chaplin: The Gold Rush
# 4        10                          A science fiction classic

# %%
# Number of records and features for the dataset
sampled_data.shape
# Out:
# (5335, 13)

# %%
# Check if the sample is balanced
sampled_data['is_spoiler'].value_counts()
# Out:
# is_spoiler
# False    2677
# True     2658
# Name: count, dtype: int64

# %% [markdown]
# The target variable is balanced.

# %%
sampled_data['whole_review'] = sampled_data['review_text'] + sampled_data['review_summary']

# %%
# View the columns of the dataset
sampled_data.columns
# Out:
# Index(['movie_id', 'plot_summary', 'duration', 'genre', 'rating_x',
#        'release_date', 'plot_synopsis', 'review_date', 'user_id', 'is_spoiler',
#        'review_text', 'rating_y', 'review_summary', 'whole_review'],
#       dtype='object')

# %%
sampled_data['whole_plot'] = sampled_data['plot_synopsis'] + sampled_data['plot_summary']

# %% [markdown]
# The target variable is balanced.

# %%
# Check for duplicated records
sampled_data.duplicated().any()
# Out:
# False

# %% [markdown]
# There are no duplicated records.

# %%
# Check the data types
sampled_data.dtypes
# Out:
# movie_id           object
# plot_summary       object
# duration           object
# genre              object
# rating_x          float64
# release_date       object
# plot_synopsis      object
# review_date        object
# user_id            object
# is_spoiler           bool
# review_text        object
# rating_y            int64
# review_summary     object
# whole_review       object
# whole_plot         object
# dtype: object

# %%
# Save the sampled data as a csv
sampled_data.to_csv("sampled_data.csv", index=False)

# %% [markdown]
# ### Named entity Recognition on the plot synopsis and review to find the main characters

# %%
#This must be run every time before NER, we may put this in the beginning of the notebook
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 508.0 kB/s eta 0:00:25
#      - ------------------------------------- 0.5/12.8 MB 508.0 kB/s eta 0:00:25
#      -- ------------------------------------ 0.8/12.8 MB 532.3 kB/s eta 0:00:23
#      -- ------------------------------------ 0.8/12.8 MB 532.3 kB/s eta 0:00:23
#      --- ----------------------------------- 1.0/12.8 MB 508.4 kB/s eta 0:00:24
#      --- ----------------------------------- 1.0/12.8 MB 508.4 kB/s eta 0:00:24
#      --- ----------------------------------- 1.0/12.8 MB 508.4 kB/s eta 0:00:24
#      --- ----------------------------------- 1.3/12.8 MB 508.3 kB/s eta 0:00:23
#      --- ----------------------------------- 1.3/12.8 MB 508.3 kB/s eta 0:00:23
#      --- ----------------------------------- 1.3/12.8 MB 508.3 kB/s eta 0:00:23
#      ---- ---------------------------------- 1.6/12.8 MB 505.3 kB/s eta 0:00:23
#      ---- ---------------------------------- 1.6/12.8 MB 505.3 kB/s eta 0:00:23
#      ---- ---------------------------------- 1.6/12.8 MB 505.3 kB/s eta 0:00:23
#      ----- --------------------------------- 1.8/12.8 MB 486.2 kB/s eta 0:00:23
#      ----- --------------------------------- 1.8/12.8 MB 486.2 kB/s eta 0:00:23
#      ------ -------------------------------- 2.1/12.8 MB 487.3 kB/s eta 0:00:22
#      ------ -------------------------------- 2.1/12.8 MB 487.3 kB/s eta 0:00:22
#      ------ -------------------------------- 2.1/12.8 MB 487.3 kB/s eta 0:00:22
#      ------- ------------------------------- 2.4/12.8 MB 486.2 kB/s eta 0:00:22
#      ------- ------------------------------- 2.4/12.8 MB 486.2 kB/s eta 0:00:22
#      ------- ------------------------------- 2.6/12.8 MB 488.6 kB/s eta 0:00:21
#      ------- ------------------------------- 2.6/12.8 MB 488.6 kB/s eta 0:00:21
#      ------- ------------------------------- 2.6/12.8 MB 488.6 kB/s eta 0:00:21
#      -------- ------------------------------ 2.9/12.8 MB 477.9 kB/s eta 0:00:21
#      -------- ------------------------------ 2.9/12.8 MB 477.9 kB/s eta 0:00:21
#      -------- ------------------------------ 2.9/12.8 MB 477.9 kB/s eta 0:00:21
#      -------- ------------------------------ 2.9/12.8 MB 477.9 kB/s eta 0:00:21
#      --------- ----------------------------- 3.1/12.8 MB 467.2 kB/s eta 0:00:21
#      --------- ----------------------------- 3.1/12.8 MB 467.2 kB/s eta 0:00:21
#      ---------- ---------------------------- 3.4/12.8 MB 466.0 kB/s eta 0:00:21
#      ---------- ---------------------------- 3.4/12.8 MB 466.0 kB/s eta 0:00:21
#      ---------- ---------------------------- 3.4/12.8 MB 466.0 kB/s eta 0:00:21
#      ----------- --------------------------- 3.7/12.8 MB 467.0 kB/s eta 0:00:20
#      ----------- --------------------------- 3.7/12.8 MB 467.0 kB/s eta 0:00:20
#      ----------- --------------------------- 3.7/12.8 MB 467.0 kB/s eta 0:00:20
#      ----------- --------------------------- 3.9/12.8 MB 467.9 kB/s eta 0:00:19
#      ----------- --------------------------- 3.9/12.8 MB 467.9 kB/s eta 0:00:19
#      ------------ -------------------------- 4.2/12.8 MB 465.1 kB/s eta 0:00:19
#      ------------ -------------------------- 4.2/12.8 MB 465.1 kB/s eta 0:00:19
#      ------------ -------------------------- 4.2/12.8 MB 465.1 kB/s eta 0:00:19
#      ------------ -------------------------- 4.2/12.8 MB 465.1 kB/s eta 0:00:19
#      ------------- ------------------------- 4.5/12.8 MB 456.5 kB/s eta 0:00:19
#      ------------- ------------------------- 4.5/12.8 MB 456.5 kB/s eta 0:00:19
#      ------------- ------------------------- 4.5/12.8 MB 456.5 kB/s eta 0:00:19
#      ------------- ------------------------- 4.5/12.8 MB 456.5 kB/s eta 0:00:19
#      -------------- ------------------------ 4.7/12.8 MB 443.6 kB/s eta 0:00:19
#      -------------- ------------------------ 4.7/12.8 MB 443.6 kB/s eta 0:00:19
#      -------------- ------------------------ 4.7/12.8 MB 443.6 kB/s eta 0:00:19
#      -------------- ------------------------ 4.7/12.8 MB 443.6 kB/s eta 0:00:19
#      -------------- ------------------------ 4.7/12.8 MB 443.6 kB/s eta 0:00:19
#      -------------- ------------------------ 4.7/12.8 MB 443.6 kB/s eta 0:00:19
#      --------------- ----------------------- 5.0/12.8 MB 421.8 kB/s eta 0:00:19
#      --------------- ----------------------- 5.0/12.8 MB 421.8 kB/s eta 0:00:19
#      --------------- ----------------------- 5.0/12.8 MB 421.8 kB/s eta 0:00:19
#      --------------- ----------------------- 5.2/12.8 MB 415.1 kB/s eta 0:00:19
#      --------------- ----------------------- 5.2/12.8 MB 415.1 kB/s eta 0:00:19
#      --------------- ----------------------- 5.2/12.8 MB 415.1 kB/s eta 0:00:19
#      --------------- ----------------------- 5.2/12.8 MB 415.1 kB/s eta 0:00:19
#      --------------- ----------------------- 5.2/12.8 MB 415.1 kB/s eta 0:00:19
#      --------------- ----------------------- 5.2/12.8 MB 415.1 kB/s eta 0:00:19
#      ---------------- ---------------------- 5.5/12.8 MB 399.0 kB/s eta 0:00:19
#      ---------------- ---------------------- 5.5/12.8 MB 399.0 kB/s eta 0:00:19
#      ---------------- ---------------------- 5.5/12.8 MB 399.0 kB/s eta 0:00:19
#      ---------------- ---------------------- 5.5/12.8 MB 399.0 kB/s eta 0:00:19
#      ---------------- ---------------------- 5.5/12.8 MB 399.0 kB/s eta 0:00:19
#      ----------------- --------------------- 5.8/12.8 MB 387.2 kB/s eta 0:00:19
#      ----------------- --------------------- 5.8/12.8 MB 387.2 kB/s eta 0:00:19
#      ------------------ -------------------- 6.0/12.8 MB 391.8 kB/s eta 0:00:18
#      ------------------ -------------------- 6.0/12.8 MB 391.8 kB/s eta 0:00:18
#      ------------------- ------------------- 6.3/12.8 MB 398.2 kB/s eta 0:00:17
#      ------------------- ------------------- 6.3/12.8 MB 398.2 kB/s eta 0:00:17
#      ------------------- ------------------- 6.6/12.8 MB 405.5 kB/s eta 0:00:16
#      ------------------- ------------------- 6.6/12.8 MB 405.5 kB/s eta 0:00:16
#      -------------------- ------------------ 6.8/12.8 MB 413.6 kB/s eta 0:00:15
#      -------------------- ------------------ 6.8/12.8 MB 413.6 kB/s eta 0:00:15
#      --------------------- ----------------- 7.1/12.8 MB 420.2 kB/s eta 0:00:14
#      ---------------------- ---------------- 7.3/12.8 MB 426.5 kB/s eta 0:00:13
#      ---------------------- ---------------- 7.3/12.8 MB 426.5 kB/s eta 0:00:13
#      ----------------------- --------------- 7.6/12.8 MB 432.6 kB/s eta 0:00:13
#      ----------------------- --------------- 7.6/12.8 MB 432.6 kB/s eta 0:00:13
#      ----------------------- --------------- 7.9/12.8 MB 439.9 kB/s eta 0:00:12
#      ------------------------ -------------- 8.1/12.8 MB 446.2 kB/s eta 0:00:11
#      ------------------------- ------------- 8.4/12.8 MB 454.6 kB/s eta 0:00:10
#      -------------------------- ------------ 8.7/12.8 MB 462.4 kB/s eta 0:00:09
#      -------------------------- ------------ 8.7/12.8 MB 462.4 kB/s eta 0:00:09
#      --------------------------- ----------- 8.9/12.8 MB 470.0 kB/s eta 0:00:09
#      --------------------------- ----------- 9.2/12.8 MB 477.7 kB/s eta 0:00:08
#      ---------------------------- ---------- 9.4/12.8 MB 484.9 kB/s eta 0:00:07
#      ----------------------------- --------- 9.7/12.8 MB 491.8 kB/s eta 0:00:07
#      ----------------------------- -------- 10.0/12.8 MB 499.4 kB/s eta 0:00:06
#      ----------------------------- -------- 10.0/12.8 MB 499.4 kB/s eta 0:00:06
#      ------------------------------ ------- 10.2/12.8 MB 506.0 kB/s eta 0:00:06
#      ------------------------------- ------ 10.5/12.8 MB 513.2 kB/s eta 0:00:05
#      ------------------------------- ------ 10.7/12.8 MB 519.8 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 525.9 kB/s eta 0:00:04
#      -------------------------------- ----- 11.0/12.8 MB 525.9 kB/s eta 0:00:04
#      --------------------------------- ---- 11.3/12.8 MB 531.0 kB/s eta 0:00:03
#      --------------------------------- ---- 11.3/12.8 MB 531.0 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 534.0 kB/s eta 0:00:03
#      ---------------------------------- --- 11.5/12.8 MB 534.0 kB/s eta 0:00:03
#      ----------------------------------- -- 11.8/12.8 MB 532.2 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 532.2 kB/s eta 0:00:02
#      ----------------------------------- -- 11.8/12.8 MB 532.2 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 529.1 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 529.1 kB/s eta 0:00:02
#      ----------------------------------- -- 12.1/12.8 MB 529.1 kB/s eta 0:00:02
#      ------------------------------------ - 12.3/12.8 MB 526.8 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 526.8 kB/s eta 0:00:01
#      ------------------------------------ - 12.3/12.8 MB 526.8 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 522.2 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 522.2 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 522.2 kB/s eta 0:00:01
#      -------------------------------------  12.6/12.8 MB 522.2 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 517.3 kB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from collections import Counter
import pandas as pd

# Load spaCy model
nlp = spacy.load("en_core_web_sm")  

# POS Tagging on 'whole_review' column
pos_tags_by_movie = {}
for movie_id, text in sampled_data.groupby("movie_id")["whole_review"].apply(lambda x: " ".join(x)).items():
    doc = nlp(text)  
    pos_tags = [(token.text, token.pos_) for token in doc]  
    pos_counts = Counter(pos_tags)  
    pos_tags_by_movie[movie_id] = pos_counts

# NER for PERSON and ORGANIZATION in 'whole_plot' column
person_entities_by_movie = {}

for movie_id, text in sampled_data.groupby("movie_id")["whole_plot"].apply(lambda x: " ".join(x)).items():
    doc = nlp(text)  
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]

    # Count occurrences
    person_counts = Counter(person_entities)
    # Store results
    person_entities_by_movie[movie_id] = person_counts
# Display Results
# POS Tagging

print("POS Tagging in review text Results:")
for movie_id, pos_counts in pos_tags_by_movie.items():
    print(f"\nMovie ID: {movie_id} - Most Common POS Tags:")
    for (word, pos), count in pos_counts.most_common(10):  #does this make sense? I dont want to display ALL the words.
        print(f"{word} ({pos}): {count} times")
    print("\n" + "="*40)

# PERSON Entities
print("\nPERSON Entity Results:")
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"\nMovie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):
        print(f"{entity}: {count} times")
    print("\n" + "="*40)
# Out:
# POS Tagging Results:
#
# Movie ID: tt0015864 - Most Common POS Tags:
# , (PUNCT): 57 times
# the (DET): 55 times
# . (PUNCT): 33 times
# of (ADP): 29 times
# and (CCONJ): 27 times
# a (DET): 26 times
# Chaplin (PROPN): 20 times
# to (PART): 18 times
# he (PRON): 15 times
# his (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0017136 - Most Common POS Tags:
# the (DET): 136 times
# . (PUNCT): 96 times
# , (PUNCT): 86 times
# and (CCONJ): 75 times
# is (AUX): 63 times
# a (DET): 62 times
# of (ADP): 42 times
# in (ADP): 37 times
# to (PART): 34 times
# it (PRON): 28 times
#
# ========================================
#
# Movie ID: tt0017925 - Most Common POS Tags:
# , (PUNCT): 78 times
# the (DET): 77 times
# . (PUNCT): 57 times
# a (DET): 50 times
# and (CCONJ): 38 times
# of (ADP): 38 times
# in (ADP): 27 times
# it (PRON): 27 times
# to (PART): 24 times
# is (AUX): 23 times
#
# ========================================
#
# Movie ID: tt0018455 - Most Common POS Tags:
# the (DET): 41 times
# , (PUNCT): 35 times
# . (PUNCT): 23 times
# I (PRON): 19 times
# and (CCONJ): 18 times
# of (ADP): 18 times
# a (DET): 15 times
# to (PART): 13 times
# film (NOUN): 13 times
# was (AUX): 12 times
#
# ========================================
#
# Movie ID: tt0019254 - Most Common POS Tags:
# the (DET): 50 times
# of (ADP): 44 times
# . (PUNCT): 39 times
# , (PUNCT): 33 times
# to (PART): 20 times
# and (CCONJ): 17 times
# her (PRON): 16 times
# in (ADP): 15 times
# to (ADP): 14 times
# 's (PART): 14 times
#
# ========================================
#
# Movie ID: tt0021749 - Most Common POS Tags:
# the (DET): 50 times
# . (PUNCT): 49 times
# , (PUNCT): 43 times
# and (CCONJ): 25 times
# is (AUX): 25 times
# a (DET): 23 times
# film (NOUN): 21 times
# of (ADP): 21 times
# to (PART): 17 times
# The (DET): 14 times
#
# ========================================
#
# Movie ID: tt0022100 - Most Common POS Tags:
# the (DET): 54 times
# . (PUNCT): 43 times
# , (PUNCT): 39 times
# and (CCONJ): 26 times
# a (DET): 24 times
# is (AUX): 23 times
# of (ADP): 23 times
# to (PART): 18 times
# in (ADP): 16 times
# I (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0025316 - Most Common POS Tags:
# , (PUNCT): 44 times
# the (DET): 42 times
# . (PUNCT): 35 times
# and (CCONJ): 34 times
# a (DET): 25 times
# to (PART): 17 times
# in (ADP): 16 times
# of (ADP): 16 times
# is (AUX): 14 times
# it (PRON): 13 times
#
# ========================================
#
# Movie ID: tt0031381 - Most Common POS Tags:
# , (PUNCT): 108 times
# the (DET): 60 times
# . (PUNCT): 55 times
# and (CCONJ): 37 times
# a (DET): 30 times
# is (AUX): 26 times
# of (ADP): 26 times
# on (ADP): 21 times
# her (PRON): 20 times
# ( (PUNCT): 20 times
#
# ========================================
#
# Movie ID: tt0031679 - Most Common POS Tags:
# , (PUNCT): 46 times
# the (DET): 36 times
# . (PUNCT): 35 times
# a (DET): 24 times
# of (ADP): 22 times
# " (PUNCT): 16 times
# in (ADP): 14 times
# is (AUX): 14 times
# and (CCONJ): 13 times
# to (PART): 12 times
#
# ========================================
#
# Movie ID: tt0032138 - Most Common POS Tags:
# the (DET): 64 times
# , (PUNCT): 42 times
# . (PUNCT): 35 times
# and (CCONJ): 24 times
# in (ADP): 17 times
# of (ADP): 15 times
# a (DET): 15 times
# movie (NOUN): 13 times
# was (AUX): 12 times
# I (PRON): 12 times
#
# ========================================
#
# Movie ID: tt0032551 - Most Common POS Tags:
# . (PUNCT): 46 times
# the (DET): 38 times
# to (PART): 21 times
# , (PUNCT): 19 times
# and (CCONJ): 17 times
# of (ADP): 17 times
# it (PRON): 17 times
# is (AUX): 16 times
# a (DET): 14 times
# his (PRON): 12 times
#
# ========================================
#
# Movie ID: tt0032553 - Most Common POS Tags:
# , (PUNCT): 109 times
# . (PUNCT): 103 times
# the (DET): 102 times
# of (ADP): 63 times
# a (DET): 58 times
# and (CCONJ): 58 times
# his (PRON): 41 times
# Chaplin (PROPN): 39 times
# in (ADP): 30 times
# is (AUX): 28 times
#
# ========================================
#
# Movie ID: tt0032976 - Most Common POS Tags:
# , (PUNCT): 97 times
# . (PUNCT): 90 times
# the (DET): 71 times
# and (CCONJ): 44 times
# of (ADP): 39 times
# a (DET): 34 times
# is (AUX): 33 times
# in (ADP): 30 times
# her (PRON): 26 times
# I (PRON): 22 times
#
# ========================================
#
# Movie ID: tt0033467 - Most Common POS Tags:
# the (DET): 50 times
# , (PUNCT): 50 times
# of (ADP): 41 times
# . (PUNCT): 41 times
# and (CCONJ): 32 times
# a (DET): 31 times
# it (PRON): 30 times
# I (PRON): 26 times
# " (PUNCT): 26 times
# in (ADP): 22 times
#
# ========================================
#
# Movie ID: tt0033870 - Most Common POS Tags:
# the (DET): 85 times
# , (PUNCT): 74 times
# . (PUNCT): 68 times
# of (ADP): 51 times
# and (CCONJ): 43 times
# a (DET): 34 times
# to (PART): 31 times
# in (ADP): 26 times
# was (AUX): 22 times
# on (ADP): 20 times
#
# ========================================
#
# Movie ID: tt0034583 - Most Common POS Tags:
# the (DET): 86 times
# . (PUNCT): 50 times
# of (ADP): 38 times
# , (PUNCT): 37 times
# a (DET): 32 times
# and (CCONJ): 30 times
# to (PART): 23 times
# film (NOUN): 23 times
# in (ADP): 20 times
# you (PRON): 17 times
#
# ========================================
#
# Movie ID: tt0036775 - Most Common POS Tags:
# , (PUNCT): 61 times
# the (DET): 48 times
# and (CCONJ): 48 times
# . (PUNCT): 45 times
# a (DET): 31 times
# is (AUX): 30 times
# of (ADP): 28 times
# - (PUNCT): 22 times
# I (PRON): 21 times
# The (DET): 15 times
#
# ========================================
#
# Movie ID: tt0036868 - Most Common POS Tags:
# . (PUNCT): 53 times
# the (DET): 36 times
# and (CCONJ): 29 times
# , (PUNCT): 24 times
# is (AUX): 22 times
# I (PRON): 21 times
# a (DET): 21 times
# of (ADP): 21 times
# in (ADP): 15 times
# it (PRON): 15 times
#
# ========================================
#
# Movie ID: tt0038650 - Most Common POS Tags:
# , (PUNCT): 97 times
# . (PUNCT): 85 times
# and (CCONJ): 85 times
# the (DET): 81 times
# of (ADP): 53 times
# a (DET): 48 times
# in (ADP): 35 times
# it (PRON): 32 times
# is (AUX): 26 times
# to (PART): 25 times
#
# ========================================
#
# Movie ID: tt0040522 - Most Common POS Tags:
# the (DET): 41 times
# . (PUNCT): 35 times
# , (PUNCT): 26 times
# and (CCONJ): 25 times
# it (PRON): 23 times
# is (AUX): 21 times
# of (ADP): 18 times
# not (PART): 14 times
# but (CCONJ): 13 times
# a (DET): 13 times
#
# ========================================
#
# Movie ID: tt0040897 - Most Common POS Tags:
# the (DET): 108 times
# , (PUNCT): 93 times
# . (PUNCT): 72 times
# of (ADP): 59 times
# a (DET): 52 times
# and (CCONJ): 45 times
# in (ADP): 36 times
# is (AUX): 28 times
# to (PART): 27 times
# it (PRON): 23 times
#
# ========================================
#
# Movie ID: tt0041959 - Most Common POS Tags:
# the (DET): 67 times
# , (PUNCT): 65 times
# . (PUNCT): 53 times
# of (ADP): 38 times
# and (CCONJ): 35 times
# a (DET): 34 times
# to (PART): 33 times
# in (ADP): 23 times
# 's (PART): 22 times
# is (AUX): 20 times
#
# ========================================
#
# Movie ID: tt0042192 - Most Common POS Tags:
# . (PUNCT): 88 times
# the (DET): 76 times
# , (PUNCT): 73 times
# a (DET): 50 times
# of (ADP): 49 times
# is (AUX): 38 times
# and (CCONJ): 37 times
# " (PUNCT): 34 times
# to (PART): 31 times
# in (ADP): 28 times
#
# ========================================
#
# Movie ID: tt0042876 - Most Common POS Tags:
# the (DET): 104 times
# , (PUNCT): 65 times
# . (PUNCT): 62 times
# of (ADP): 49 times
# and (CCONJ): 44 times
# a (DET): 40 times
# is (AUX): 27 times
# in (ADP): 24 times
# to (PART): 19 times
# film (NOUN): 18 times
#
# ========================================
#
# Movie ID: tt0043014 - Most Common POS Tags:
# . (PUNCT): 93 times
# the (DET): 72 times
# , (PUNCT): 66 times
# and (CCONJ): 49 times
# a (DET): 39 times
# of (ADP): 33 times
# in (ADP): 30 times
# film (NOUN): 27 times
# was (AUX): 27 times
# is (AUX): 25 times
#
# ========================================
#
# Movie ID: tt0045152 - Most Common POS Tags:
# the (DET): 65 times
# . (PUNCT): 57 times
# , (PUNCT): 40 times
# and (CCONJ): 30 times
# of (ADP): 28 times
# I (PRON): 24 times
# a (DET): 21 times
# in (ADP): 18 times
# it (PRON): 15 times
# movie (NOUN): 13 times
#
# ========================================
#
# Movie ID: tt0046268 - Most Common POS Tags:
# the (DET): 48 times
# . (PUNCT): 42 times
# , (PUNCT): 35 times
# I (PRON): 24 times
# and (CCONJ): 21 times
# of (ADP): 19 times
# is (AUX): 18 times
# a (DET): 17 times
# to (PART): 14 times
# it (PRON): 11 times
#
# ========================================
#
# Movie ID: tt0046438 - Most Common POS Tags:
# , (PUNCT): 98 times
# the (DET): 69 times
# . (PUNCT): 52 times
# a (DET): 40 times
# and (CCONJ): 39 times
# of (ADP): 37 times
# in (ADP): 31 times
# to (PART): 26 times
# ( (PUNCT): 26 times
# ) (PUNCT): 26 times
#
# ========================================
#
# Movie ID: tt0046911 - Most Common POS Tags:
# . (PUNCT): 56 times
# the (DET): 46 times
# and (CCONJ): 31 times
# a (DET): 26 times
# to (PART): 24 times
# I (PRON): 21 times
# of (ADP): 20 times
# is (AUX): 18 times
# , (PUNCT): 17 times
# it (PRON): 16 times
#
# ========================================
#
# Movie ID: tt0046912 - Most Common POS Tags:
# . (PUNCT): 57 times
# the (DET): 44 times
# , (PUNCT): 42 times
# and (CCONJ): 32 times
# is (AUX): 30 times
# a (DET): 19 times
# of (ADP): 17 times
# Hitchcock (PROPN): 13 times
# film (NOUN): 11 times
# it (PRON): 11 times
#
# ========================================
#
# Movie ID: tt0047296 - Most Common POS Tags:
# . (PUNCT): 72 times
# the (DET): 62 times
# , (PUNCT): 48 times
# a (DET): 37 times
# of (ADP): 37 times
# and (CCONJ): 32 times
# is (AUX): 31 times
# in (ADP): 31 times
# 's (PART): 19 times
# Terry (PROPN): 18 times
#
# ========================================
#
# Movie ID: tt0047396 - Most Common POS Tags:
# . (PUNCT): 85 times
# the (DET): 85 times
# , (PUNCT): 75 times
# and (CCONJ): 50 times
# is (AUX): 41 times
# a (DET): 41 times
# of (ADP): 41 times
# his (PRON): 23 times
# film (NOUN): 22 times
# to (PART): 22 times
#
# ========================================
#
# Movie ID: tt0047478 - Most Common POS Tags:
# the (DET): 73 times
# , (PUNCT): 57 times
# . (PUNCT): 51 times
# of (ADP): 43 times
# is (AUX): 27 times
# and (CCONJ): 24 times
# in (ADP): 24 times
# a (DET): 20 times
# to (PART): 19 times
# samurai (NOUN): 13 times
#
# ========================================
#
# Movie ID: tt0050083 - Most Common POS Tags:
# the (DET): 55 times
# . (PUNCT): 37 times
# of (ADP): 31 times
# , (PUNCT): 31 times
# and (CCONJ): 23 times
# is (AUX): 22 times
# a (DET): 19 times
# I (PRON): 18 times
# to (PART): 17 times
# that (SCONJ): 12 times
#
# ========================================
#
# Movie ID: tt0050212 - Most Common POS Tags:
# the (DET): 113 times
# , (PUNCT): 106 times
# . (PUNCT): 84 times
# of (ADP): 52 times
# and (CCONJ): 47 times
# a (DET): 43 times
# is (AUX): 35 times
# in (ADP): 29 times
#   (SPACE): 28 times
# it (PRON): 27 times
#
# ========================================
#
# Movie ID: tt0050783 - Most Common POS Tags:
# , (PUNCT): 49 times
# the (DET): 46 times
# . (PUNCT): 38 times
# and (CCONJ): 32 times
# a (DET): 29 times
# of (ADP): 26 times
# is (AUX): 26 times
# film (NOUN): 24 times
# I (PRON): 20 times
# to (PART): 16 times
#
# ========================================
#
# Movie ID: tt0050825 - Most Common POS Tags:
# , (PUNCT): 64 times
# the (DET): 55 times
# . (PUNCT): 42 times
# a (DET): 34 times
# and (CCONJ): 31 times
# of (ADP): 27 times
# is (AUX): 21 times
# to (ADP): 16 times
# film (NOUN): 14 times
# to (PART): 14 times
#
# ========================================
#
# Movie ID: tt0050976 - Most Common POS Tags:
# , (PUNCT): 83 times
# the (DET): 65 times
# . (PUNCT): 50 times
# a (DET): 34 times
# and (CCONJ): 32 times
# of (ADP): 28 times
# " (PUNCT): 28 times
# in (ADP): 26 times
# to (PART): 23 times
# is (AUX): 22 times
#
# ========================================
#
# Movie ID: tt0050986 - Most Common POS Tags:
# , (PUNCT): 166 times
# . (PUNCT): 101 times
# the (DET): 97 times
# and (CCONJ): 74 times
# is (AUX): 72 times
# of (ADP): 60 times
# a (DET): 52 times
# in (ADP): 47 times
# he (PRON): 44 times
# his (PRON): 38 times
#
# ========================================
#
# Movie ID: tt0051201 - Most Common POS Tags:
# , (PUNCT): 96 times
# the (DET): 68 times
# . (PUNCT): 66 times
# a (DET): 42 times
# of (ADP): 34 times
# is (AUX): 27 times
# and (CCONJ): 25 times
# to (PART): 22 times
# in (ADP): 19 times
# 's (PART): 18 times
#
# ========================================
#
# Movie ID: tt0052311 - Most Common POS Tags:
# the (DET): 91 times
# . (PUNCT): 79 times
# , (PUNCT): 64 times
# and (CCONJ): 61 times
# a (DET): 51 times
# is (AUX): 38 times
# of (ADP): 34 times
# " (PUNCT): 26 times
# in (ADP): 25 times
# his (PRON): 22 times
#
# ========================================
#
# Movie ID: tt0052357 - Most Common POS Tags:
# , (PUNCT): 84 times
# the (DET): 79 times
# . (PUNCT): 75 times
# of (ADP): 54 times
# is (AUX): 39 times
# a (DET): 38 times
# and (CCONJ): 37 times
# in (ADP): 33 times
# his (PRON): 28 times
# it (PRON): 25 times
#
# ========================================
#
# Movie ID: tt0052618 - Most Common POS Tags:
# . (PUNCT): 80 times
# the (DET): 79 times
# , (PUNCT): 74 times
# and (CCONJ): 43 times
# a (DET): 33 times
# of (ADP): 32 times
# is (AUX): 24 times
# it (PRON): 17 times
# to (PART): 15 times
# 's (AUX): 14 times
#
# ========================================
#
# Movie ID: tt0053125 - Most Common POS Tags:
# , (PUNCT): 58 times
# the (DET): 49 times
# . (PUNCT): 39 times
# and (CCONJ): 28 times
# a (DET): 28 times
# of (ADP): 28 times
# is (AUX): 24 times
# - (PUNCT): 20 times
# Grant (PROPN): 14 times
# it (PRON): 12 times
#
# ========================================
#
# Movie ID: tt0053291 - Most Common POS Tags:
# the (DET): 50 times
# . (PUNCT): 46 times
# , (PUNCT): 40 times
# a (DET): 30 times
# and (CCONJ): 28 times
# in (ADP): 26 times
# of (ADP): 23 times
# was (AUX): 23 times
# " (PUNCT): 18 times
# to (PART): 10 times
#
# ========================================
#
# Movie ID: tt0053604 - Most Common POS Tags:
# , (PUNCT): 87 times
# . (PUNCT): 72 times
# and (CCONJ): 51 times
# the (DET): 43 times
# is (AUX): 41 times
# a (DET): 33 times
# he (PRON): 28 times
# to (PART): 27 times
# of (ADP): 25 times
# his (PRON): 21 times
#
# ========================================
#
# Movie ID: tt0054215 - Most Common POS Tags:
# the (DET): 38 times
# , (PUNCT): 32 times
# . (PUNCT): 31 times
# and (CCONJ): 21 times
# I (PRON): 20 times
# a (DET): 19 times
# of (ADP): 15 times
# it (PRON): 13 times
# is (AUX): 11 times
# in (ADP): 10 times
#
# ========================================
#
# Movie ID: tt0055031 - Most Common POS Tags:
# the (DET): 77 times
# , (PUNCT): 59 times
# . (PUNCT): 49 times
# of (ADP): 41 times
# a (DET): 33 times
# and (CCONJ): 28 times
# to (PART): 22 times
# is (AUX): 20 times
# in (ADP): 15 times
# with (ADP): 13 times
#
# ========================================
#
# Movie ID: tt0055630 - Most Common POS Tags:
# the (DET): 26 times
# . (PUNCT): 19 times
# of (ADP): 15 times
# , (PUNCT): 14 times
# and (CCONJ): 12 times
# movie (NOUN): 11 times
# in (ADP): 10 times
# a (DET): 9 times
# this (DET): 9 times
# film (NOUN): 6 times
#
# ========================================
#
# Movie ID: tt0056172 - Most Common POS Tags:
# , (PUNCT): 49 times
# the (DET): 43 times
# . (PUNCT): 43 times
# a (DET): 30 times
# of (ADP): 25 times
# I (PRON): 23 times
# and (CCONJ): 17 times
# to (PART): 15 times
# for (ADP): 12 times
# is (AUX): 12 times
#
# ========================================
#
# Movie ID: tt0056592 - Most Common POS Tags:
# the (DET): 73 times
# . (PUNCT): 63 times
# and (CCONJ): 39 times
# , (PUNCT): 37 times
# a (DET): 34 times
# is (AUX): 30 times
# I (PRON): 29 times
# of (ADP): 27 times
# in (ADP): 23 times
# movie (NOUN): 21 times
#
# ========================================
#
# Movie ID: tt0057012 - Most Common POS Tags:
# the (DET): 67 times
# a (DET): 46 times
# . (PUNCT): 42 times
# , (PUNCT): 38 times
# of (ADP): 35 times
# and (CCONJ): 32 times
# to (PART): 28 times
# is (AUX): 27 times
# ' (PUNCT): 23 times
# in (ADP): 18 times
#
# ========================================
#
# Movie ID: tt0057115 - Most Common POS Tags:
# the (DET): 46 times
# , (PUNCT): 39 times
# . (PUNCT): 34 times
# of (ADP): 28 times
# and (CCONJ): 25 times
# a (DET): 21 times
# The (DET): 19 times
#   (SPACE): 18 times
# is (AUX): 14 times
# " (PUNCT): 13 times
#
# ========================================
#
# Movie ID: tt0059578 - Most Common POS Tags:
# the (DET): 71 times
# , (PUNCT): 54 times
# . (PUNCT): 37 times
# and (CCONJ): 34 times
# a (DET): 32 times
# of (ADP): 29 times
# is (AUX): 25 times
# The (DET): 16 times
# ` (PUNCT): 15 times
#   (SPACE): 15 times
#
# ========================================
#
# Movie ID: tt0060107 - Most Common POS Tags:
# , (PUNCT): 81 times
# and (CCONJ): 69 times
# the (DET): 57 times
# . (PUNCT): 55 times
# a (DET): 38 times
# of (ADP): 34 times
# in (ADP): 26 times
# is (AUX): 22 times
# his (PRON): 19 times
# to (PART): 18 times
#
# ========================================
#
# Movie ID: tt0060196 - Most Common POS Tags:
# . (PUNCT): 102 times
# , (PUNCT): 85 times
# the (DET): 77 times
# and (CCONJ): 64 times
# of (ADP): 50 times
# a (DET): 49 times
# is (AUX): 41 times
# in (ADP): 30 times
# it (PRON): 28 times
# The (DET): 22 times
#
# ========================================
#
# Movie ID: tt0060827 - Most Common POS Tags:
# . (PUNCT): 59 times
# , (PUNCT): 57 times
# the (DET): 46 times
# I (PRON): 41 times
# a (DET): 38 times
# of (ADP): 28 times
# in (ADP): 22 times
# and (CCONJ): 20 times
# to (PART): 18 times
# is (AUX): 16 times
#
# ========================================
#
# Movie ID: tt0061512 - Most Common POS Tags:
# the (DET): 109 times
# , (PUNCT): 90 times
# . (PUNCT): 85 times
# is (AUX): 55 times
# a (DET): 55 times
# and (CCONJ): 54 times
# Luke (PROPN): 52 times
# of (ADP): 41 times
# he (PRON): 40 times
# in (ADP): 36 times
#
# ========================================
#
# Movie ID: tt0062622 - Most Common POS Tags:
# , (PUNCT): 80 times
# the (DET): 67 times
# . (PUNCT): 60 times
# of (ADP): 46 times
# and (CCONJ): 36 times
# a (DET): 33 times
# to (PART): 29 times
# it (PRON): 28 times
# film (NOUN): 25 times
# is (AUX): 24 times
#
# ========================================
#
# Movie ID: tt0064115 - Most Common POS Tags:
# , (PUNCT): 47 times
# . (PUNCT): 44 times
# the (DET): 41 times
# and (CCONJ): 26 times
# of (ADP): 22 times
# " (PUNCT): 19 times
# a (DET): 16 times
# I (PRON): 16 times
# it (PRON): 16 times
# n't (PART): 15 times
#
# ========================================
#
# Movie ID: tt0064116 - Most Common POS Tags:
# the (DET): 98 times
# . (PUNCT): 64 times
# and (CCONJ): 59 times
# a (DET): 51 times
# , (PUNCT): 42 times
# of (ADP): 36 times
# in (ADP): 27 times
# is (AUX): 26 times
# to (PART): 23 times
# " (PUNCT): 23 times
#
# ========================================
#
# Movie ID: tt0066921 - Most Common POS Tags:
# , (PUNCT): 39 times
# . (PUNCT): 21 times
# and (CCONJ): 18 times
# of (ADP): 17 times
# is (AUX): 16 times
# a (DET): 16 times
# the (DET): 15 times
# ( (PUNCT): 12 times
# ) (PUNCT): 12 times
# movie (NOUN): 10 times
#
# ========================================
#
# Movie ID: tt0068646 - Most Common POS Tags:
# , (PUNCT): 94 times
# the (DET): 80 times
# . (PUNCT): 73 times
# of (ADP): 51 times
# and (CCONJ): 44 times
# I (PRON): 34 times
# a (DET): 32 times
# to (PART): 29 times
# ' (PUNCT): 28 times
# is (AUX): 26 times
#
# ========================================
#
# Movie ID: tt0070510 - Most Common POS Tags:
# , (PUNCT): 72 times
# the (DET): 66 times
# and (CCONJ): 61 times
# . (PUNCT): 48 times
# to (PART): 36 times
# a (DET): 31 times
# of (ADP): 29 times
# in (ADP): 23 times
# her (PRON): 22 times
# is (AUX): 20 times
#
# ========================================
#
# Movie ID: tt0070735 - Most Common POS Tags:
# , (PUNCT): 44 times
# . (PUNCT): 36 times
# and (CCONJ): 31 times
# the (DET): 30 times
# a (DET): 27 times
# to (PART): 19 times
# I (PRON): 18 times
# in (ADP): 14 times
# it (PRON): 13 times
# of (ADP): 12 times
#
# ========================================
#
# Movie ID: tt0071315 - Most Common POS Tags:
# the (DET): 32 times
# , (PUNCT): 31 times
# . (PUNCT): 28 times
# a (DET): 27 times
# and (CCONJ): 22 times
# of (ADP): 19 times
# is (AUX): 17 times
# it (PRON): 12 times
# in (ADP): 12 times
# to (PART): 11 times
#
# ========================================
#
# Movie ID: tt0071562 - Most Common POS Tags:
# . (PUNCT): 77 times
# the (DET): 71 times
# , (PUNCT): 66 times
# and (CCONJ): 40 times
# a (DET): 34 times
# is (AUX): 32 times
# of (ADP): 31 times
# in (ADP): 26 times
# to (PART): 21 times
# his (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0071853 - Most Common POS Tags:
# the (DET): 38 times
# " (PUNCT): 29 times
# . (PUNCT): 27 times
# , (PUNCT): 20 times
# is (AUX): 16 times
# of (ADP): 15 times
# I (PRON): 13 times
# it (PRON): 11 times
# The (DET): 11 times
# a (DET): 10 times
#
# ========================================
#
# Movie ID: tt0072684 - Most Common POS Tags:
# the (DET): 51 times
# , (PUNCT): 47 times
# . (PUNCT): 38 times
# and (CCONJ): 28 times
# of (ADP): 26 times
# is (AUX): 25 times
# a (DET): 25 times
# Barry (PROPN): 19 times
# in (ADP): 15 times
# I (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0072890 - Most Common POS Tags:
# the (DET): 81 times
# . (PUNCT): 71 times
# , (PUNCT): 54 times
# a (DET): 46 times
# of (ADP): 44 times
# is (AUX): 33 times
# in (ADP): 24 times
# " (PUNCT): 22 times
# his (PRON): 20 times
# and (CCONJ): 20 times
#
# ========================================
#
# Movie ID: tt0073195 - Most Common POS Tags:
# , (PUNCT): 76 times
# the (DET): 71 times
# and (CCONJ): 38 times
# ... (PUNCT): 32 times
# . (PUNCT): 31 times
# of (ADP): 29 times
# a (DET): 28 times
# is (AUX): 23 times
# to (PART): 19 times
# in (ADP): 13 times
#
# ========================================
#
# Movie ID: tt0073486 - Most Common POS Tags:
# the (DET): 87 times
# . (PUNCT): 56 times
# , (PUNCT): 48 times
# of (ADP): 39 times
# and (CCONJ): 30 times
# a (DET): 30 times
# to (PART): 28 times
# it (PRON): 23 times
# is (AUX): 21 times
# in (ADP): 18 times
#
# ========================================
#
# Movie ID: tt0074958 - Most Common POS Tags:
# . (PUNCT): 61 times
# , (PUNCT): 60 times
# the (DET): 59 times
# of (ADP): 39 times
# and (CCONJ): 30 times
# it (PRON): 25 times
# a (DET): 25 times
# is (AUX): 18 times
# ' (PUNCT): 16 times
# was (AUX): 16 times
#
# ========================================
#
# Movie ID: tt0075148 - Most Common POS Tags:
# the (DET): 71 times
# , (PUNCT): 67 times
# . (PUNCT): 60 times
# a (DET): 45 times
# is (AUX): 44 times
# and (CCONJ): 40 times
# of (ADP): 34 times
# Rocky (PROPN): 32 times
# to (PART): 21 times
# who (PRON): 20 times
#
# ========================================
#
# Movie ID: tt0075314 - Most Common POS Tags:
# . (PUNCT): 53 times
# is (AUX): 37 times
# of (ADP): 34 times
# the (DET): 32 times
# , (PUNCT): 29 times
# a (DET): 28 times
# and (CCONJ): 28 times
# film (NOUN): 19 times
# in (ADP): 15 times
# this (DET): 15 times
#
# ========================================
#
# Movie ID: tt0075686 - Most Common POS Tags:
# and (CCONJ): 65 times
# the (DET): 55 times
# , (PUNCT): 55 times
# . (PUNCT): 54 times
# is (AUX): 40 times
# a (DET): 34 times
# to (PART): 30 times
# he (PRON): 30 times
# it (PRON): 29 times
# of (ADP): 24 times
#
# ========================================
#
# Movie ID: tt0076759 - Most Common POS Tags:
# the (DET): 92 times
# . (PUNCT): 68 times
# , (PUNCT): 54 times
# and (CCONJ): 50 times
# of (ADP): 40 times
# to (PART): 36 times
# a (DET): 33 times
# in (ADP): 24 times
# is (AUX): 23 times
# I (PRON): 19 times
#
# ========================================
#
# Movie ID: tt0077416 - Most Common POS Tags:
# , (PUNCT): 50 times
# the (DET): 39 times
# . (PUNCT): 38 times
# and (CCONJ): 35 times
# is (AUX): 18 times
# a (DET): 18 times
# to (PART): 17 times
# of (ADP): 16 times
# his (PRON): 14 times
# in (ADP): 14 times
#
# ========================================
#
# Movie ID: tt0078748 - Most Common POS Tags:
# the (DET): 102 times
# , (PUNCT): 72 times
# . (PUNCT): 57 times
# of (ADP): 42 times
# a (DET): 41 times
# and (CCONJ): 41 times
# is (AUX): 34 times
# to (PART): 30 times
# - (PUNCT): 20 times
# in (ADP): 19 times
#
# ========================================
#
# Movie ID: tt0078788 - Most Common POS Tags:
# the (DET): 109 times
# . (PUNCT): 87 times
# of (ADP): 57 times
# and (CCONJ): 52 times
# , (PUNCT): 49 times
# is (AUX): 38 times
# a (DET): 36 times
# in (ADP): 27 times
# to (PART): 20 times
# by (ADP): 19 times
#
# ========================================
#
# Movie ID: tt0079470 - Most Common POS Tags:
# , (PUNCT): 79 times
# the (DET): 75 times
# . (PUNCT): 59 times
# of (ADP): 40 times
# and (CCONJ): 38 times
# is (AUX): 25 times
# a (DET): 23 times
# it (PRON): 22 times
# ' (PUNCT): 20 times
# to (PART): 19 times
#
# ========================================
#
# Movie ID: tt0079944 - Most Common POS Tags:
# the (DET): 87 times
# . (PUNCT): 76 times
# of (ADP): 50 times
# and (CCONJ): 46 times
# , (PUNCT): 45 times
# a (DET): 39 times
# is (AUX): 36 times
# to (PART): 33 times
# in (ADP): 17 times
# It (PRON): 15 times
#
# ========================================
#
# Movie ID: tt0080678 - Most Common POS Tags:
# , (PUNCT): 74 times
# the (DET): 68 times
# . (PUNCT): 61 times
# is (AUX): 39 times
# of (ADP): 39 times
# a (DET): 38 times
# and (CCONJ): 38 times
# it (PRON): 27 times
# that (PRON): 23 times
# I (PRON): 19 times
#
# ========================================
#
# Movie ID: tt0080684 - Most Common POS Tags:
# the (DET): 80 times
# , (PUNCT): 52 times
# . (PUNCT): 47 times
# of (ADP): 41 times
# and (CCONJ): 31 times
# to (PART): 26 times
# in (ADP): 22 times
# is (AUX): 19 times
# a (DET): 17 times
# The (DET): 14 times
#
# ========================================
#
# Movie ID: tt0081398 - Most Common POS Tags:
# , (PUNCT): 73 times
# the (DET): 62 times
# . (PUNCT): 61 times
# and (CCONJ): 48 times
# of (ADP): 35 times
# is (AUX): 32 times
# in (ADP): 24 times
# it (PRON): 23 times
# to (PART): 22 times
# his (PRON): 21 times
#
# ========================================
#
# Movie ID: tt0081505 - Most Common POS Tags:
# , (PUNCT): 77 times
# the (DET): 73 times
# . (PUNCT): 59 times
# movie (NOUN): 32 times
# and (CCONJ): 32 times
# of (ADP): 29 times
# is (AUX): 27 times
# I (PRON): 26 times
# a (DET): 26 times
# it (PRON): 24 times
#
# ========================================
#
# Movie ID: tt0082096 - Most Common POS Tags:
# the (DET): 95 times
# , (PUNCT): 75 times
# . (PUNCT): 56 times
# and (CCONJ): 54 times
# of (ADP): 52 times
# a (DET): 26 times
# - (PUNCT): 24 times
# in (ADP): 22 times
# " (PUNCT): 20 times
# is (AUX): 18 times
#
# ========================================
#
# Movie ID: tt0082971 - Most Common POS Tags:
# , (PUNCT): 100 times
# the (DET): 90 times
# . (PUNCT): 81 times
# and (CCONJ): 46 times
# of (ADP): 39 times
# is (AUX): 32 times
# a (DET): 30 times
# in (ADP): 27 times
# to (PART): 25 times
# I (PRON): 23 times
#
# ========================================
#
# Movie ID: tt0083658 - Most Common POS Tags:
# , (PUNCT): 64 times
# the (DET): 49 times
# . (PUNCT): 37 times
# and (CCONJ): 26 times
# a (DET): 24 times
# is (AUX): 23 times
# it (PRON): 19 times
# of (ADP): 16 times
# ? (PUNCT): 16 times
# to (PART): 15 times
#
# ========================================
#
# Movie ID: tt0083987 - Most Common POS Tags:
# . (PUNCT): 32 times
# the (DET): 23 times
# a (DET): 22 times
# of (ADP): 13 times
# and (CCONJ): 13 times
# movie (NOUN): 12 times
# , (PUNCT): 12 times
# is (AUX): 12 times
# to (PART): 10 times
# I (PRON): 10 times
#
# ========================================
#
# Movie ID: tt0084787 - Most Common POS Tags:
# the (DET): 151 times
# and (CCONJ): 104 times
# . (PUNCT): 100 times
# , (PUNCT): 82 times
# is (AUX): 68 times
# of (ADP): 61 times
# a (DET): 55 times
# in (ADP): 43 times
# The (DET): 41 times
# film (NOUN): 37 times
#
# ========================================
#
# Movie ID: tt0086190 - Most Common POS Tags:
# the (DET): 43 times
# . (PUNCT): 27 times
# of (ADP): 21 times
# , (PUNCT): 20 times
# and (CCONJ): 17 times
# is (AUX): 13 times
# I (PRON): 13 times
# a (DET): 11 times
# to (PART): 10 times
# The (DET): 8 times
#
# ========================================
#
# Movie ID: tt0086250 - Most Common POS Tags:
# the (DET): 45 times
# , (PUNCT): 37 times
# . (PUNCT): 33 times
# and (CCONJ): 25 times
# a (DET): 24 times
# is (AUX): 21 times
# of (ADP): 18 times
# to (PART): 16 times
#   (SPACE): 13 times
# I (PRON): 13 times
#
# ========================================
#
# Movie ID: tt0086879 - Most Common POS Tags:
# . (PUNCT): 86 times
# the (DET): 82 times
# , (PUNCT): 81 times
# of (ADP): 38 times
# and (CCONJ): 34 times
# Mozart (PROPN): 25 times
# is (AUX): 23 times
# a (DET): 19 times
# I (PRON): 18 times
# in (ADP): 18 times
#
# ========================================
#
# Movie ID: tt0087843 - Most Common POS Tags:
# , (PUNCT): 126 times
# the (DET): 87 times
# . (PUNCT): 68 times
# of (ADP): 49 times
# a (DET): 43 times
# is (AUX): 39 times
# and (CCONJ): 34 times
# in (ADP): 30 times
# he (PRON): 21 times
# to (PART): 21 times
#
# ========================================
#
# Movie ID: tt0087884 - Most Common POS Tags:
# . (PUNCT): 64 times
# the (DET): 59 times
# , (PUNCT): 50 times
# a (DET): 34 times
# and (CCONJ): 32 times
# is (AUX): 30 times
# of (ADP): 29 times
# in (ADP): 27 times
# I (PRON): 20 times
# film (NOUN): 20 times
#
# ========================================
#
# Movie ID: tt0088247 - Most Common POS Tags:
# , (PUNCT): 113 times
# the (DET): 99 times
# . (PUNCT): 61 times
# a (DET): 55 times
# and (CCONJ): 42 times
# of (ADP): 34 times
# is (AUX): 29 times
# - (PUNCT): 28 times
# to (PART): 25 times
# film (NOUN): 21 times
#
# ========================================
#
# Movie ID: tt0088763 - Most Common POS Tags:
# . (PUNCT): 52 times
# , (PUNCT): 50 times
# the (DET): 38 times
# and (CCONJ): 23 times
# a (DET): 23 times
# is (AUX): 17 times
# of (ADP): 15 times
# movie (NOUN): 14 times
# you (PRON): 12 times
# The (DET): 11 times
#
# ========================================
#
# Movie ID: tt0089881 - Most Common POS Tags:
# the (DET): 47 times
# . (PUNCT): 42 times
# , (PUNCT): 34 times
# of (ADP): 27 times
# and (CCONJ): 24 times
# " (PUNCT): 22 times
# is (AUX): 17 times
# a (DET): 14 times
# for (ADP): 11 times
# The (DET): 10 times
#
# ========================================
#
# Movie ID: tt0090605 - Most Common POS Tags:
# the (DET): 55 times
# . (PUNCT): 44 times
# is (AUX): 38 times
# and (CCONJ): 33 times
# , (PUNCT): 28 times
# film (NOUN): 22 times
# of (ADP): 21 times
# a (DET): 21 times
# in (ADP): 18 times
# I (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0091763 - Most Common POS Tags:
# the (DET): 97 times
# , (PUNCT): 65 times
# . (PUNCT): 54 times
# of (ADP): 50 times
# and (CCONJ): 42 times
# a (DET): 35 times
# in (ADP): 28 times
# to (PART): 26 times
# it (PRON): 23 times
# is (AUX): 23 times
#
# ========================================
#
# Movie ID: tt0092005 - Most Common POS Tags:
# . (PUNCT): 66 times
# the (DET): 65 times
# , (PUNCT): 55 times
# and (CCONJ): 38 times
# of (ADP): 32 times
# a (DET): 29 times
# is (AUX): 28 times
# in (ADP): 22 times
# they (PRON): 19 times
# to (PART): 17 times
#
# ========================================
#
# Movie ID: tt0092067 - Most Common POS Tags:
# , (PUNCT): 136 times
# the (DET): 120 times
# . (PUNCT): 75 times
# and (CCONJ): 67 times
# of (ADP): 51 times
# is (AUX): 51 times
# a (DET): 39 times
# in (ADP): 37 times
# it (PRON): 28 times
# to (PART): 23 times
#
# ========================================
#
# Movie ID: tt0093058 - Most Common POS Tags:
# , (PUNCT): 55 times
# . (PUNCT): 50 times
# the (DET): 44 times
# of (ADP): 27 times
# in (ADP): 19 times
# to (PART): 18 times
# and (CCONJ): 17 times
# a (DET): 16 times
# film (NOUN): 16 times
# is (AUX): 16 times
#
# ========================================
#
# Movie ID: tt0093779 - Most Common POS Tags:
# the (DET): 87 times
# . (PUNCT): 75 times
# , (PUNCT): 70 times
# and (CCONJ): 54 times
# a (DET): 47 times
# of (ADP): 33 times
# I (PRON): 32 times
# it (PRON): 26 times
# The (DET): 21 times
# is (AUX): 20 times
#
# ========================================
#
# Movie ID: tt0095016 - Most Common POS Tags:
# , (PUNCT): 66 times
# the (DET): 62 times
# . (PUNCT): 43 times
# and (CCONJ): 39 times
# a (DET): 32 times
# of (ADP): 22 times
# is (AUX): 20 times
# " (PUNCT): 18 times
# his (PRON): 17 times
# in (ADP): 17 times
#
# ========================================
#
# Movie ID: tt0095327 - Most Common POS Tags:
# the (DET): 97 times
# , (PUNCT): 80 times
# . (PUNCT): 65 times
# of (ADP): 54 times
# I (PRON): 43 times
# a (DET): 42 times
# is (AUX): 40 times
# and (CCONJ): 32 times
# in (ADP): 30 times
# it (PRON): 27 times
#
# ========================================
#
# Movie ID: tt0095765 - Most Common POS Tags:
# , (PUNCT): 38 times
# the (DET): 31 times
# . (PUNCT): 30 times
# a (DET): 27 times
# is (AUX): 23 times
# and (CCONJ): 22 times
# of (ADP): 17 times
# it (PRON): 15 times
# film (NOUN): 13 times
# It (PRON): 9 times
#
# ========================================
#
# Movie ID: tt0096283 - Most Common POS Tags:
# the (DET): 64 times
# . (PUNCT): 54 times
# , (PUNCT): 50 times
# of (ADP): 35 times
# is (AUX): 26 times
# a (DET): 25 times
# and (CCONJ): 22 times
# Miyazaki (PROPN): 17 times
# in (ADP): 16 times
# Totoro (PROPN): 15 times
#
# ========================================
#
# Movie ID: tt0097165 - Most Common POS Tags:
# , (PUNCT): 36 times
# . (PUNCT): 35 times
# the (DET): 29 times
# ! (PUNCT): 21 times
# of (ADP): 17 times
# is (AUX): 14 times
# I (PRON): 13 times
# a (DET): 12 times
# it (PRON): 11 times
# and (CCONJ): 11 times
#
# ========================================
#
# Movie ID: tt0097576 - Most Common POS Tags:
# the (DET): 58 times
# , (PUNCT): 38 times
# . (PUNCT): 37 times
# and (CCONJ): 32 times
# a (DET): 27 times
# of (ADP): 26 times
# is (AUX): 24 times
# in (ADP): 17 times
# to (PART): 17 times
# The (DET): 11 times
#
# ========================================
#
# Movie ID: tt0098966 - Most Common POS Tags:
# the (DET): 58 times
# . (PUNCT): 48 times
# and (CCONJ): 44 times
# a (DET): 35 times
# , (PUNCT): 33 times
# I (PRON): 21 times
# of (ADP): 20 times
# is (AUX): 19 times
# with (ADP): 14 times
# to (PART): 13 times
#
# ========================================
#
# Movie ID: tt0099052 - Most Common POS Tags:
# , (PUNCT): 73 times
# . (PUNCT): 59 times
# the (DET): 59 times
# a (DET): 53 times
# and (CCONJ): 35 times
# of (ADP): 28 times
# I (PRON): 26 times
# is (AUX): 24 times
# in (ADP): 23 times
# it (PRON): 22 times
#
# ========================================
#
# Movie ID: tt0099077 - Most Common POS Tags:
# . (PUNCT): 43 times
# a (DET): 24 times
# , (PUNCT): 20 times
# the (DET): 19 times
# I (PRON): 14 times
# of (ADP): 13 times
# it (PRON): 12 times
# in (ADP): 11 times
# and (CCONJ): 11 times
#   (SPACE): 11 times
#
# ========================================
#
# Movie ID: tt0099088 - Most Common POS Tags:
# the (DET): 66 times
# . (PUNCT): 41 times
# and (CCONJ): 34 times
# of (ADP): 32 times
# , (PUNCT): 31 times
# I (PRON): 20 times
# a (DET): 20 times
# to (ADP): 19 times
# is (AUX): 15 times
# in (ADP): 15 times
#
# ========================================
#
# Movie ID: tt0099253 - Most Common POS Tags:
# . (PUNCT): 36 times
# the (DET): 31 times
# , (PUNCT): 28 times
# and (CCONJ): 22 times
# a (DET): 22 times
# I (PRON): 19 times
# 's (PART): 16 times
# was (AUX): 16 times
# film (NOUN): 16 times
# in (ADP): 14 times
#
# ========================================
#
# Movie ID: tt0099329 - Most Common POS Tags:
# the (DET): 57 times
# . (PUNCT): 40 times
# , (PUNCT): 35 times
# and (CCONJ): 34 times
# of (ADP): 34 times
# a (DET): 31 times
# movie (NOUN): 21 times
# is (AUX): 20 times
# it (PRON): 16 times
# to (PART): 12 times
#
# ========================================
#
# Movie ID: tt0099348 - Most Common POS Tags:
# . (PUNCT): 28 times
# the (DET): 27 times
# I (PRON): 18 times
# , (PUNCT): 18 times
# and (CCONJ): 17 times
# of (ADP): 17 times
# a (DET): 13 times
# it (PRON): 12 times
# in (ADP): 10 times
# this (DET): 10 times
#
# ========================================
#
# Movie ID: tt0099365 - Most Common POS Tags:
# . (PUNCT): 72 times
# the (DET): 70 times
# , (PUNCT): 65 times
# and (CCONJ): 45 times
# of (ADP): 44 times
# a (DET): 36 times
# is (AUX): 29 times
# to (PART): 28 times
# his (PRON): 27 times
# in (ADP): 21 times
#
# ========================================
#
# Movie ID: tt0099422 - Most Common POS Tags:
# , (PUNCT): 89 times
# the (DET): 74 times
# a (DET): 49 times
# . (PUNCT): 48 times
# and (CCONJ): 36 times
# to (PART): 31 times
# of (ADP): 30 times
# is (AUX): 29 times
# Tracy (PROPN): 21 times
# to (ADP): 16 times
#
# ========================================
#
# Movie ID: tt0099423 - Most Common POS Tags:
# the (DET): 50 times
# , (PUNCT): 42 times
# . (PUNCT): 41 times
# " (PUNCT): 40 times
# and (CCONJ): 32 times
# a (DET): 28 times
# I (PRON): 17 times
# of (ADP): 17 times
# his (PRON): 17 times
# in (ADP): 16 times
#
# ========================================
#
# Movie ID: tt0099487 - Most Common POS Tags:
# , (PUNCT): 122 times
# . (PUNCT): 107 times
# the (DET): 96 times
# a (DET): 56 times
# is (AUX): 56 times
# of (ADP): 54 times
# and (CCONJ): 53 times
# to (PART): 35 times
# Edward (PROPN): 29 times
# his (PRON): 26 times
#
# ========================================
#
# Movie ID: tt0099566 - Most Common POS Tags:
# , (PUNCT): 68 times
# . (PUNCT): 63 times
# the (DET): 49 times
# a (DET): 44 times
# of (ADP): 32 times
# in (ADP): 24 times
# and (CCONJ): 21 times
# to (PART): 20 times
# " (PUNCT): 15 times
# his (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0099582 - Most Common POS Tags:
# the (DET): 32 times
# . (PUNCT): 32 times
# , (PUNCT): 32 times
# a (DET): 25 times
# is (AUX): 22 times
# of (ADP): 19 times
# and (CCONJ): 16 times
# with (ADP): 12 times
# to (PART): 11 times
# to (ADP): 10 times
#
# ========================================
#
# Movie ID: tt0099653 - Most Common POS Tags:
# the (DET): 74 times
# . (PUNCT): 72 times
# , (PUNCT): 67 times
# and (CCONJ): 53 times
# of (ADP): 51 times
# a (DET): 41 times
# I (PRON): 34 times
# is (AUX): 33 times
# in (ADP): 22 times
# to (PART): 22 times
#
# ========================================
#
# Movie ID: tt0099674 - Most Common POS Tags:
# the (DET): 93 times
# . (PUNCT): 73 times
# , (PUNCT): 70 times
# of (ADP): 45 times
# a (DET): 45 times
# and (CCONJ): 42 times
# is (AUX): 41 times
# to (PART): 29 times
# in (ADP): 26 times
# it (PRON): 24 times
#
# ========================================
#
# Movie ID: tt0099685 - Most Common POS Tags:
# . (PUNCT): 46 times
# , (PUNCT): 39 times
# is (AUX): 30 times
# the (DET): 29 times
# and (CCONJ): 25 times
# a (DET): 24 times
# in (ADP): 20 times
# of (ADP): 17 times
# I (PRON): 15 times
# it (PRON): 14 times
#
# ========================================
#
# Movie ID: tt0099731 - Most Common POS Tags:
# . (PUNCT): 39 times
# the (DET): 35 times
# , (PUNCT): 31 times
# is (AUX): 28 times
# of (ADP): 28 times
# in (ADP): 20 times
# and (CCONJ): 18 times
# a (DET): 15 times
# ( (PUNCT): 14 times
# ) (PUNCT): 13 times
#
# ========================================
#
# Movie ID: tt0099739 - Most Common POS Tags:
# , (PUNCT): 62 times
# . (PUNCT): 56 times
# the (DET): 53 times
# and (CCONJ): 52 times
# a (DET): 39 times
# of (ADP): 34 times
# in (ADP): 29 times
# is (AUX): 26 times
# to (PART): 23 times
# Seagal (PROPN): 22 times
#
# ========================================
#
# Movie ID: tt0099785 - Most Common POS Tags:
# the (DET): 50 times
# * (PUNCT): 47 times
# , (PUNCT): 44 times
# . (PUNCT): 40 times
# and (CCONJ): 29 times
# is (AUX): 27 times
# I (PRON): 24 times
# of (ADP): 19 times
# a (DET): 18 times
# his (PRON): 16 times
#
# ========================================
#
# Movie ID: tt0099810 - Most Common POS Tags:
# , (PUNCT): 51 times
# the (DET): 48 times
# . (PUNCT): 41 times
# a (DET): 30 times
# and (CCONJ): 25 times
# of (ADP): 24 times
# - (PUNCT): 18 times
# is (AUX): 17 times
# in (ADP): 16 times
# for (ADP): 10 times
#
# ========================================
#
# Movie ID: tt0099871 - Most Common POS Tags:
# . (PUNCT): 84 times
# the (DET): 78 times
# , (PUNCT): 56 times
# of (ADP): 35 times
# you (PRON): 32 times
# is (AUX): 31 times
# a (DET): 30 times
# to (PART): 30 times
# in (ADP): 27 times
# and (CCONJ): 25 times
#
# ========================================
#
# Movie ID: tt0099938 - Most Common POS Tags:
# , (PUNCT): 50 times
# a (DET): 30 times
# . (PUNCT): 30 times
# the (DET): 25 times
# and (CCONJ): 23 times
# is (AUX): 17 times
# it (PRON): 13 times
# to (PART): 13 times
# I (PRON): 12 times
# ! (PUNCT): 12 times
#
# ========================================
#
# Movie ID: tt0100029 - Most Common POS Tags:
# the (DET): 31 times
# a (DET): 24 times
# . (PUNCT): 20 times
# , (PUNCT): 16 times
# is (AUX): 16 times
# of (ADP): 14 times
# in (ADP): 13 times
# and (CCONJ): 13 times
# ? (PUNCT): 11 times
# Van (PROPN): 10 times
#
# ========================================
#
# Movie ID: tt0100140 - Most Common POS Tags:
# , (PUNCT): 77 times
# the (DET): 72 times
# and (CCONJ): 63 times
# . (PUNCT): 41 times
# a (DET): 35 times
# is (AUX): 32 times
# to (PART): 27 times
# of (ADP): 27 times
# she (PRON): 22 times
# her (PRON): 22 times
#
# ========================================
#
# Movie ID: tt0100150 - Most Common POS Tags:
# . (PUNCT): 49 times
# a (DET): 36 times
# , (PUNCT): 30 times
# the (DET): 29 times
# of (ADP): 22 times
# it (PRON): 21 times
# and (CCONJ): 18 times
# is (AUX): 16 times
# Tom (PROPN): 14 times
# movie (NOUN): 12 times
#
# ========================================
#
# Movie ID: tt0100157 - Most Common POS Tags:
# , (PUNCT): 86 times
# the (DET): 79 times
# . (PUNCT): 66 times
# a (DET): 55 times
# I (PRON): 38 times
# is (AUX): 32 times
# and (CCONJ): 31 times
# of (ADP): 28 times
# in (ADP): 24 times
# to (PART): 22 times
#
# ========================================
#
# Movie ID: tt0100403 - Most Common POS Tags:
# . (PUNCT): 39 times
# the (DET): 38 times
# Predator (PROPN): 19 times
# , (PUNCT): 15 times
# a (DET): 14 times
# of (ADP): 12 times
# in (ADP): 11 times
# this (DET): 11 times
# to (PART): 11 times
# movie (NOUN): 10 times
#
# ========================================
#
# Movie ID: tt0100404 - Most Common POS Tags:
# . (PUNCT): 38 times
# the (DET): 37 times
# , (PUNCT): 32 times
# is (AUX): 18 times
# a (DET): 18 times
# movie (NOUN): 13 times
# it (PRON): 11 times
# - (PUNCT): 10 times
# and (CCONJ): 9 times
# that (SCONJ): 9 times
#
# ========================================
#
# Movie ID: tt0100405 - Most Common POS Tags:
# , (PUNCT): 105 times
# the (DET): 54 times
# and (CCONJ): 45 times
# . (PUNCT): 42 times
# a (DET): 34 times
# to (PART): 33 times
# is (AUX): 33 times
# he (PRON): 28 times
# her (PRON): 23 times
# she (PRON): 23 times
#
# ========================================
#
# Movie ID: tt0100419 - Most Common POS Tags:
# a (DET): 32 times
# . (PUNCT): 31 times
# , (PUNCT): 26 times
# and (CCONJ): 21 times
# the (DET): 19 times
# I (PRON): 14 times
# movie (NOUN): 14 times
# to (PART): 12 times
# it (PRON): 11 times
# of (ADP): 10 times
#
# ========================================
#
# Movie ID: tt0100502 - Most Common POS Tags:
# the (DET): 97 times
# . (PUNCT): 76 times
# , (PUNCT): 65 times
# is (AUX): 44 times
# of (ADP): 43 times
# and (CCONJ): 40 times
# a (DET): 39 times
# it (PRON): 32 times
# film (NOUN): 28 times
# to (PART): 25 times
#
# ========================================
#
# Movie ID: tt0100507 - Most Common POS Tags:
# the (DET): 128 times
# . (PUNCT): 113 times
# , (PUNCT): 90 times
# Rocky (PROPN): 89 times
# and (CCONJ): 54 times
# a (DET): 37 times
# his (PRON): 35 times
# to (PART): 34 times
# is (AUX): 34 times
# of (ADP): 33 times
#
# ========================================
#
# Movie ID: tt0100758 - Most Common POS Tags:
# , (PUNCT): 55 times
# the (DET): 48 times
# . (PUNCT): 38 times
# " (PUNCT): 35 times
# a (DET): 31 times
# and (CCONJ): 27 times
# of (ADP): 22 times
# is (AUX): 17 times
# it (PRON): 15 times
# movie (NOUN): 14 times
#
# ========================================
#
# Movie ID: tt0100802 - Most Common POS Tags:
# the (DET): 61 times
# , (PUNCT): 45 times
# and (CCONJ): 44 times
# . (PUNCT): 40 times
# of (ADP): 39 times
# a (DET): 34 times
# - (PUNCT): 24 times
# " (PUNCT): 23 times
# it (PRON): 22 times
# is (AUX): 19 times
#
# ========================================
#
# Movie ID: tt0100814 - Most Common POS Tags:
# , (PUNCT): 46 times
# the (DET): 42 times
# . (PUNCT): 37 times
# and (CCONJ): 31 times
# a (DET): 16 times
# " (PUNCT): 16 times
# to (PART): 13 times
# of (ADP): 13 times
# in (ADP): 12 times
# is (AUX): 12 times
#
# ========================================
#
# Movie ID: tt0100935 - Most Common POS Tags:
# . (PUNCT): 95 times
# , (PUNCT): 64 times
# the (DET): 58 times
# and (CCONJ): 39 times
# a (DET): 39 times
# of (ADP): 38 times
# is (AUX): 33 times
# to (PART): 22 times
# 's (PART): 20 times
# at (ADP): 19 times
#
# ========================================
#
# Movie ID: tt0101272 - Most Common POS Tags:
# , (PUNCT): 77 times
# . (PUNCT): 49 times
# the (DET): 46 times
# and (CCONJ): 33 times
# of (ADP): 24 times
# a (DET): 20 times
# is (AUX): 17 times
# Addams (PROPN): 16 times
# ( (PUNCT): 15 times
# The (DET): 15 times
#
# ========================================
#
# Movie ID: tt0101316 - Most Common POS Tags:
# the (DET): 63 times
# . (PUNCT): 53 times
# and (CCONJ): 49 times
# , (PUNCT): 45 times
# of (ADP): 33 times
# her (PRON): 26 times
# I (PRON): 24 times
# is (AUX): 24 times
# to (PART): 23 times
# it (PRON): 21 times
#
# ========================================
#
# Movie ID: tt0101393 - Most Common POS Tags:
# . (PUNCT): 58 times
# , (PUNCT): 57 times
# the (DET): 57 times
# and (CCONJ): 30 times
# is (AUX): 24 times
# a (DET): 23 times
# of (ADP): 18 times
# I (PRON): 17 times
# in (ADP): 16 times
# Backdraft (PROPN): 15 times
#
# ========================================
#
# Movie ID: tt0101410 - Most Common POS Tags:
# . (PUNCT): 64 times
# the (DET): 62 times
# a (DET): 41 times
# and (CCONJ): 40 times
# is (AUX): 37 times
# of (ADP): 34 times
# , (PUNCT): 33 times
# to (PART): 21 times
# in (ADP): 19 times
# it (PRON): 19 times
#
# ========================================
#
# Movie ID: tt0101414 - Most Common POS Tags:
# , (PUNCT): 81 times
# the (DET): 73 times
# . (PUNCT): 65 times
# and (CCONJ): 41 times
# I (PRON): 32 times
# of (ADP): 27 times
# a (DET): 26 times
# in (ADP): 24 times
# was (AUX): 18 times
# is (AUX): 13 times
#
# ========================================
#
# Movie ID: tt0101507 - Most Common POS Tags:
# the (DET): 112 times
# , (PUNCT): 87 times
# . (PUNCT): 67 times
# and (CCONJ): 60 times
# of (ADP): 53 times
# a (DET): 36 times
# to (PART): 35 times
# is (AUX): 34 times
# in (ADP): 26 times
# his (PRON): 21 times
#
# ========================================
#
# Movie ID: tt0101516 - Most Common POS Tags:
# , (PUNCT): 112 times
# the (DET): 84 times
# . (PUNCT): 60 times
# and (CCONJ): 53 times
# of (ADP): 41 times
# a (DET): 35 times
# is (AUX): 31 times
# his (PRON): 21 times
# ' (PUNCT): 21 times
# Bugsy (PROPN): 19 times
#
# ========================================
#
# Movie ID: tt0101540 - Most Common POS Tags:
# . (PUNCT): 62 times
# the (DET): 55 times
# a (DET): 34 times
# and (CCONJ): 33 times
# , (PUNCT): 28 times
# - (PUNCT): 27 times
# is (AUX): 24 times
# in (ADP): 24 times
# of (ADP): 21 times
# it (PRON): 17 times
#
# ========================================
#
# Movie ID: tt0101545 - Most Common POS Tags:
# , (PUNCT): 76 times
# the (DET): 73 times
# . (PUNCT): 71 times
# and (CCONJ): 45 times
# of (ADP): 32 times
# to (PART): 28 times
# a (DET): 24 times
# with (ADP): 23 times
# Jim (PROPN): 22 times
# you (PRON): 21 times
#
# ========================================
#
# Movie ID: tt0101587 - Most Common POS Tags:
# . (PUNCT): 69 times
# , (PUNCT): 69 times
# the (DET): 37 times
# a (DET): 31 times
# is (AUX): 23 times
# and (CCONJ): 23 times
# I (PRON): 16 times
# of (ADP): 16 times
# " (PUNCT): 15 times
# to (PART): 13 times
#
# ========================================
#
# Movie ID: tt0101635 - Most Common POS Tags:
# . (PUNCT): 73 times
# , (PUNCT): 63 times
# the (DET): 55 times
# I (PRON): 39 times
# and (CCONJ): 39 times
# a (DET): 37 times
# of (ADP): 30 times
# it (PRON): 25 times
# is (AUX): 25 times
# to (PART): 24 times
#
# ========================================
#
# Movie ID: tt0101745 - Most Common POS Tags:
# , (PUNCT): 56 times
# the (DET): 40 times
# a (DET): 35 times
# . (PUNCT): 28 times
# and (CCONJ): 27 times
# of (ADP): 16 times
# as (ADP): 16 times
# I (PRON): 14 times
# - (PUNCT): 13 times
# in (ADP): 12 times
#
# ========================================
#
# Movie ID: tt0101757 - Most Common POS Tags:
# . (PUNCT): 85 times
# a (DET): 60 times
# the (DET): 58 times
# , (PUNCT): 50 times
# and (CCONJ): 43 times
# is (AUX): 30 times
# of (ADP): 28 times
# to (PART): 27 times
# " (PUNCT): 25 times
# she (PRON): 23 times
#
# ========================================
#
# Movie ID: tt0101761 - Most Common POS Tags:
# the (DET): 55 times
# . (PUNCT): 50 times
# , (PUNCT): 44 times
# and (CCONJ): 37 times
# a (DET): 29 times
# of (ADP): 27 times
# is (AUX): 21 times
# The (DET): 16 times
# I (PRON): 15 times
# in (ADP): 15 times
#
# ========================================
#
# Movie ID: tt0101775 - Most Common POS Tags:
# the (DET): 30 times
# . (PUNCT): 29 times
# is (AUX): 25 times
# and (CCONJ): 24 times
# I (PRON): 22 times
# , (PUNCT): 22 times
# of (ADP): 20 times
# a (DET): 15 times
# to (PART): 14 times
# her (PRON): 13 times
#
# ========================================
#
# Movie ID: tt0101862 - Most Common POS Tags:
# , (PUNCT): 56 times
# the (DET): 30 times
# and (CCONJ): 25 times
# . (PUNCT): 22 times
# a (DET): 19 times
# to (PART): 11 times
# in (ADP): 11 times
# it (PRON): 11 times
# you (PRON): 10 times
# n't (PART): 9 times
#
# ========================================
#
# Movie ID: tt0101889 - Most Common POS Tags:
# , (PUNCT): 52 times
# the (DET): 49 times
# . (PUNCT): 25 times
# a (DET): 23 times
# of (ADP): 19 times
# and (CCONJ): 14 times
# in (ADP): 13 times
# to (PART): 11 times
# is (AUX): 11 times
# ! (PUNCT): 9 times
#
# ========================================
#
# Movie ID: tt0102057 - Most Common POS Tags:
# . (PUNCT): 47 times
# , (PUNCT): 29 times
# and (CCONJ): 23 times
# of (ADP): 22 times
# the (DET): 22 times
# a (DET): 20 times
# is (AUX): 17 times
# I (PRON): 16 times
# movie (NOUN): 12 times
#   (SPACE): 12 times
#
# ========================================
#
# Movie ID: tt0102070 - Most Common POS Tags:
# the (DET): 58 times
# . (PUNCT): 51 times
# , (PUNCT): 49 times
# and (CCONJ): 27 times
# of (ADP): 26 times
# a (DET): 26 times
# to (PART): 23 times
# I (PRON): 22 times
# movie (NOUN): 17 times
# it (PRON): 16 times
#
# ========================================
#
# Movie ID: tt0102138 - Most Common POS Tags:
# the (DET): 66 times
# . (PUNCT): 49 times
# of (ADP): 32 times
# , (PUNCT): 28 times
# and (CCONJ): 24 times
# ' (PUNCT): 24 times
# is (AUX): 20 times
# in (ADP): 20 times
# to (PART): 17 times
# ...
#
# Movie ID: tt2404233 - Most Common PERSON Entities:
# Ra: 36 times
# Set: 24 times
# Thoth: 24 times
# Horus: 20 times
# Osiris: 12 times
#
# ========================================
#
# Movie ID: tt2404435 - Most Common PERSON Entities:
# Chisolm: 92 times
# Robicheaux: 52 times
# Emma: 44 times
# Teddy: 20 times
# Horne: 20 times
#
# ========================================
#
# Movie ID: tt2404463 - Most Common PERSON Entities:
# Ashburn: 104 times
# Larkin: 100 times
# Mullins: 96 times
# Jason: 56 times
# Adam: 16 times
#
# ========================================
#
# Movie ID: tt2488496 - Most Common PERSON Entities:
# Rey: 200 times
# Finn: 168 times
# Jakku: 52 times
# Kylo Ren: 40 times
# Poe: 40 times
#
# ========================================
#
# Movie ID: tt2527336 - Most Common PERSON Entities:
# Luke: 128 times
# Rey: 96 times
# Finn: 80 times
# Rose: 48 times
# Poe: 20 times
#
# ========================================
#
# Movie ID: tt2543164 - Most Common PERSON Entities:
# Louise: 96 times
# Ian: 40 times
# Hannah: 32 times
# Shang: 16 times
# Weber: 12 times
#
# ========================================
#
# Movie ID: tt2554274 - Most Common PERSON Entities:
# Edith: 84 times
# Thomas: 48 times
# Thomas Sharpe: 12 times
# Lady Lucille Sharpe: 12 times
# McMichael: 12 times
#
# ========================================
#
# Movie ID: tt2562232 - Most Common PERSON Entities:
# Riggan: 232 times
# Mike: 160 times
# Sam: 56 times
# Ralph: 20 times
# Laura: 20 times
#
# ========================================
#
# Movie ID: tt2582782 - Most Common PERSON Entities:
# Alberto: 40 times
# Toby: 12 times
# Tanner Howard: 8 times
# Toby Howard: 8 times
# Ben Foster: 4 times
#
# ========================================
#
# Movie ID: tt2582802 - Most Common PERSON Entities:
# Andrew: 236 times
# Fletcher: 148 times
# Nicole: 12 times
# Caravan: 12 times
# Ryan: 12 times
#
# ========================================
#
# Movie ID: tt2582846 - Most Common PERSON Entities:
# Hazel: 344 times
# Gus: 280 times
# Van Houten: 56 times
# Isaac: 40 times
# Monica: 20 times
#
# ========================================
#
# Movie ID: tt2632424 - Most Common PERSON Entities:
# Klaus: 20 times
# Mikaelson: 8 times
# Rebekah: 8 times
# Joseph Morgan: 4 times
# Charles Michael Davis: 4 times
#
# ========================================
#
# Movie ID: tt2660888 - Most Common PERSON Entities:
# Kirk: 120 times
# Krall: 72 times
# Spock: 48 times
# Jaylah: 36 times
# Abronath: 32 times
#
# ========================================
#
# Movie ID: tt2661044 - Most Common PERSON Entities:
# Clark: 40 times
# Ark: 12 times
# Wells: 8 times
# Chancelor: 8 times
# Tabia Blake's: 4 times
#
# ========================================
#
# Movie ID: tt2674426 - Most Common PERSON Entities:
# Lou: 648 times
# Will: 244 times
# Patrick: 60 times
# Nathan: 60 times
# Alicia: 40 times
#
# ========================================
#
# Movie ID: tt2692250 - Most Common PERSON Entities:
# Larry: 132 times
# Octavius: 36 times
# Ahkmenrah: 36 times
# Jed: 28 times
# Lancelot: 24 times
#
# ========================================
#
# Movie ID: tt2713180 - Most Common PERSON Entities:
# Ellison: 248 times
# Emma: 56 times
# Gordo: 32 times
# Irma: 16 times
# Waggoner: 12 times
#
# ========================================
#
# Movie ID: tt2719848 - Most Common PERSON Entities:
# Rob: 120 times
# Beck: 48 times
# Doug: 40 times
# Andy: 20 times
# Helen: 16 times
#
# ========================================
#
# Movie ID: tt2802144 - Most Common PERSON Entities:
# Valentine: 212 times
# Harry: 200 times
# Arthur: 96 times
# Roxy: 56 times
# Dean: 48 times
#
# ========================================
#
# Movie ID: tt2820852 - Most Common PERSON Entities:
# Brian: 80 times
# Ramsey: 52 times
# Shaw: 44 times
# Mia: 36 times
# Jack: 16 times
#
# ========================================
#
# Movie ID: tt2848292 - Most Common PERSON Entities:
# Fat Amy: 32 times
# Beca: 28 times
# Bella: 28 times
# Chloe: 16 times
# Jesse: 16 times
#
# ========================================
#
# Movie ID: tt2872718 - Most Common PERSON Entities:
# Lou: 212 times
# Rick: 84 times
# Frank: 12 times
# Jake Gyllenhaal: 8 times
# Rene Russo: 8 times
#
# ========================================
#
# Movie ID: tt2872732 - Most Common PERSON Entities:
# Lucy: 160 times
# Jang: 80 times
# Norman: 24 times
# Richard: 16 times
# Pierre Del Rio: 8 times
#
# ========================================
#
# Movie ID: tt2911666 - Most Common PERSON Entities:
# John: 260 times
# Iosef: 48 times
# Viggo: 32 times
# Daisy: 24 times
# Aurelio: 16 times
#
# ========================================
#
# Movie ID: tt2948356 - Most Common PERSON Entities:
# Judy: 508 times
# Nick: 108 times
# Bellwether: 72 times
# Otterton: 44 times
# Manchas: 44 times
#
# ========================================
#
# Movie ID: tt2975590 - Most Common PERSON Entities:
# Superman: 80 times
# Luthor: 32 times
# Martha: 16 times
# Clark: 16 times
# Wayne: 12 times
#
# ========================================
#
# Movie ID: tt2980516 - Most Common PERSON Entities:
# Jane: 60 times
# Stephen: 28 times
# Jonathan: 24 times
# Stephen Hawking: 12 times
# Jane Wilde: 8 times
#
# ========================================
#
# Movie ID: tt3076658 - Most Common PERSON Entities:
# Donnie: 224 times
# Conlan: 40 times
# Rocky: 20 times
# Wheeler: 12 times
# Pete: 12 times
#
# ========================================
#
# Movie ID: tt3079380 - Most Common PERSON Entities:
# Cooper: 104 times
# Boyanov: 80 times
# De Luca: 44 times
# Nancy: 28 times
# Renaldo: 16 times
#
# ========================================
#
# Movie ID: tt3152624 - Most Common PERSON Entities:
# Amy: 232 times
# Aaron: 136 times
# Kim: 76 times
# Gordon: 44 times
# Steven: 24 times
#
# ========================================
#
# Movie ID: tt3170832 - Most Common PERSON Entities:
# Jack: 416 times
# Ma: 208 times
# Nick: 48 times
# Old Nick: 24 times
# Grandma: 8 times
#
# ========================================
#
# Movie ID: tt3183660 - Most Common PERSON Entities:
# Newt: 220 times
# Jacob: 160 times
# Tina: 96 times
# Graves: 36 times
# Queenie: 36 times
#
# ========================================
#
# Movie ID: tt3205802 - Most Common PERSON Entities:
# Wes: 32 times
# Sam: 32 times
# Keating: 24 times
# Lila: 24 times
# Sam Keating: 12 times
#
# ========================================
#
# Movie ID: tt3235888 - Most Common PERSON Entities:
# Jay: 160 times
# Hugh: 44 times
# Paul: 40 times
# Greg: 36 times
# Kelly: 8 times
#
# ========================================
#
# Movie ID: tt3315342 - Most Common PERSON Entities:
# Laura: 132 times
# Gabriela: 44 times
# Rice: 24 times
# Kathryn: 16 times
# Pierce: 12 times
#
# ========================================
#
# Movie ID: tt3322364 - Most Common PERSON Entities:
# Webster: 24 times
# Cyril: 12 times
# Bennet Omalu: 8 times
# Will Smith: 8 times
# Cyril Wecht: 8 times
#
# ========================================
#
# Movie ID: tt3332064 - Most Common PERSON Entities:
# Peter: 160 times
# Tiger Lily: 28 times
# Mary: 24 times
# Smee: 16 times
# Barnabas: 12 times
#
# ========================================
#
# Movie ID: tt3385516 - Most Common PERSON Entities:
# Charles: 108 times
# Erik: 68 times
# Jean: 56 times
# Angel: 44 times
# Raven: 28 times
#
# ========================================
#
# Movie ID: tt3397884 - Most Common PERSON Entities:
# Kate: 104 times
# Diaz: 44 times
# Silvio: 40 times
# Matt: 28 times
# Ted: 28 times
#
# ========================================
#
# Movie ID: tt3402236 - Most Common PERSON Entities:
# Poirot: 104 times
# Ratchett: 40 times
# Bouc: 28 times
# Daisy Armstrong: 20 times
# Daisy: 20 times
#
# ========================================
#
# Movie ID: tt3416742 - Most Common PERSON Entities:
# Stu: 36 times
# Vladislav: 20 times
# Jackie: 16 times
# Nick: 8 times
# Petyr: 4 times
#
# ========================================
#
# Movie ID: tt3460252 - Most Common PERSON Entities:
# Warren: 244 times
# Mannix: 216 times
# Ruth: 192 times
# Daisy: 92 times
# Sanford: 56 times
#
# ========================================
#
# Movie ID: tt3464902 - Most Common PERSON Entities:
# David: 108 times
# John: 24 times
# Maid: 20 times
# Robert: 12 times
# Elizabeth: 8 times
#
# ========================================
#
# Movie ID: tt3470600 - Most Common PERSON Entities:
# Buster: 84 times
# Johnny: 56 times
# Mike: 56 times
# Crawley: 24 times
# Eddie: 20 times
#
# ========================================
#
# Movie ID: tt3498820 - Most Common PERSON Entities:
# Cap: 116 times
# Steve: 76 times
# Tony: 56 times
# Bucky: 52 times
# Panther: 36 times
#
# ========================================
#
# Movie ID: tt3501632 - Most Common PERSON Entities:
# Thor: 100 times
# Hela: 64 times
# Loki: 60 times
# Valkyrie: 36 times
# Grandmaster: 24 times
#
# ========================================
#
# Movie ID: tt3521164 - Most Common PERSON Entities:
# Moana: 320 times
# Maui: 76 times
# Te Ka: 56 times
# Tui: 36 times
# Tala: 24 times
#
# ========================================
#
# Movie ID: tt3530002 - Most Common PERSON Entities:
# Isaac: 112 times
# Ethan: 108 times
# Chris: 80 times
# Betsy: 48 times
# Green: 40 times
#
# ========================================
#
# Movie ID: tt3532216 - Most Common PERSON Entities:
# Barry: 180 times
# Lucy: 32 times
# Schafer: 20 times
# Barry Seal: 8 times
# Tom Cruise: 4 times
#
# ========================================
#
# Movie ID: tt3631112 - Most Common PERSON Entities:
# Rachel: 332 times
# Tom: 176 times
# Megan: 140 times
# Anna: 92 times
# Martha: 32 times
#
# ========================================
#
# Movie ID: tt3640424 - Most Common PERSON Entities:
# Max: 184 times
# Marianne: 128 times
# Paul: 36 times
# Anna: 24 times
# Frank: 20 times
#
# ========================================
#
# Movie ID: tt3647998 - Most Common PERSON Entities:
# James Keziah Delaney: 7 times
# Adventurer James Keziah Delaney: 1 times
#
# ========================================
#
# Movie ID: tt3659388 - Most Common PERSON Entities:
# Watney: 48 times
# Lewis: 20 times
# Mark Watney: 16 times
# Martinez: 16 times
# Pathfinder: 16 times
#
# ========================================
#
# Movie ID: tt3682448 - Most Common PERSON Entities:
# Donovan: 108 times
# Abel: 64 times
# Pryor: 24 times
# Rudolf Abel: 12 times
# James B. Donovan: 12 times
#
# ========================================
#
# Movie ID: tt3741834 - Most Common PERSON Entities:
# Saroo: 196 times
# Mantosh: 32 times
# Lucy: 32 times
# Sue: 16 times
# John: 16 times
#
# ========================================
#
# Movie ID: tt3748528 - Most Common PERSON Entities:
# Galen: 20 times
# Lyra: 16 times
# Jyn: 12 times
# Jyn Erso: 4 times
# Beau Gadsdon: 4 times
#
# ========================================
#
# Movie ID: tt3783958 - Most Common PERSON Entities:
# Mia: 380 times
# Sebastian: 300 times
# Keith: 40 times
# David: 40 times
# Greg: 16 times
#
# ========================================
#
# Movie ID: tt3850590 - Most Common PERSON Entities:
# Max: 100 times
# Sarah: 76 times
# Tom: 72 times
# Krampus: 68 times
# Beth: 56 times
#
# ========================================
#
# Movie ID: tt3896198 - Most Common PERSON Entities:
# Peter: 148 times
# Gamora: 80 times
# Yondu: 76 times
# Ego: 64 times
# Drax: 40 times
#
# ========================================
#
# Movie ID: tt4016934 - Most Common PERSON Entities:
# Sook-Hee: 368 times
# Lady: 84 times
# Lady Hideko: 80 times
# Count Fujiwara: 48 times
# Ben: 16 times
#
# ========================================
#
# Movie ID: tt4034228 - Most Common PERSON Entities:
# Lee: 528 times
# Patrick: 460 times
# Joe: 100 times
# George: 60 times
# Randi: 40 times
#
# ========================================
#
# Movie ID: tt4046784 - Most Common PERSON Entities:
# Thomas: 140 times
# Brenda: 56 times
# Janson: 40 times
# Gladers: 20 times
# Newt: 12 times
#
# ========================================
#
# Movie ID: tt4263482 - Most Common PERSON Entities:
# William: 44 times
# Katherine: 32 times
# Sam: 32 times
# Jonas: 20 times
# Samuel: 12 times
#
# ========================================
#
# Movie ID: tt4501244 - Most Common PERSON Entities:
# Laird: 228 times
# Ned: 152 times
# Stephanie: 60 times
# Barb: 20 times
# Scotty: 16 times
#
# ========================================
#
# Movie ID: tt4550098 - Most Common PERSON Entities:
# Tony: 372 times
# Susan: 204 times
# Bobby: 128 times
# Ray: 124 times
# Edward: 100 times
#
# ========================================
#
# Movie ID: tt4555426 - Most Common PERSON Entities:
# Churchill: 144 times
# Elizabeth: 32 times
# George: 12 times
# Hitler: 12 times
# Neville Chamberlain: 8 times
#
# ========================================
#
# Movie ID: tt4574334 - Most Common PERSON Entities:
# Mike: 340 times
# Joyce: 296 times
# Jonathan: 292 times
# Nancy: 244 times
# Will: 140 times
#
# ========================================
#
# Movie ID: tt4622512 - Most Common PERSON Entities:
# Bobby: 108 times
# Billie Jean: 64 times
# Marilyn: 36 times
# Larry: 28 times
# Priscilla: 20 times
#
# ========================================
#
# Movie ID: tt4649466 - Most Common PERSON Entities:
# Harry: 124 times
# Charlie: 76 times
# Poppy: 48 times
# Tequila: 44 times
# Tilde: 32 times
#
# ========================================
#
# Movie ID: tt4651520 - Most Common PERSON Entities:
# Amy: 268 times
# Gwendolyn: 72 times
# Jane: 68 times
# Carla: 52 times
# Mike: 48 times
#
# ========================================
#
# Movie ID: tt4682786 - Most Common PERSON Entities:
# Howard: 232 times
# Simon: 84 times
# Claire: 72 times
# Whit: 56 times
# Amy: 44 times
#
# ========================================
#
# Movie ID: tt4731136 - Most Common PERSON Entities:
# Hannah: 88 times
# Lockhart: 72 times
# Pembroke: 16 times
# Watkins: 12 times
# Morris: 8 times
#
# ========================================
#
# Movie ID: tt4765284 - Most Common PERSON Entities:
# Fat Amy: 28 times
# Beca: 14 times
# Aubrey: 10 times
# Theo: 10 times
# John: 8 times
#
# ========================================
#
# Movie ID: tt4846340 - Most Common PERSON Entities:
# Katherine: 160 times
# Dorothy: 92 times
# Mary: 48 times
# Al: 40 times
# Glenn: 40 times
#
# ========================================
#
# Movie ID: tt4925292 - Most Common PERSON Entities:
# Lady Bird: 124 times
# Marion: 24 times
# Kyle: 24 times
# Julie: 20 times
# Jenna: 16 times
#
# ========================================
#
# Movie ID: tt4972582 - Most Common PERSON Entities:
# Casey: 136 times
# Kevin: 72 times
# Karen: 72 times
# Claire: 64 times
# Marcia: 52 times
#
# ========================================
#
# Movie ID: tt4975722 - Most Common PERSON Entities:
# Kevin: 120 times
# Juan: 76 times
# Paula: 40 times
# Terrel: 24 times
# Samantha: 8 times
#
# ========================================
#
# Movie ID: tt5013056 - Most Common PERSON Entities:
# Gibson: 36 times
# Alex: 36 times
# Peter: 36 times
# Tommy: 32 times
# Dawson: 28 times
#
# ========================================
#
# Movie ID: tt5027774 - Most Common PERSON Entities:
# Dixon: 80 times
# Willoughby: 48 times
# Angela: 44 times
# Robbie: 36 times
# Charlie: 32 times
#
# ========================================
#
# Movie ID: tt5052448 - Most Common PERSON Entities:
# Chris: 344 times
# Rose: 88 times
# Dean: 60 times
# Missy: 44 times
# Jeremy: 40 times
#
# ========================================
#
# Movie ID: tt5074352 - Most Common PERSON Entities:
# Geeta: 84 times
# Mahavir: 76 times
# Babita: 40 times
# Mahavir Singh Phogat: 12 times
# Babita Kumari: 8 times
#
# ========================================
#
# Movie ID: tt5109784 - Most Common PERSON Entities:
# Mother: 12 times
# Javier Bardem: 4 times
# Jennifer Lawrence: 4 times
# Ed Harris: 4 times
# Michelle Pfeiffer: 4 times
#
# ========================================
#
# Movie ID: tt5311514 - Most Common PERSON Entities:
# Okudera: 68 times
# Hitoha: 32 times
# Katsuhiko: 24 times
# Mitsuha: 12 times
# Okuderas: 8 times
#
# ========================================
#
# Movie ID: tt5362988 - Most Common PERSON Entities:
# Jane: 76 times
# Natalie: 60 times
# Matt: 56 times
# Pete: 56 times
# Corey: 24 times
#
# ========================================
#
# Movie ID: tt5439796 - Most Common PERSON Entities:
# Jimmy: 100 times
# Clyde: 60 times
# Joe: 48 times
# Mellie: 24 times
# Max: 24 times
#
# ========================================
#
# Movie ID: tt5519340 - Most Common PERSON Entities:
# Leilah: 60 times
# Ward: 16 times
# Sherri: 12 times
# Nick Jakoby: 8 times
# Sophia: 8 times
#
# ========================================
#
# Movie ID: tt5580036 - Most Common PERSON Entities:
# Jeff: 60 times
# Shawn: 20 times
# Tonya: 18 times
# Nancy: 14 times
# Diane: 10 times
#
# ========================================
#
# Movie ID: tt5580390 - Most Common PERSON Entities:
# Elisa: 116 times
# Giles: 36 times
# Hoffstetler: 32 times
# Zelda: 24 times
# Strickland: 16 times
#
# ========================================
#
# Movie ID: tt5726616 - Most Common PERSON Entities:
# Oliver: 148 times
# Elio: 32 times
# Elio Perlman: 8 times
# Michael Stuhlbarg: 8 times
# Amira Casar: 8 times
#
# ========================================

# %% [markdown]
# ##### The small model gives accurate results but we may also use the large one in a similar manner - for runtime purposes I will not run the following cells.

# %%
#!python -m spacy download en_core_web_lg

# %%
'''
# Load spaCy model
nlp = spacy.load("en_core_web_lg")  # Changed to a larger model for better accuracy

# Group reviews by movie_id
grouped_reviews = sampled_data.groupby("movie_id")["plot_summary"].apply(lambda x: " ".join(x))

# Dictionary to store PERSON entity counts per movie
person_entities_by_movie = {}

# Process each movie's reviews separately
for movie_id, text in grouped_reviews.items():
    doc = nlp(text)  # Apply spaCy NER directly without tokenization
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]  # Extract only PERSON entities
    
    # Count occurrences of each PERSON entity
    person_counts = Counter(person_entities)
    
    # Store results
    person_entities_by_movie[movie_id] = person_counts

# Print the most common PERSON entities per movie
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"Movie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):  # Top 5 most common PERSON names
        print(f"{entity}: {count} times")
    print("\n" + "="*40 + "\n")  # Separator for readability
'''

# %%
#remove starting and trailing white spaces from strings
columns_to_strip = ['movie_id','plot_summary','duration','genre','release_date','plot_synopsis',
                            'review_date','user_id','review_text','review_summary']
sampled_data[columns_to_strip] = original_data[columns_to_strip].apply(lambda col: col.str.strip())

# %%
# Check for missing values
sampled_data.isna().any()

# %% [markdown]
# There are no missing values.

# %%
# Check for empty strings
(sampled_data == '').sum()

# %% [markdown]
# There are no empty strings.

# %%
genre = sampled_data['genre']
genre

# %%
# Check if every element of genre feature is a string in order to make them lists
sampled_data['genre'].apply(lambda x: isinstance(x, str)).all()

# %%
# split the genres and remove the "[" "]" characters
sampled_data["genre"] = sampled_data["genre"].str.split(",")

sampled_data_exploded = sampled_data.explode('genre')
sampled_data_exploded['genre'] = sampled_data_exploded['genre'].str.replace(r"[\[\]' ]", "", regex=True)

# Apply one-hot encoding using get_dummies
sampled_data_encoded = pd.get_dummies(sampled_data_exploded['genre'])

# merge with the original dataframe
sampled_data_final = sampled_data.merge(sampled_data_encoded.groupby(sampled_data_exploded.index).sum(), left_index= True, right_index = True)

#  Drop the original 'genre' column if it's no longer needed
sampled_data_final = sampled_data_final.drop(columns=['genre'])
sampled_data = sampled_data_final

sampled_data

# %%
sampled_data.columns

# %% [markdown]
# The number of records does not change.

# %%
# Convert duration to minutes

def convert_to_minutes(duration):
    parts = duration.replace("h", "").replace("min", "").strip().split()
    
    hours = int(parts[0]) if "h" in duration else 0
    minutes = int(parts[1]) if len(parts) > 1 else 0
    
    return hours * 60 + minutes

sampled_data['duration_minutes'] = sampled_data['duration'].apply(convert_to_minutes)
sampled_data

# %%
sampled_data.columns

# %%
# Rename rating_x, rating_y
sampled_data.rename(columns={'rating_x': 'IMDB_rating', 'rating_y': 'user_rating'}, inplace=True)

# %%
# Create new features that only have the year of release and the year of the review

sampled_data['release_year'] = sampled_data['release_date'].str[:4]
sampled_data['review_year'] = sampled_data['review_date'].str[-4:]

sampled_data

# %%
# Convert True to 1 and False to 0 in the response variable
sampled_data['is_spoiler'] = sampled_data['is_spoiler'].astype(int)
sampled_data['is_spoiler']

# %% [markdown]
# ### Text Pre-processing

# %%
# Create new dataframe for spoiler and not spoiler class
df_spoiler = sampled_data[sampled_data['is_spoiler'] == 1]
df_not_spoiler = sampled_data[sampled_data['is_spoiler'] == 0]

# %% [markdown]
# #### Uncontract

# %%
# Define the uncontract function which converts short forms to the full word. For example: 'isn't' to 'is not'.
def uncontract(text):
    text = re.sub(r"(\b)([Aa]re|[Cc]ould|[Dd]id|[Dd]oes|[Dd]o|[Hh]ad|[Hh]as|[Hh]ave|[Ii]s|[Mm]ight|[Mm]ust|[Ss]hould|[Ww]ere|[Ww]ould)n't", r"\1\2 not", text)
    text = re.sub(r"(\b)([Hh]e|[Ii]|[Ss]he|[Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Yy]ou)'ll", r"\1\2 will", text)
    text = re.sub(r"(\b)([Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Yy]ou)'re", r"\1\2 are", text)
    text = re.sub(r"(\b)([Ii]|[Ss]hould|[Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Ww]ould|[Yy]ou)'ve", r"\1\2 have", text)

    text = re.sub(r"(\b)([Cc]a)n't", r"\1\2n not", text)
    text = re.sub(r"(\b)([Ii])'m", r"\1\2 am", text)
    text = re.sub(r"(\b)([Ll]et)'s", r"\1\2 us", text)
    text = re.sub(r"(\b)([Tt]here)'s", r"\1\2 is", text)
    text = re.sub(r"(\b)([Ww])on't", r"\1\2ill not", text)
    text = re.sub(r"(\b)([Ss])han't", r"\1\2hall not", text)
    text = re.sub(r"(\b)([Yy])(?:'all|a'll)", r"\1\2ou all", text)

    return text

# %%
sampled_data['review_text'] = [uncontract(t) for t in sampled_data['review_text']]
sampled_data['review_summary'] = [uncontract(t) for t in sampled_data['review_summary']]

# %%
# Create new dataframe for spoiler and not spoiler class
df_spoiler = sampled_data[sampled_data['is_spoiler'] == 1]
df_not_spoiler = sampled_data[sampled_data['is_spoiler'] == 0]

# %% [markdown]
# #### Tokenization

# %%
spoiler_tokens = [word_tokenize(t) for t in df_spoiler['whole_review']]

not_spoiler_tokens = [word_tokenize(t) for t in df_not_spoiler['whole_review']]

# %%
# Convert to a single list
spoiler_tokens = list(itertools.chain.from_iterable(spoiler_tokens))

not_spoiler_tokens = list(itertools.chain.from_iterable(not_spoiler_tokens))

# %%
# Check the number of unique tokens
print('Number of Unique Spoiler Tokens:', len(set(spoiler_tokens)))
print('Number of Unique Non-spoiler Tokens:', len(set(not_spoiler_tokens)))
# Out:
# Number of Unique Spoiler Tokens: 50505
# Number of Unique Non-spoiler Tokens: 40262

# %%
# Check the most frequent tokens for Spoilers and Non-spoilers
print('Spoiler Tokens:\n')

for t, f in Counter(spoiler_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
#------------------------------------
print('Non Spoiler Tokens:\n')

for t, f in Counter(not_spoiler_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Tokens:
#
# the                       46382
# ,                         42739
# .                         34238
# and                       25402
# a                         23422
# to                        21460
# of                        21416
# is                        17486
# in                        13383
# that                      11254
#
# Non Spoiler Tokens:
#
# the                       32025
# ,                         30217
# .                         25088
# and                       18750
# a                         16877
# of                        15589
# to                        14373
# is                        13083
# I                         9328
# in                        9128

# %%
def dimensionality_info(spoilertext ,nonspoilertext):

    print('Number of Spoiler Tokens:    ', len(spoilertext),     '/', len(spoiler_tokens))
    print('Number of Non Spoiler Tokens:', len(nonspoilertext), '/', len(not_spoiler_tokens))

    print()

    print('Number of Unique Spoiler Tokens:    ', len(set(spoilertext)),     '/', len(spoiler_tokens))
    print('Number of Unique Non Spoiler Tokens:', len(set(nonspoilertext)), '/', len(not_spoiler_tokens))

    print()
    print('|V|/|Tokens|:            ', len(set(spoilertext)) / len(set(spoiler_tokens)))
    print('|V|/|Tokens|:            ', len(set(nonspoilertext)) / len(set(not_spoiler_tokens)))

# %% [markdown]
# We observe that the most frequent tokens are stopwords. For that reason we will remvove them to get more informative result.

# %% [markdown]
# #### Remove Punctuation and Stopwords

# %% [markdown]
# ##### Remove Punctuation

# %%
spoiler_punctuations = list(
    filter(
        lambda t: all(c.isdigit() or c in string.punctuation for c in t),
        spoiler_tokens
    )
)
#--------------------------------------
non_spoiler_punctuations = list(
    filter(
        lambda t: all(c.isdigit() or c in string.punctuation for c in t),
        not_spoiler_tokens
    )
)

# %%
spoiler_punctuations = set(spoiler_punctuations)

non_spoiler_punctuations = set(non_spoiler_punctuations)

# %%
# Remove punctuation
spoiler_clean_tokens = [t for t in spoiler_tokens if t not in spoiler_punctuations]

non_spoiler_clean_tokens = [t for t in not_spoiler_tokens if t not in non_spoiler_punctuations]

# %% [markdown]
# ##### Remove Stopwords

# %%
stop_word_regex = '|'.join(['^{}$'.format(s) for s in stopwords.words('english')])

stop_word_regex = re.compile(stop_word_regex)

# %%
spoiler_stop_words = list(filter(stop_word_regex.match, spoiler_clean_tokens))

non_spoiler_stop_words = list(filter(stop_word_regex.match, non_spoiler_clean_tokens))
#----------------------------------------------------
spoiler_stop_words = set(spoiler_stop_words)

non_spoiler_stop_words = set(non_spoiler_stop_words)

# %%
# Remove stopwords
spoiler_clean_tokens = [t for t in spoiler_clean_tokens if t not in spoiler_stop_words]

non_spoiler_clean_tokens = [t for t in non_spoiler_clean_tokens if t not in non_spoiler_stop_words]

# %% [markdown]
# Check the most frequent tokens after removing punctuation and stopwords.

# %%
# Check again the most frequent tokens for Spoilers and Non-spoilers
print('Clean Spoiler Tokens:\n')

for t, f in Counter(spoiler_clean_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
#------------------------------------
print('Clean Non Spoiler Tokens:\n')

for t, f in Counter(non_spoiler_clean_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Clean Spoiler Tokens:
#
# I                         10988
# 's                        9686
# movie                     6808
# The                       5916
# film                      5624
# n't                       4986
# one                       3203
# like                      2896
# It                        2405
# good                      2063
#
# Clean Non Spoiler Tokens:
#
# I                         9328
# 's                        6743
# movie                     6358
# film                      4835
# The                       4344
# n't                       3787
# one                       2588
# like                      2148
# It                        2076
# good                      1843

# %% [markdown]
# We can observe that the possesive s does not give much information. Therefore we decided to consider it as a stopword and remove it.

# %%
spoiler_clean_tokens = [t for t in spoiler_clean_tokens if t != "'s"]

non_spoiler_clean_tokens = [t for t in non_spoiler_clean_tokens if t != "'s"]

# %% [markdown]
# #### Normalization

# %% [markdown]
# ##### Lowercasing

# %%
spoiler_clean_tokens     = [t.lower() for t in spoiler_clean_tokens]

non_spoiler_clean_tokens     = [t.lower() for t in non_spoiler_clean_tokens]

# %% [markdown]
# ##### Stemming

# %%
ps = PorterStemmer()

stems_spoiler = [ps.stem(t) for t in spoiler_clean_tokens]
stems_non_spoiler = [ps.stem(t) for t in non_spoiler_clean_tokens]

# %%
print('Spoiler Stems:\n')

for t, f in Counter(stems_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
#-----------------------------
print('Non Spoiler Stems:\n')

for t, f in Counter(stems_non_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Stems:
#
# i                         10989
# movi                      8033
# film                      6683
# the                       6046
# n't                       5004
# one                       3643
# like                      3454
# charact                   2712
# it                        2548
# time                      2453
#
# Non Spoiler Stems:
#
# i                         9329
# movi                      7570
# film                      5814
# the                       4448
# n't                       3799
# one                       2917
# like                      2581
# it                        2175
# charact                   2047
# good                      1966

# %%
dimensionality_info(stems_spoiler, stems_non_spoiler)
# Out:
# Number of Spoiler Tokens:     506174 / 1021153
# Number of Non Spoiler Tokens: 364236 / 730968
#
# Number of Unique Spoiler Tokens:     33314 / 1021153
# Number of Unique Non Spoiler Tokens: 26725 / 730968
#
# |V|/|Tokens|:             0.6596178596178596
# |V|/|Tokens|:             0.6637772589538523

# %% [markdown]
# ##### Lemmatizing

# %%
lemmatizer = WordNetLemmatizer()

lemmas_spoiler = [lemmatizer.lemmatize(t) for t in spoiler_clean_tokens]
lemmas_non_spoiler = [lemmatizer.lemmatize(t) for t in non_spoiler_clean_tokens]

# %%
print('Spoiler Lemmas:\n')

for t, f in Counter(lemmas_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
#-----------------------------
print('Non Spoiler Lemmas:\n')

for t, f in Counter(lemmas_non_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Lemmas:
#
# i                         10988
# movie                     8033
# film                      6599
# the                       6046
# n't                       5004
# one                       3643
# like                      3082
# character                 2712
# it                        2548
# time                      2428
#
# Non Spoiler Lemmas:
#
# i                         9328
# movie                     7570
# film                      5718
# the                       4448
# n't                       3799
# one                       2917
# like                      2290
# it                        2175
# character                 2047
# good                      1952

# %%
dimensionality_info(lemmas_spoiler, lemmas_non_spoiler)
# Out:
# Number of Spoiler Tokens:     506174 / 1021153
# Number of Non Spoiler Tokens: 364236 / 730968
#
# Number of Unique Spoiler Tokens:     40430 / 1021153
# Number of Unique Non Spoiler Tokens: 32250 / 730968
#
# |V|/|Tokens|:             0.8005148005148005
# |V|/|Tokens|:             0.8010034275495505

# %%
#Many of the spoiler and non-spoiler most common words are the same - therefore we can try to isolate the 
#most common words that appear *only* in spoiler reviews and *only* in negative reviews

# %%
##############################################
# Define an informative function to view the #
# information of frequencies between the two #
# sets of tokens passed as input.            #
##############################################

def comparison_info(spoiler, nonspoiler, desc=None, n=10):

    print(f'{desc.capitalize()} only in Spoiler reviews:')
    print()

    spoilerfreq = dict(Counter(spoiler))
    nonspoilerfreq = dict(Counter(nonspoiler))

    onlyspoiler = set(spoilerfreq).difference(set(nonspoilerfreq))
    onlynonspoiler = set(nonspoilerfreq).difference(set(spoilerfreq))
    common   = set(spoilerfreq).intersection(set(nonspoilerfreq))

    for u in sorted(onlyspoiler, key=lambda t: spoilerfreq[t], reverse=True)[:n]: print('- {0:35} {1}'.format(u, spoilerfreq[u]))

    print()
    print(f'{desc.capitalize()} only in Non-Spoiler Reviews:')
    print()

    for u in sorted(onlynonspoiler, key=lambda t: nonspoilerfreq[t], reverse=True)[:n]: print('- {0:35} {1}'.format(u, nonspoilerfreq[u]))

    print()
    print(f'{desc.capitalize()} common in Spoiler and Non spoiler reviews:')
    print()

    print('{0:37} {1:10} {2:10}'.format('Token', 'Spoiler', 'Non Spoiler'))
    print('------------------------------------------------------------')

    for u in sorted(common, key=lambda t: spoilerfreq[t] + nonspoilerfreq[t], reverse=True)[:n]:

        print('- {0:35} {1:<10} {2:<10}'.format(u, spoilerfreq[u], nonspoilerfreq[u]))

# %%
comparison_info(
  lemmas_spoiler,
  lemmas_non_spoiler,
  desc = 'Lemmas',
  n    = 10
)
# Out:
# Lemmas only in Spoiler reviews:
#
# - dir                                 30
# - edmond                              26
# - ant                                 25
# - sheeta                              21
# - pazu                                19
# - backdraft                           19
# - atticus                             18
# - susanna                             17
# - nzt                                 16
# - alvy                                16
#
# Lemmas only in Non-Spoiler Reviews:
#
# - algren                              15
# - spiderwick                          12
# - harding                             11
# - ivy                                 10
# - shu                                 10
# - percy                               10
# - feig                                9
# - drillbit                            9
# - katsumoto                           9
# - tadashi                             9
#
# Lemmas common in Spoiler and Non spoiler reviews:
#
# Token                                 Spoiler    Non Spoiler
# ------------------------------------------------------------
# - i                                   10988      9328
# - movie                               8033       7570
# - film                                6599       5718
# - the                                 6046       4448
# - n't                                 5004       3799
# - one                                 3643       2917
# - like                                3082       2290
# - character                           2712       2047
# - it                                  2548       2175
# - time                                2428       1874

# %% [markdown]
# Comment: mallon ta results pano ennen toso useful : perhaps removing ALL common words in both spoiler and non spoiler is a bit harsh and removes way too many words/ much info.
#
# Another approach we can follow is:, we remove the top 10 common in both lemmas (ie movie, a, film, the, i, good, great etc. since they dont give much information on whether a review contains a spoiler or not.
#
# After doing so we can check the results and filter more words out if needed.
