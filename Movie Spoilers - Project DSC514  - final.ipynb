# %% [markdown]
# # Detection of Movie Spoilers in Reviews

# %% [markdown]
# ### ***Import essential libraries***

# %%
import pandas as pd
import numpy as np
import re, string, nltk 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import itertools
import spacy
from collections import Counter
from nltk.stem import WordNetLemmatizer


nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('punkt_tab')

# %% [markdown]
# ### Understanding the data

# %% [markdown]
# Apories:
# 1. what is rating_x, rating_y IMDB???
# 2. maybe convert duration to minutes would be better to compare

# %%
# Load the dataset
original_data = pd.read_csv('movie_spoiler_sample.csv')

# %%
# First view of the dataset
original_data.head(5)
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0318649  Master explorer and former US Navy Seal Dirk P...   2h 4min
# 1  tt0803096  When the world of the Orcs of Draenor is being...   2h 3min
# 2  tt0425112  Top London cop, PC Nicholas Angel is good. Too...   2h 1min
# 3  tt0327056  In the summer of 1975 in a neighborhood in Bos...  2h 18min
# 4  tt0259711  Incarcerated and charged with murder, David Aa...  2h 16min
#
#                                 genre  rating_x release_date  \
# 0   ['Action', 'Adventure', 'Comedy']       6.0   2005-04-08
# 1  ['Action', 'Adventure', 'Fantasy']       6.9   2016-06-10
# 2                ['Action', 'Comedy']       7.9   2007-04-20
# 3       ['Crime', 'Drama', 'Mystery']       8.0   2003-10-15
# 4   ['Fantasy', 'Mystery', 'Romance']       6.9   2001-12-14
#
#                                        plot_synopsis      review_date  \
# 0  The film begins with a prologue set in Richmon...      27 May 2005
# 1  For ages in the region of Middle Earth, humans...     20 June 2016
# 2  Nicholas Angel (Simon Pegg) is undoubtedly Lon...     11 June 2007
# 3  Three young boys, all the best of friends, are...  5 November 2015
# 4  David Aames (Tom Cruise) drives to work, he fi...   12 August 2016
#
#       user_id  is_spoiler                                        review_text  \
# 0   ur3270789       False  The film starts in the Richmond battle (1865) ...
# 1  ur47788388        True  I saw the movie with six friends and we all lo...
# 2  ur14440242        True  I enjoyed this movie very much, but it being l...
# 3  ur63623011       False  What you get here is no more than Clint eastwo...
# 4   ur2781970       False  I think the first time I saw this movie, I did...
#
#    rating_y                                     review_summary
# 0         7  Splendid adventure film with mesmerizing deser...
# 1        10                   Epic movie for fans and non fans
# 2         8                    once again a funny British film
# 3         1               For he made a 'plot twist' out of it
# 4        10                     As brilliant as I recalled it!

# %% [markdown]
# The dataset is very large and run time error occurs therefore we decided to use undersampling to obtain a balanced sample of the data.

# %%
# Check the count per movie id
original_data['movie_id'].value_counts()
# Out:
# movie_id
# tt0468569    643
# tt0111161    565
# tt0167260    328
# tt0137523    272
# tt0110912    265
#             ...
# tt0383534      3
# tt0110989      2
# tt5580036      2
# tt0107719      1
# tt0374887      1
# Name: count, Length: 1339, dtype: int64

# %%
# Check how many unique movies we have
len(original_data['movie_id'].value_counts())
# Out:
# 1339

# %% [markdown]
# For the above reason we decided to take a sample of at most 4 reviews per movie (or less if they don't have enough reviews).

# %%
# Sample each movie's reviews based on the given criteria
sampled_data = original_data.groupby('movie_id', group_keys=False, as_index=False).apply(
    lambda movie_df: movie_df if len(movie_df) <= 4 else pd.concat([
        movie_df[movie_df['is_spoiler'] == True].sample(n=min(2, len(movie_df[movie_df['is_spoiler'] == True])), random_state=42),
        movie_df[movie_df['is_spoiler'] == False].sample(n=min(2, len(movie_df[movie_df['is_spoiler'] == False])), random_state=42)
    ])
).reset_index(drop=True)

sampled_data.head()
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 1  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 2  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 3  tt0015864  A lone prospector ventures into Alaska looking...  1h 35min
# 4  tt0017136  Sometime in the future, the city of Metropolis...  2h 33min
#
#                               genre  rating_x release_date  \
# 0  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 1  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 2  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 3  ['Adventure', 'Comedy', 'Drama']       8.2         1925
# 4               ['Drama', 'Sci-Fi']       8.3   1927-03-13
#
#                                        plot_synopsis      review_date  \
# 0  It is in the middle of the Gold Rush. A Lone P...  1 February 2006
# 1  It is in the middle of the Gold Rush. A Lone P...   11 August 2005
# 2  It is in the middle of the Gold Rush. A Lone P...     22 June 2000
# 3  It is in the middle of the Gold Rush. A Lone P...     9 March 2009
# 4  The film is set in the year 2026, in the extra...     7 March 2015
#
#       user_id  is_spoiler                                        review_text  \
# 0   ur5945598        True  Oh where can I start on why alleged comedians ...
# 1   ur5805910        True  We follow "the little fellow" (Chaplin), in hi...
# 2   ur0773000       False  I recently saw this movie with a live orchestr...
# 3   ur0361658       False  The Gold Rush (1925) was a big undertaking for...
# 4  ur13977076        True  This sci-fi classic is set in a future where t...
#
#    rating_y                                     review_summary
# 0        10                        Chaplin strikes comic gold!
# 1        10          Chaplin's delightful bonhomie & innocence
# 2         9  As fresh, funny, and moving as the day it was ...
# 3        10       The Cinema of Charles Chaplin: The Gold Rush
# 4        10                          A science fiction classic

# %%
# Number of records and features for the dataset
sampled_data.shape
# Out:
# (5335, 13)

# %%
# Check if the sample is balanced
sampled_data['is_spoiler'].value_counts()
# Out:
# is_spoiler
# False    2677
# True     2658
# Name: count, dtype: int64

# %% [markdown]
# The target variable is balanced.

# %%
sampled_data['whole_review'] = sampled_data['review_text'] + sampled_data['review_summary']

# %%
# View the columns of the dataset
sampled_data.columns
# Out:
# Index(['movie_id', 'plot_summary', 'duration', 'genre', 'rating_x',
#        'release_date', 'plot_synopsis', 'review_date', 'user_id', 'is_spoiler',
#        'review_text', 'rating_y', 'review_summary', 'whole_review'],
#       dtype='object')

# %%
sampled_data['whole_plot'] = sampled_data['plot_synopsis'] + sampled_data['plot_summary']

# %% [markdown]
# The target variable is balanced.

# %%
# Check for duplicated records
sampled_data.duplicated().any()
# Out:
# False

# %% [markdown]
# There are no duplicated records.

# %%
# Check the data types
sampled_data.dtypes
# Out:
# movie_id           object
# plot_summary       object
# duration           object
# genre              object
# rating_x          float64
# release_date       object
# plot_synopsis      object
# review_date        object
# user_id            object
# is_spoiler           bool
# review_text        object
# rating_y            int64
# review_summary     object
# whole_review       object
# whole_plot         object
# dtype: object

# %%
# Save the sampled data as a csv
sampled_data.to_csv("sampled_data.csv", index=False)

# %% [markdown]
# ### Named entity Recognition on the plot synopsis and review to find the main characters

# %%
#This must be run every time before NER, we may put this in the beginning of the notebook
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 2.8 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.6/12.8 MB 3.7 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/12.8 MB 3.8 MB/s eta 0:00:03
#      --------- ------------------------------ 2.9/12.8 MB 3.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.4/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.1 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 3.1 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.2/12.8 MB 3.1 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.5/12.8 MB 3.0 MB/s eta 0:00:03
#      ------------------ --------------------- 5.8/12.8 MB 2.8 MB/s eta 0:00:03
#      ------------------- -------------------- 6.3/12.8 MB 2.7 MB/s eta 0:00:03
#      -------------------- ------------------- 6.6/12.8 MB 2.6 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 2.5 MB/s eta 0:00:03
#      --------------------- ------------------ 6.8/12.8 MB 2.5 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.1/12.8 MB 2.3 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.1/12.8 MB 2.3 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.3/12.8 MB 2.1 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.6/12.8 MB 2.0 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.6/12.8 MB 2.0 MB/s eta 0:00:03
#      ------------------------ --------------- 7.9/12.8 MB 1.9 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 1.8 MB/s eta 0:00:03
#      ------------------------- -------------- 8.1/12.8 MB 1.8 MB/s eta 0:00:03
#      -------------------------- ------------- 8.4/12.8 MB 1.8 MB/s eta 0:00:03
#      --------------------------- ------------ 8.7/12.8 MB 1.7 MB/s eta 0:00:03
#      --------------------------- ------------ 8.7/12.8 MB 1.7 MB/s eta 0:00:03
#      --------------------------- ------------ 8.9/12.8 MB 1.7 MB/s eta 0:00:03
#      ---------------------------- ----------- 9.2/12.8 MB 1.6 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.4/12.8 MB 1.6 MB/s eta 0:00:03
#      ----------------------------- ---------- 9.4/12.8 MB 1.6 MB/s eta 0:00:03
#      ------------------------------ --------- 9.7/12.8 MB 1.6 MB/s eta 0:00:02
#      ------------------------------ --------- 9.7/12.8 MB 1.6 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.8 MB 1.5 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.8 MB 1.5 MB/s eta 0:00:02
#      ------------------------------- -------- 10.2/12.8 MB 1.5 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 1.4 MB/s eta 0:00:02
#      -------------------------------- ------- 10.5/12.8 MB 1.4 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.4 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.8 MB 1.4 MB/s eta 0:00:02
#      ---------------------------------- ----- 11.0/12.8 MB 1.4 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.3 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.3 MB/s eta 0:00:02
#      ------------------------------------ --- 11.5/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.2 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_sm")  

# Group reviews by movie_id
grouped_reviews = sampled_data.groupby("movie_id")["plot_summary"].apply(lambda x: " ".join(x))

# Dictionary to store PERSON entity counts per movie
person_entities_by_movie = {}

# Process each movie's reviews separately
for movie_id, text in grouped_reviews.items():
    doc = nlp(text)  # Apply spaCy NER directly without tokenization
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]  # Extract only PERSON entities
    
    # Count occurrences of each PERSON entity
    person_counts = Counter(person_entities)
    
    # Store results
    person_entities_by_movie[movie_id] = person_counts

# Print the most common PERSON entities per movie
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"Movie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):  # Top 5 most common PERSON names
        print(f"{entity}: {count} times")
    print("\n" + "="*40 + "\n")  # Separator for readability
# Out:
# Movie ID: tt0015864 - Most Common PERSON Entities:
# John J. Magee: 4 times
#
# ========================================
#
# Movie ID: tt0017136 - Most Common PERSON Entities:
# Metropolis: 8 times
# Maria: 8 times
# Freder Fredersen: 4 times
# Freder: 4 times
# John Fredersen: 4 times
#
# ========================================
#
# Movie ID: tt0017925 - Most Common PERSON Entities:
# Johnnie: 8 times
# Annabelle Lee: 4 times
# Ed Stephan: 4 times
#
# ========================================
#
# Movie ID: tt0018455 - Most Common PERSON Entities:
# Indre: 4 times
#
# ========================================
#
# Movie ID: tt0019254 - Most Common PERSON Entities:
# Jeanne D'Arc: 4 times
# Jeanne: 4 times
#
# ========================================
#
# Movie ID: tt0021749 - Most Common PERSON Entities:
# John J. Magee: 4 times
#
# ========================================
#
# Movie ID: tt0022100 - Most Common PERSON Entities:
# Hans Beckert: 4 times
# Hans: 4 times
# Claudio Carvalho: 4 times
#
# ========================================
#
# Movie ID: tt0025316 - Most Common PERSON Entities:
# King Westley: 4 times
# King: 4 times
# Peter Warne: 4 times
# Warne: 4 times
# Peter: 4 times
#
# ========================================
#
# Movie ID: tt0031381 - Most Common PERSON Entities:
# Scarlett: 16 times
# Ashley: 8 times
# Melanie: 8 times
# Tara: 4 times
# Mammy: 4 times
#
# ========================================
#
# Movie ID: tt0031679 - Most Common PERSON Entities:
# Smith: 12 times
# Jefferson Smith: 4 times
# Joseph Paine: 4 times
# Jim Taylor: 4 times
# Taylor: 4 times
#
# ========================================
#
# Movie ID: tt0032138 - Most Common PERSON Entities:
# L. Frank Baum: 4 times
# Dorothy: 4 times
# the Wizard of Oz: 4 times
# Dale Roloff: 4 times
#
# ========================================
#
# Movie ID: tt0032551 - Most Common PERSON Entities:
# Tom Joad: 4 times
# Colin Tinto: 4 times
#
# ========================================
#
# Movie ID: tt0032553 - Most Common PERSON Entities:
# Adenoid Hynkel: 4 times
# Hannah: 4 times
# Schultz: 4 times
# Benzino Napaloni: 4 times
#
# ========================================
#
# Movie ID: tt0032976 - Most Common PERSON Entities:
# Max: 8 times
# Manderley: 8 times
# Monte Carlo: 4 times
# Maxim de Winter: 4 times
# Danvers: 4 times
#
# ========================================
#
# Movie ID: tt0033467 - Most Common PERSON Entities:
# Kane: 8 times
# Charles Foster Kane: 4 times
# Zack H.: 4 times
#
# ========================================
#
# Movie ID: tt0033870 - Most Common PERSON Entities:
# Sam: 8 times
# Miles: 8 times
# Wonderly: 8 times
# Archer: 4 times
# Sam Spade: 4 times
#
# ========================================
#
# Movie ID: tt0034583 - Most Common PERSON Entities:
# Rick: 12 times
# Rick Blaine: 4 times
# Ilsa: 4 times
# Kyle Perez: 4 times
#
# ========================================
#
# Movie ID: tt0036775 - Most Common PERSON Entities:
# Phyllis: 8 times
# Walter: 8 times
# Walter Neff: 4 times
# Phyllis Dietrichson: 4 times
# Dietrichson: 4 times
#
# ========================================
#
# Movie ID: tt0036868 - Most Common PERSON Entities:
# Al Stephenson: 4 times
# Fred Derry: 4 times
# Homer Parrish: 4 times
#
# ========================================
#
# Movie ID: tt0038650 - Most Common PERSON Entities:
# George: 12 times
# Potter: 8 times
# George Bailey: 4 times
# Bedford Falls: 4 times
# Billy: 4 times
#
# ========================================
#
# Movie ID: tt0040522 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt0040897 - Most Common PERSON Entities:
# Bob Curtin: 4 times
# Howard: 4 times
# Jim Beaver: 4 times
# Fred C. Dobbs: 1 times
#
# ========================================
#
# Movie ID: tt0041959 - Most Common PERSON Entities:
# Harry Lime: 8 times
# Holly Martins: 4 times
# Martins: 4 times
# Mark Thompson: 4 times
#
# ========================================
#
# Movie ID: tt0042192 - Most Common PERSON Entities:
# Eve: 12 times
# Anne Baxter: 4 times
# Bette Davis: 4 times
# DeWitt: 4 times
# George Sanders: 4 times
#
# ========================================
#
# Movie ID: tt0042876 - Most Common PERSON Entities:
# Rashômon: 8 times
#
# ========================================
#
# Movie ID: tt0043014 - Most Common PERSON Entities:
# Norma: 12 times
# Joe: 8 times
# Joe Gillis: 4 times
# Norma Desmond: 4 times
# Max Von Mayerling: 4 times
#
# ========================================
#
# Movie ID: tt0045152 - Most Common PERSON Entities:
# Don: 16 times
# Monumental: 8 times
# Don Lockwood: 4 times
# R.F. Simpson: 4 times
#
# ========================================
#
# Movie ID: tt0046268 - Most Common PERSON Entities:
# Col Needham: 4 times
#
# ========================================
#
# Movie ID: tt0046438 - Most Common PERSON Entities:
# Paul Watabe: 4 times
#
# ========================================
#
# Movie ID: tt0046911 - Most Common PERSON Entities:
# Michael Brooke: 4 times
#
# ========================================
#
# Movie ID: tt0046912 - Most Common PERSON Entities:
# Tony: 12 times
# Mark: 8 times
# Mark Halliday: 4 times
# Tony Wendice: 4 times
# Lesgate: 4 times
#
# ========================================
#
# Movie ID: tt0047296 - Most Common PERSON Entities:
# Johnny Friendly: 4 times
# Terry: 4 times
# Johnny: 4 times
# Barry: 4 times
# Colin Tinto: 4 times
#
# ========================================
#
# Movie ID: tt0047396 - Most Common PERSON Entities:
# Jeff: 4 times
# Lisa Freemont: 4 times
# Stella: 4 times
# Col Needham: 4 times
#
# ========================================
#
# Movie ID: tt0047478 - Most Common PERSON Entities:
# Colin Tinto: 4 times
#
# ========================================
#
# Movie ID: tt0050083 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt0050212 - Most Common PERSON Entities:
# Nicholson: 8 times
# Saito: 4 times
# Warden: 4 times
#
# ========================================
#
# Movie ID: tt0050783 - Most Common PERSON Entities:
# Giorgio: 3 times
#
# ========================================
#
# Movie ID: tt0050825 - Most Common PERSON Entities:
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0050976 - Most Common PERSON Entities:
# Death: 4 times
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0050986 - Most Common PERSON Entities:
# Agda: 4 times
# Isak Borg: 4 times
# Marianne: 4 times
#
# ========================================
#
# Movie ID: tt0051201 - Most Common PERSON Entities:
# Wilfrid Robarts: 4 times
# Miss Plimsoll: 4 times
# Leonard Vole: 4 times
# Emily French: 4 times
# Leonard: 4 times
#
# ========================================
#
# Movie ID: tt0052311 - Most Common PERSON Entities:
# Vargas: 12 times
# Quinlan: 8 times
# Susie: 8 times
# Ramon Miguel 'Mike': 4 times
# Grandi: 4 times
#
# ========================================
#
# Movie ID: tt0052357 - Most Common PERSON Entities:
# Madeleine: 12 times
# John "Scottie" Ferguson: 4 times
# Scottie: 4 times
#
# ========================================
#
# Movie ID: tt0052618 - Most Common PERSON Entities:
# Judah: 12 times
# Messala: 8 times
# Judah Ben-Hur: 4 times
# Matthias Scheler: 4 times
#
# ========================================
#
# Movie ID: tt0053125 - Most Common PERSON Entities:
# Roger Thornhill: 4 times
# George Kaplan: 4 times
# Philip Vandamm: 4 times
# Leonard: 4 times
# Thornhill: 4 times
#
# ========================================
#
# Movie ID: tt0053291 - Most Common PERSON Entities:
# Joe: 8 times
# Jerry: 4 times
# Josephine: 4 times
# Daphne: 4 times
# Sugar Kane Kowalczyk: 4 times
#
# ========================================
#
# Movie ID: tt0053604 - Most Common PERSON Entities:
# Baxter: 8 times
# C.C. Baxter: 4 times
# Vanderhoff: 4 times
# Jeff D. Sheldrake: 4 times
# Fran Kubelik: 4 times
#
# ========================================
#
# Movie ID: tt0054215 - Most Common PERSON Entities:
# Sam: 12 times
# Marion Crane: 4 times
# Marion: 4 times
# Norman: 4 times
# Col Needham: 4 times
#
# ========================================
#
# Movie ID: tt0055031 - Most Common PERSON Entities:
# Dan Haywood: 4 times
# Tony Fontana: 4 times
#
# ========================================
#
# Movie ID: tt0055630 - Most Common PERSON Entities:
# Bernard Keane: 4 times
#
# ========================================
#
# Movie ID: tt0056172 - Most Common PERSON Entities:
# Bedouin: 4 times
# T.E. Lawrence: 4 times
# Prince Faisal: 4 times
# Sherif Ali: 4 times
# Lawrence: 4 times
#
# ========================================
#
# Movie ID: tt0056592 - Most Common PERSON Entities:
# Jem: 8 times
# Gregory Peck: 4 times
# Tom Robinson: 4 times
# Scout: 4 times
# Boo Radley: 4 times
#
# ========================================
#
# Movie ID: tt0057012 - Most Common PERSON Entities:
# Ripper: 12 times
# Burpelson: 8 times
# Jack D. Ripper: 4 times
# Buck Turgidson: 4 times
# Merkin Muffley: 4 times
#
# ========================================
#
# Movie ID: tt0057115 - Most Common PERSON Entities:
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0059578 - Most Common PERSON Entities:
# Douglas Mortimer: 4 times
# Claudio Carvalho: 4 times
# Monco: 3 times
#
# ========================================
#
# Movie ID: tt0060107 - Most Common PERSON Entities:
# Andreiv Rublev: 4 times
# L.H. Wong: 4 times
#
# ========================================
#
# Movie ID: tt0060196 - Most Common PERSON Entities:
# Tuco: 28 times
# Angel Eyes: 8 times
# Bill Carson: 8 times
# Carson: 8 times
# Blondie: 5 times
#
# ========================================
#
# Movie ID: tt0060827 - Most Common PERSON Entities:
# Alma: 12 times
# Elisabeth: 12 times
# Elisabeth Vogler: 4 times
# Kathy Li: 4 times
#
# ========================================
#
# Movie ID: tt0061512 - Most Common PERSON Entities:
# Luke: 8 times
# Luke Jackson: 4 times
# Dragline: 4 times
#
# ========================================
#
# Movie ID: tt0062622 - Most Common PERSON Entities:
# Bowman: 4 times
# Larry Cousins: 4 times
#
# ========================================
#
# Movie ID: tt0064115 - Most Common PERSON Entities:
# Butch: 12 times
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0064116 - Most Common PERSON Entities:
# McBain: 4 times
# Cheyenne: 4 times
# assassin gang: 4 times
# Frank: 4 times
# Story: 3 times
#
# ========================================
#
# Movie ID: tt0066921 - Most Common PERSON Entities:
# Alex: 8 times
# Alex DeLarge: 4 times
#
# ========================================
#
# Movie ID: tt0068646 - Most Common PERSON Entities:
# J. S. Golden: 4 times
#
# ========================================
#
# Movie ID: tt0070510 - Most Common PERSON Entities:
# Addie: 8 times
# Addie Pray: 4 times
# Joe David Brown: 4 times
# Addie Loggins: 4 times
# mfleetwo@mail.coin.missouri.edu>: 3 times
#
# ========================================
#
# Movie ID: tt0070735 - Most Common PERSON Entities:
# Lonnegan: 12 times
# Luther: 8 times
# Johnny Hooker: 4 times
# Doyle Lonnegan: 4 times
# Henry Gondorff: 4 times
#
# ========================================
#
# Movie ID: tt0071315 - Most Common PERSON Entities:
# Mulwray: 8 times
# Evelyn Mulwray: 4 times
#
# ========================================
#
# Movie ID: tt0071562 - Most Common PERSON Entities:
# Michael Corleone: 4 times
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0071853 - Most Common PERSON Entities:
# Arthur: 4 times
# Tim: 4 times
# Python: 4 times
#
# ========================================
#
# Movie ID: tt0072684 - Most Common PERSON Entities:
# Barry: 12 times
# Redmond Barry: 4 times
# Nora Brady: 4 times
# Nora: 4 times
# John Quin: 4 times
#
# ========================================
#
# Movie ID: tt0072890 - Most Common PERSON Entities:
# Sonny: 16 times
# Moretti: 4 times
#
# ========================================
#
# Movie ID: tt0073195 - Most Common PERSON Entities:
# Martin Brody: 4 times
# Larry Vaughn: 4 times
# Quint: 4 times
# Soon Quint: 4 times
# Brody: 4 times
#
# ========================================
#
# Movie ID: tt0073486 - Most Common PERSON Entities:
# McMurphy: 12 times
# Jacob Oberfrank McMurphy: 3 times
# Jacob Oberfrank: 1 times
#
# ========================================
#
# Movie ID: tt0074958 - Most Common PERSON Entities:
# Howard Beale: 4 times
# Max Schumacher: 4 times
# Diana Christensen: 4 times
# Bruce Janson: 4 times
#
# ========================================
#
# Movie ID: tt0075148 - Most Common PERSON Entities:
# Rocky Balboa: 4 times
# Creed: 4 times
# Rocky: 4 times
# Murray Chapman: 4 times
#
# ========================================
#
# Movie ID: tt0075314 - Most Common PERSON Entities:
# Betsy: 4 times
# Charles Palantine: 4 times
# Iris: 4 times
# Matthew: 4 times
# Travis Bickle: 1 times
#
# ========================================
#
# Movie ID: tt0075686 - Most Common PERSON Entities:
# Annie Hall: 4 times
# Annie: 4 times
# Alvy Singer: 1 times
#
# ========================================
#
# Movie ID: tt0076759 - Most Common PERSON Entities:
# Darth Vader: 4 times
# Luke Skywalker: 4 times
#
# ========================================
#
# Movie ID: tt0077416 - Most Common PERSON Entities:
# Michael: 8 times
# Steven: 8 times
# Angela: 4 times
# Leon Wolters: 4 times
#
# ========================================
#
# Movie ID: tt0078748 - Most Common PERSON Entities:
# blazesnakes9: 4 times
#
# ========================================
#
# Movie ID: tt0078788 - Most Common PERSON Entities:
# Willard: 16 times
# Viet Cong: 8 times
# Kurtz: 8 times
# Lucas: 4 times
# Walter Kurtz: 4 times
#
# ========================================
#
# Movie ID: tt0079470 - Most Common PERSON Entities:
# Brian: 16 times
# Nazareth: 8 times
# Jesus: 4 times
#
# ========================================
#
# Movie ID: tt0079944 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt0080678 - Most Common PERSON Entities:
# John Merrick: 4 times
# Joseph: 4 times
# Sam Cibula: 4 times
#
# ========================================
#
# Movie ID: tt0080684 - Most Common PERSON Entities:
# Luke: 8 times
# Yoda: 4 times
# Jedi: 4 times
# Darth Vader: 4 times
# Jwelch5742 Luke Skywalker: 3 times
#
# ========================================
#
# Movie ID: tt0081398 - Most Common PERSON Entities:
# Jake LaMotta: 4 times
#
# ========================================
#
# Movie ID: tt0081505 - Most Common PERSON Entities:
# Jack Torrance: 4 times
# Jack: 4 times
# Danny: 4 times
# J. S. Golden Signing: 3 times
# J. S. Golden: 1 times
#
# ========================================
#
# Movie ID: tt0082096 - Most Common PERSON Entities:
# Anthony Hughes: 4 times
#
# ========================================
#
# Movie ID: tt0082971 - Most Common PERSON Entities:
# Jones: 8 times
# Indiana Jones: 4 times
# Marcus Brody: 4 times
# Rene Belloq: 4 times
# John Wiggins: 4 times
#
# ========================================
#
# Movie ID: tt0083658 - Most Common PERSON Entities:
# Deckard: 8 times
# depressing metropolis: 4 times
# Rick Deckard: 4 times
# Blade Runner: 4 times
# Rachel: 4 times
#
# ========================================
#
# Movie ID: tt0083987 - Most Common PERSON Entities:
# Gandhi: 20 times
#
# ========================================
#
# Movie ID: tt0084787 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt0086190 - Most Common PERSON Entities:
# Darth Vader: 4 times
# Lando Calrissian: 4 times
# Ewoks: 4 times
# Jwelch5742 Luke Skywalker: 3 times
# Luke Skywalker: 1 times
#
# ========================================
#
# Movie ID: tt0086250 - Most Common PERSON Entities:
# Tony: 12 times
# Tony Montana: 4 times
# Manny: 4 times
# Frank Lopez: 4 times
# Frank: 4 times
#
# ========================================
#
# Movie ID: tt0086879 - Most Common PERSON Entities:
# Mozart: 20 times
# Antonio Salieri: 4 times
# Wolfgang Amadeus Mozart's: 4 times
# Joseph II: 4 times
# Khaled Salem: 4 times
#
# ========================================
#
# Movie ID: tt0087843 - Most Common PERSON Entities:
# Andrew Welsh: 4 times
#
# ========================================
#
# Movie ID: tt0087884 - Most Common PERSON Entities:
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0088247 - Most Common PERSON Entities:
# Sarah: 8 times
# Sarah Connor: 4 times
# Colin Tinto: 4 times
#
# ========================================
#
# Movie ID: tt0088763 - Most Common PERSON Entities:
# Marty McFly: 4 times
# Marty: 4 times
# Robert Lynch: 4 times
#
# ========================================
#
# Movie ID: tt0089881 - Most Common PERSON Entities:
# Saburo: 12 times
# Hidetori Ichimonji: 4 times
# Jiro: 4 times
#
# ========================================
#
# Movie ID: tt0090605 - Most Common PERSON Entities:
# Ellen Ripley: 4 times
# blazesnakes9: 4 times
#
# ========================================
#
# Movie ID: tt0091763 - Most Common PERSON Entities:
# Chris: 8 times
# Chris Taylor: 4 times
# Sergeant Robert Barnes: 4 times
# Jeremy Thomson: 4 times
#
# ========================================
#
# Movie ID: tt0092005 - Most Common PERSON Entities:
# Gordie: 4 times
# Chris: 4 times
# Teddy: 4 times
# Vern: 4 times
#
# ========================================
#
# Movie ID: tt0092067 - Most Common PERSON Entities:
# Sheeta: 8 times
# Lin: 4 times
#
# ========================================
#
# Movie ID: tt0093058 - Most Common PERSON Entities:
# Joker: 4 times
# Scott Renshaw: 4 times
#
# ========================================
#
# Movie ID: tt0093779 - Most Common PERSON Entities:
# Buttercup: 8 times
# Westley: 8 times
# Roberts: 4 times
#
# ========================================
#
# Movie ID: tt0095016 - Most Common PERSON Entities:
# John: 8 times
# John McClane: 4 times
# Holly: 4 times
# Hans Gruber: 4 times
# Sam NYPD: 3 times
#
# ========================================
#
# Movie ID: tt0095327 - Most Common PERSON Entities:
# Satsuko: 4 times
# Kyle Perez: 4 times
#
# ========================================
#
# Movie ID: tt0095765 - Most Common PERSON Entities:
# Salvatore: 8 times
# Clarisse P.: 4 times
#
# ========================================
#
# Movie ID: tt0096283 - Most Common PERSON Entities:
# Satsuki: 8 times
# Mei: 8 times
# Christopher E. Meadows: 4 times
#
# ========================================
#
# Movie ID: tt0097165 - Most Common PERSON Entities:
# Todd Anderson: 4 times
# Neil Perry: 4 times
# Keating: 4 times
# Liz Jordan: 4 times
#
# ========================================
#
# Movie ID: tt0097576 - Most Common PERSON Entities:
# Jones: 4 times
# Henry Jones: 4 times
#
# ========================================
#
# Movie ID: tt0098966 - Most Common PERSON Entities:
# Mary: 8 times
# Murray Chapman: 4 times
# Sylvia: 1 times
#
# ========================================
#
# Movie ID: tt0099052 - Most Common PERSON Entities:
# Shaun Ouimette: 4 times
#
# ========================================
#
# Movie ID: tt0099077 - Most Common PERSON Entities:
# Malcolm Sayer: 4 times
#
# ========================================
#
# Movie ID: tt0099088 - Most Common PERSON Entities:
# Marty: 12 times
# Marty McFly: 4 times
# Emmett Brown: 4 times
# Emmett: 4 times
# Vampire Sharpshooter: 1 times
#
# ========================================
#
# Movie ID: tt0099253 - Most Common PERSON Entities:
# Charles Lee Ray: 4 times
# Andy: 4 times
# Will Andy: 4 times
# Phil Fernando Andy Barclay: 3 times
# Andy Barclay: 1 times
#
# ========================================
#
# Movie ID: tt0099329 - Most Common PERSON Entities:
# Allison: 8 times
# Greaser: 4 times
# John Waters: 4 times
# Juvenile Delinquency: 4 times
# Linda: 4 times
#
# ========================================
#
# Movie ID: tt0099348 - Most Common PERSON Entities:
# John Dunbar: 4 times
# Greg Bole: 4 times
#
# ========================================
#
# Movie ID: tt0099365 - Most Common PERSON Entities:
# Peyton Westlake: 4 times
# Darkman: 4 times
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0099422 - Most Common PERSON Entities:
# Dick Tracy: 4 times
# Tracy: 4 times
# Breathless Mahoney: 4 times
# Jeremy Perkins: 4 times
#
# ========================================
#
# Movie ID: tt0099423 - Most Common PERSON Entities:
# John McClane: 4 times
# Willis: 4 times
# Stuart: 4 times
#
# ========================================
#
# Movie ID: tt0099487 - Most Common PERSON Entities:
# Edward: 4 times
# Peg: 4 times
#
# ========================================
#
# Movie ID: tt0099566 - Most Common PERSON Entities:
# Bull: 3 times
# Kathy Li: 3 times
#
# ========================================
#
# Movie ID: tt0099582 - Most Common PERSON Entities:
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0099653 - Most Common PERSON Entities:
# Sam: 8 times
# Carl: 8 times
# Molly Jensen: 4 times
# Carl Bruner: 4 times
# Molly: 4 times
#
# ========================================
#
# Movie ID: tt0099674 - Most Common PERSON Entities:
# Don Michael Corleone: 4 times
# Michael: 4 times
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0099685 - Most Common PERSON Entities:
# Henry Hill: 4 times
# Jimmy Conway: 4 times
# Tommy De Vito: 4 times
# Henry: 4 times
# Tommy: 4 times
#
# ========================================
#
# Movie ID: tt0099731 - Most Common PERSON Entities:
# Kate: 12 times
# Handmaid: 6 times
# Aunt Lydia: 3 times
# Reid Gagle Set: 2 times
# Reid Gagle: 1 times
#
# ========================================
#
# Movie ID: tt0099739 - Most Common PERSON Entities:
# Nick Riganas: 4 times
#
# ========================================
#
# Movie ID: tt0099785 - Most Common PERSON Entities:
# Kevin: 20 times
# McCallister: 4 times
# Buzz: 4 times
# Harry: 4 times
# John Wiggins: 4 times
#
# ========================================
#
# Movie ID: tt0099810 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt0099871 - Most Common PERSON Entities:
# Jacob Singer: 4 times
# Jacob: 4 times
# Jean-Marc Rocher: 4 times
#
# ========================================
#
# Movie ID: tt0099938 - Most Common PERSON Entities:
# John Kimble: 4 times
# Cullen Crisp: 4 times
# Kimble: 4 times
# Col Needham: 4 times
#
# ========================================
#
# Movie ID: tt0100029 - Most Common PERSON Entities:
# Gaultier: 4 times
# Tognacci Sebastiano: 4 times
# Lyon Gaultier: 1 times
#
# ========================================
#
# Movie ID: tt0100140 - Most Common PERSON Entities:
# Flax: 4 times
# Cher: 4 times
# Paul Skerry: 4 times
#
# ========================================
#
# Movie ID: tt0100150 - Most Common PERSON Entities:
# Tom: 12 times
# Leo: 8 times
# Tom Reagan: 4 times
# Gabriel Byrne: 4 times
# Albert Finney: 4 times
#
# ========================================
#
# Movie ID: tt0100157 - Most Common PERSON Entities:
# Paul: 24 times
# Paul Sheldon: 4 times
# Annie: 4 times
# Andrew Backhouse: 4 times
#
# ========================================
#
# Movie ID: tt0100403 - Most Common PERSON Entities:
# Mike Harrigan: 4 times
# Danny Glover: 4 times
# Jerry Lambert: 4 times
# Bill Paxton: 4 times
# King Willie's: 4 times
#
# ========================================
#
# Movie ID: tt0100404 - Most Common PERSON Entities:
# Rusty: 16 times
# Carolyn: 16 times
# Barbara: 8 times
# Rozat Sabich - Rusty: 4 times
# Barbara Sabich: 4 times
#
# ========================================
#
# Movie ID: tt0100405 - Most Common PERSON Entities:
# Edward Lewis: 4 times
# Philip Stuckey: 4 times
# Edward: 4 times
# Philip: 4 times
# James Morse: 4 times
#
# ========================================
#
# Movie ID: tt0100419 - Most Common PERSON Entities:
# Ben Healy: 4 times
# Flo Healy: 4 times
# Martin Beck: 4 times
# Flo: 4 times
# Ben: 4 times
#
# ========================================
#
# Movie ID: tt0100502 - Most Common PERSON Entities:
# Cane: 4 times
# Murphy: 4 times
# Faxx: 4 times
# Aldo Della Rocca: 4 times
#
# ========================================
#
# Movie ID: tt0100507 - Most Common PERSON Entities:
# Rocky Balboa: 4 times
# Ivan Drago: 4 times
# Balboa: 4 times
# Rocky: 4 times
# Tommy Gunn: 4 times
#
# ========================================
#
# Movie ID: tt0100758 - Most Common PERSON Entities:
# Splinter: 4 times
# Shredder: 4 times
# Tom Zoerner: 4 times
# Tom.Zoerner@informatik.uni-erlangen.de>: 3 times
#
# ========================================
#
# Movie ID: tt0100802 - Most Common PERSON Entities:
# Douglas Quaid: 4 times
# Cohaagen: 4 times
# Harald Mayr: 4 times
#
# ========================================
#
# Movie ID: tt0100814 - Most Common PERSON Entities:
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0100935 - Most Common PERSON Entities:
# Sailor: 8 times
# Tom Zoerner: 4 times
# Tom.Zoerner@informatik.uni-erlangen.de>: 3 times
# Lula: 1 times
#
# ========================================
#
# Movie ID: tt0101272 - Most Common PERSON Entities:
# Charles Addams': 4 times
# Uncle Fester: 4 times
# Fester: 4 times
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0101316 - Most Common PERSON Entities:
# Cal Lott: 4 times
#
# ========================================
#
# Movie ID: tt0101393 - Most Common PERSON Entities:
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0101410 - Most Common PERSON Entities:
# Charlie Meadows: 4 times
# Scott Renshaw: 4 times
#
# ========================================
#
# Movie ID: tt0101414 - Most Common PERSON Entities:
# Belle: 4 times
#
# ========================================
#
# Movie ID: tt0101507 - Most Common PERSON Entities:
# John Singleton's: 4 times
# Ricky Baker: 4 times
# Ricky: 4 times
# Dough: 4 times
# Tre: 4 times
#
# ========================================
#
# Movie ID: tt0101516 - Most Common PERSON Entities:
# Ben Bugsy Siegel: 4 times
# Siegel: 4 times
# Jeremy Perkins: 4 times
#
# ========================================
#
# Movie ID: tt0101540 - Most Common PERSON Entities:
# Sam Bowden: 5 times
# Nick Nolte)is: 4 times
# Max Cady: 4 times
# Robert De Niro: 4 times
# Sam: 4 times
#
# ========================================
#
# Movie ID: tt0101545 - Most Common PERSON Entities:
# Jim: 8 times
# Josie: 8 times
#
# ========================================
#
# Movie ID: tt0101587 - Most Common PERSON Entities:
# Ed: 4 times
# Phil: 4 times
# Sami Al-Taher: 4 times
# Mitch: 1 times
#
# ========================================
#
# Movie ID: tt0101635 - Most Common PERSON Entities:
# Curly Sue: 12 times
# Bill: 8 times
# Bill Dancer: 4 times
# Grey Ellison: 4 times
# Grey: 4 times
#
# ========================================
#
# Movie ID: tt0101745 - Most Common PERSON Entities:
# Benjamin Stone: 4 times
# Lou: 4 times
# Sami Al-Taher: 4 times
#
# ========================================
#
# Movie ID: tt0101757 - Most Common PERSON Entities:
# Mom: 4 times
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0101761 - Most Common PERSON Entities:
# Jim Morrison: 4 times
# Morrison: 4 times
# Val Kilmer: 4 times
# Jim Morrison's: 4 times
# Denise P. Meyer: 4 times
#
# ========================================
#
# Movie ID: tt0101775 - Most Common PERSON Entities:
# C. Marshall: 4 times
#
# ========================================
#
# Movie ID: tt0101862 - Most Common PERSON Entities:
# Spencer Tracy: 4 times
# George and Nina Banks: 4 times
# George: 4 times
# Reid Gagle: 4 times
#
# ========================================
#
# Movie ID: tt0101889 - Most Common PERSON Entities:
# Parry: 4 times
# Jim Sanders: 4 times
#
# ========================================
#
# Movie ID: tt0102057 - Most Common PERSON Entities:
# Peter Pan: 8 times
# Hook: 8 times
# Williams: 4 times
# Hoffman: 4 times
# Peter: 4 times
#
# ========================================
#
# Movie ID: tt0102070 - Most Common PERSON Entities:
# Leonardo da Vinci: 4 times
# Tommy: 4 times
# Harald Mayr: 4 times
# Eddie Hawkins: 1 times
#
# ========================================
#
# Movie ID: tt0102138 - Most Common PERSON Entities:
# Lee Harvey Oswald: 8 times
# Jack Ruby: 8 times
# John F. Kennedy: 4 times
# Jim Garrison: 4 times
# Garrison: 4 times
#
# ========================================
#
# Movie ID: tt0102388 - Most Common PERSON Entities:
# Dani: 16 times
# Elvis: 4 times
# Dad: 4 times
# Court Foster: 4 times
#
# ========================================
#
# Movie ID: tt0102492 - Most Common PERSON Entities:
# Vada Sultenfuss: 4 times
# Anna Chlumsky: 4 times
# Harry: 4 times
# Dan Aykroyd: 4 times
# Thomas J Sennett: 4 times
#
# ========================================
#
# Movie ID: tt0102511 - Most Common PERSON Entities:
# William S. Burrough's: 4 times
# Bill Lee: 4 times
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0102526 - Most Common PERSON Entities:
# Scotty: 8 times
# Mattias Thuresson: 4 times
#
# ========================================
#
# Movie ID: tt0102536 - Most Common PERSON Entities:
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0102558 - Most Common PERSON Entities:
# Demi Moore: 4 times
#
# ========================================
#
# Movie ID: tt0102685 - Most Common PERSON Entities:
# Reagan: 4 times
# Carter: 4 times
# Nixon: 4 times
# Johnson: 4 times
# Johnny Utah: 4 times
#
# ========================================
#
# Movie ID: tt0102744 - Most Common PERSON Entities:
# Quigley: 12 times
# Matt Quigley: 4 times
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0102782 - Most Common PERSON Entities:
# Richard: 20 times
# Sarah: 16 times
# Lilli: 8 times
# Bree Pearson: 4 times
#
# ========================================
#
# Movie ID: tt0102798 - Most Common PERSON Entities:
# Robin: 16 times
# Richard: 12 times
# Prince John: 4 times
# Maid Marian: 4 times
# Graeme Roy: 4 times
#
# ========================================
#
# Movie ID: tt0102803 - Most Common PERSON Entities:
# Secord: 4 times
# Greg Bole: 4 times
#
# ========================================
#
# Movie ID: tt0102926 - Most Common PERSON Entities:
# Jack Crawford: 4 times
# Hannibal Lecter: 4 times
# Lecter: 4 times
# Buffalo Bill: 4 times
#
# ========================================
#
# Movie ID: tt0102975 - Most Common PERSON Entities:
# James T. Kirk: 4 times
# Kirk: 4 times
# Klingon: 4 times
# Rura Penthe: 4 times
# Colin Tinto: 4 times
#
# ========================================
#
# Movie ID: tt0103060 - Most Common PERSON Entities:
# Tom Zoerner: 4 times
#
# ========================================
#
# Movie ID: tt0103064 - Most Common PERSON Entities:
# John Connor: 12 times
# Sarah Connor: 8 times
# John: 8 times
# Sarah: 4 times
# Eric: 1 times
#
# ========================================
#
# Movie ID: tt0103074 - Most Common PERSON Entities:
# Louise: 5 times
# Jimmy: 4 times
# Darryl: 4 times
# Thelma: 4 times
# Harald Mayr: 4 times
#
# ========================================
#
# Movie ID: tt0103639 - Most Common PERSON Entities:
# Jasmine: 4 times
# Jafar: 4 times
#
# ========================================
#
# Movie ID: tt0103644 - Most Common PERSON Entities:
# Newt: 8 times
# Ellen Ripley: 4 times
# Kerwin Tsang: 4 times
#
# ========================================
#
# Movie ID: tt0103772 - Most Common PERSON Entities:
# Catherine: 12 times
# Johnny Boz: 4 times
# Nick Curran: 4 times
# Catherine Tramell: 4 times
#
# ========================================
#
# Movie ID: tt0103776 - Most Common PERSON Entities:
# Bruce Wayne: 8 times
# gotham max: 4 times
# Bat: 4 times
# Max: 4 times
# Kyle: 4 times
#
# ========================================
#
# Movie ID: tt0103855 - Most Common PERSON Entities:
# Reagan: 4 times
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0103873 - Most Common PERSON Entities:
# Sumatran: 4 times
# Lionel Cosgrove: 4 times
# Paquita: 4 times
# Nick Riganas Deep: 3 times
# Nick Riganas: 1 times
#
# ========================================
#
# Movie ID: tt0103874 - Most Common PERSON Entities:
# Dracula: 16 times
# Bram Stoker's: 4 times
# Jonathan Harker: 4 times
# Mina Murray: 4 times
# Lucy Westenra: 4 times
#
# ========================================
#
# Movie ID: tt0103893 - Most Common PERSON Entities:
# Merrick: 8 times
#
# ========================================
#
# Movie ID: tt0103919 - Most Common PERSON Entities:
# Chris Makrozahopoulos: 4 times
# > Helen Lyle: 3 times
# Helen Lyle: 1 times
#
# ========================================
#
# Movie ID: tt0103939 - Most Common PERSON Entities:
# Charles Chaplin: 4 times
# Chaplin: 4 times
# Murray Chapman: 4 times
#
# ========================================
#
# Movie ID: tt0104036 - Most Common PERSON Entities:
# Jody: 8 times
# Jude: 4 times
# Eugene Kim: 4 times
#
# ========================================
#
# Movie ID: tt0104070 - Most Common PERSON Entities:
# Madeline Ashton: 4 times
# Williams: 4 times
# Sweet Bird: 4 times
# Helen Sharp: 4 times
# Ernest Menville: 4 times
#
# ========================================
#
# Movie ID: tt0104257 - Most Common PERSON Entities:
# Daniel Kaffee: 4 times
# Aunt Ginny: 4 times
# Cmdr: 4 times
# Galloway: 4 times
# LTJG Sam Weinberg: 4 times
#
# ========================================
#
# Movie ID: tt0104348 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt0104389 - Most Common PERSON Entities:
# Claire: 8 times
# Rebecca De Mornay: 4 times
# Victor Mott: 4 times
# John de Lancie: 4 times
# Peyton: 4 times
#
# ========================================
#
# Movie ID: tt0104431 - Most Common PERSON Entities:
# Kevin: 12 times
# Kevin McCallister: 4 times
# Harry: 4 times
# Anthony Pereyra: 4 times
#
# ========================================
#
# Movie ID: tt0104691 - Most Common PERSON Entities:
# Chingachgook: 4 times
# Hawkeye: 4 times
#
# ========================================
#
# Movie ID: tt0104694 - Most Common PERSON Entities:
# Dottie Hinson: 4 times
# Kit: 4 times
# Jimmy Dugan: 4 times
# Dottie: 4 times
#
# ========================================
#
# Movie ID: tt0104714 - Most Common PERSON Entities:
# Martin Riggs: 4 times
# Lorna Cole: 4 times
# Roger Murtaugh: 4 times
# Jack Travis: 4 times
# Murtaugh: 4 times
#
# ========================================
#
# Movie ID: tt0104779 - Most Common PERSON Entities:
# Oscar: 12 times
# Nigel: 8 times
# Nigel Dobson: 4 times
# Sami Al-Taher: 4 times
#
# ========================================
#
# Movie ID: tt0104797 - Most Common PERSON Entities:
# Malcolm X: 4 times
# Malcolm Little: 4 times
# Malcolm: 4 times
# Elijah Muhammad: 4 times
# Anonymous Biograpical: 3 times
#
# ========================================
#
# Movie ID: tt0104940 - Most Common PERSON Entities:
# Dickens: 4 times
# Ebenezer Scrooge: 4 times
# Murray Chapman: 4 times
#
# ========================================
#
# Movie ID: tt0104952 - Most Common PERSON Entities:
# Bill: 8 times
# Vinny: 8 times
# Bill Gambini: 4 times
# Stanley Rothenstein: 4 times
# Stan: 4 times
#
# ========================================
#
# Movie ID: tt0104990 - Most Common PERSON Entities:
# Joseph Pulitzer: 4 times
# William Randolph Hearst: 4 times
# Jack "Cowboy" Kelly (: 4 times
# Christian Bale: 4 times
# David Jacobs: 4 times
#
# ========================================
#
# Movie ID: tt0105112 - Most Common PERSON Entities:
# Jack: 16 times
# Jack Ryan: 4 times
#
# ========================================
#
# Movie ID: tt0105156 - Most Common PERSON Entities:
# Drew Barrymore': 4 times
# Gilbert: 4 times
# Ladd: 4 times
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0105236 - Most Common PERSON Entities:
# Joe Cabot: 4 times
#
# ========================================
#
# Movie ID: tt0105265 - Most Common PERSON Entities:
# Norman: 12 times
# Paul: 4 times
#
# ========================================
#
# Movie ID: tt0105275 - Most Common PERSON Entities:
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0105323 - Most Common PERSON Entities:
# Frank: 13 times
# Lt Col: 4 times
# Charlie: 4 times
# Rob Hartill Frank: 3 times
# Rob Hartill: 1 times
#
# ========================================
#
# Movie ID: tt0105327 - Most Common PERSON Entities:
# David: 8 times
# David Green: 4 times
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0105417 - Most Common PERSON Entities:
# Vince: 16 times
# Eddie: 8 times
# Deloris Wilson: 4 times
# Deloris Van Cartier: 4 times
# Vince LaRocca: 4 times
#
# ========================================
#
# Movie ID: tt0105629 - Most Common PERSON Entities:
# Leslie: 8 times
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0105665 - Most Common PERSON Entities:
# David Lynch: 4 times
# Mark Frost's: 4 times
# Chet Desmond: 4 times
# Chris Isaak: 4 times
# Sam Stanley: 4 times
#
# ========================================
#
# Movie ID: tt0105690 - Most Common PERSON Entities:
# Krill: 16 times
# Ryback: 8 times
# Casey Ryback: 4 times
# Adam: 4 times
# William Stranix: 4 times
#
# ========================================
#
# Movie ID: tt0105695 - Most Common PERSON Entities:
# Munny: 8 times
# Bill: 4 times
# William Munny: 4 times
# Ned: 4 times
# Charlie Ness: 4 times
#
# ========================================
#
# Movie ID: tt0105698 - Most Common PERSON Entities:
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0106220 - Most Common PERSON Entities:
# Fester: 4 times
#
# ========================================
#
# Movie ID: tt0106308 - Most Common PERSON Entities:
# Arthur: 16 times
# Ash: 8 times
# Duke Henry the Red: 4 times
# Claudio Carvalho: 4 times
#
# ========================================
#
# Movie ID: tt0106489 - Most Common PERSON Entities:
# Lorenzo: 4 times
# Sonny: 4 times
# Horacio Abeledo: 4 times
# Gangster Sonny: 1 times
#
# ========================================
#
# Movie ID: tt0106519 - Most Common PERSON Entities:
# Carlito Brigante: 4 times
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0106582 - Most Common PERSON Entities:
# Michael Feller: 4 times
#
# ========================================
#
# Movie ID: tt0106611 - Most Common PERSON Entities:
# Irving Blitzer: 8 times
# Irv: 4 times
# Julian Reischl: 4 times
#
# ========================================
#
# Movie ID: tt0106697 - Most Common PERSON Entities:
# Simon Phoenix: 4 times
# John Spartan: 4 times
# Rob Hartill Frozen: 3 times
# Frozen: 1 times
# Rob Hartill: 1 times
#
# ========================================
#
# Movie ID: tt0106701 - Most Common PERSON Entities:
# Wilson: 6 times
# Dennis: 3 times
# Brian W. Martz: 3 times
#
# ========================================
#
# Movie ID: tt0106856 - Most Common PERSON Entities:
# William: 12 times
# Foster: 4 times
# Michael Douglas: 4 times
# Barbara Hershey: 4 times
# Lee: 4 times
#
# ========================================
#
# Movie ID: tt0106977 - Most Common PERSON Entities:
# Kimble: 16 times
# Richard Kimble: 4 times
# Helen: 4 times
# Justifiable Reason: 4 times
# Samuel Gerard: 4 times
#
# ========================================
#
# Movie ID: tt0107034 - Most Common PERSON Entities:
# Mark: 12 times
# Henry: 8 times
# Sam Following: 3 times
# Sam: 1 times
#
# ========================================
#
# Movie ID: tt0107048 - Most Common PERSON Entities:
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0107050 - Most Common PERSON Entities:
# John: 4 times
# Max: 4 times
# Ariel: 4 times
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0107120 - Most Common PERSON Entities:
# Sanderson: 4 times
# Max: 4 times
#
# ========================================
#
# Movie ID: tt0107207 - Most Common PERSON Entities:
# Gerry Conlon: 4 times
# Gerry: 4 times
# Liza Esser: 4 times
#
# ========================================
#
# Movie ID: tt0107290 - Most Common PERSON Entities:
# John Hammond: 4 times
#
# ========================================
#
# Movie ID: tt0107362 - Most Common PERSON Entities:
# Slater: 16 times
# Danny: 12 times
# Jack Slater: 8 times
# Danny Madigan: 4 times
# Arnold Schwarzenegger: 4 times
#
# ========================================
#
# Movie ID: tt0107614 - Most Common PERSON Entities:
# Miranda: 12 times
# Daniel: 12 times
# Daniel Hillard: 4 times
# Mrs Doubtfire: 4 times
# Stu Dunemyer: 4 times
#
# ========================================
#
# Movie ID: tt0107616 - Most Common PERSON Entities:
# Claudio: 3 times
# Don Pedro: 3 times
# Benedick: 3 times
# Don Jon: 3 times
# Liza Esser: 3 times
#
# ========================================
#
# Movie ID: tt0107688 - Most Common PERSON Entities:
# Jack Skellington: 4 times
# Jon Reeves: 4 times
#
# ========================================
#
# Movie ID: tt0107719 - Most Common PERSON Entities:
# Marie: 2 times
# Cohen: 1 times
# Mouse King: 1 times
#
# ========================================
#
# Movie ID: tt0107808 - Most Common PERSON Entities:
# Butch Haynes: 4 times
# Terry Pugh: 4 times
# Philip Perry: 4 times
# Butch: 4 times
# Philip: 4 times
#
# ========================================
#
# Movie ID: tt0107818 - Most Common PERSON Entities:
# Andrew Beckett: 4 times
# Andrew: 4 times
# Joe Miller: 4 times
# Miller: 4 times
# Geoffrey A. Middleton: 4 times
#
# ========================================
#
# Movie ID: tt0107822 - Most Common PERSON Entities:
# Ada: 12 times
# George: 12 times
# Stewart: 8 times
# Flora: 4 times
# Patrick Dominick: 4 times
#
# ========================================
#
# Movie ID: tt0107943 - Most Common PERSON Entities:
# Keith Loh: 4 times
#
# ========================================
#
# Movie ID: tt0107977 - Most Common PERSON Entities:
# Robin: 12 times
# Prince John: 8 times
# Richard: 8 times
# John: 8 times
# Rottingham: 4 times
#
# ========================================
#
# Movie ID: tt0108002 - Most Common PERSON Entities:
# Brian W Martz: 4 times
# Rudy: 1 times
#
# ========================================
#
# Movie ID: tt0108037 - Most Common PERSON Entities:
# Dan Urson Scotty Smalls: 3 times
# Scotty Smalls: 1 times
# Dan Urson: 1 times
#
# ========================================
#
# Movie ID: tt0108052 - Most Common PERSON Entities:
# Oskar Schindler: 8 times
# Harald Mayr: 4 times
#
# ========================================
#
# Movie ID: tt0108071 - Most Common PERSON Entities:
# Mary Lennox: 4 times
#
# ========================================
#
# Movie ID: tt0108160 - Most Common PERSON Entities:
# Sam: 28 times
# Maggie: 12 times
# Jonah: 12 times
# Annie: 8 times
# Sam Baldwin: 4 times
#
# ========================================
#
# Movie ID: tt0108333 - Most Common PERSON Entities:
# D'Artagnan: 8 times
# Milady: 4 times
#
# ========================================
#
# Movie ID: tt0108358 - Most Common PERSON Entities:
# Wyatt Earp: 4 times
# Doc Holliday: 4 times
# Ed Sutton: 4 times
#
# ========================================
#
# Movie ID: tt0108399 - Most Common PERSON Entities:
# Clarence Worley: 4 times
# Dick Ritchie: 4 times
# Clifford Worley: 4 times
# Claudio Carvalho: 4 times
#
# ========================================
#
# Movie ID: tt0108550 - Most Common PERSON Entities:
# Arnie: 16 times
# Gilbert: 12 times
# Ellen: 4 times
# Amy: 4 times
# Bonnie Grape: 4 times
#
# ========================================
#
# Movie ID: tt0109040 - Most Common PERSON Entities:
# Ace Ventura: 4 times
# mascot: 4 times
# Lars J. Aas: 4 times
#
# ========================================
#
# Movie ID: tt0109254 - Most Common PERSON Entities:
# Foley: 20 times
# Todd: 8 times
# Axel Foley: 4 times
# Billy Rosewood: 4 times
# Billy: 4 times
#
# ========================================
#
# Movie ID: tt0109424 - Most Common PERSON Entities:
# Wong Kar-Wai's: 4 times
# Cop: 4 times
# Tad Dibbern: 4 times
#
# ========================================
#
# Movie ID: tt0109444 - Most Common PERSON Entities:
# Ryan: 12 times
# Jack Ryan: 4 times
# James Greer: 4 times
#
# ========================================
#
# Movie ID: tt0109445 - Most Common PERSON Entities:
# Dante: 8 times
# Dante Hicks: 4 times
# Caitlin: 4 times
# Randal Graves: 4 times
#
# ========================================
#
# Movie ID: tt0109506 - Most Common PERSON Entities:
# Eric Draven: 4 times
# buff T-Bird: 4 times
# Eric: 4 times
# Don Hoffman: 4 times
#
# ========================================
#
# Movie ID: tt0109635 - Most Common PERSON Entities:
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0109686 - Most Common PERSON Entities:
# Lloyd: 4 times
# Mary Swanson: 4 times
# Mary: 4 times
# Sam Harry: 3 times
# Harry: 1 times
#
# ========================================
#
# Movie ID: tt0109707 - Most Common PERSON Entities:
# Ed: 8 times
# Edward D. Wood Jr.: 4 times
#
# ========================================
#
# Movie ID: tt0109830 - Most Common PERSON Entities:
# Forrest: 8 times
# Forrest Gump: 4 times
# Jenny: 4 times
# Dan: 4 times
# Bubba: 4 times
#
# ========================================
#
# Movie ID: tt0109831 - Most Common PERSON Entities:
# Charles: 8 times
# Carrie: 4 times
# Rob Hartill: 4 times
#
# ========================================
#
# Movie ID: tt0110005 - Most Common PERSON Entities:
# Juliet Hulme: 4 times
# Pauline Parker: 4 times
# Pauline: 4 times
# Alexander Lum: 4 times
#
# ========================================
#
# Movie ID: tt0110148 - Most Common PERSON Entities:
# Louis: 4 times
# Louis accepts: 4 times
#
# ========================================
#
# Movie ID: tt0110322 - Most Common PERSON Entities:
# Samuel: 12 times
# Alfred: 8 times
# William Ludlow: 4 times
# Susannah: 4 times
#
# ========================================
#
# Movie ID: tt0110357 - Most Common PERSON Entities:
# femaledragon1234: 1 times
#
# ========================================
#
# Movie ID: tt0110367 - Most Common PERSON Entities:
# Louisa May Alcott's: 4 times
# Jo: 4 times
# Amy: 4 times
# Beth: 4 times
#
# ========================================
#
# Movie ID: tt0110413 - Most Common PERSON Entities:
# J. S. Golden: 4 times
#
# ========================================
#
# Movie ID: tt0110475 - Most Common PERSON Entities:
# Stanley Ipkiss: 4 times
# Jim Carrey: 4 times
# Dorian Tyrel: 4 times
# Peter Greene: 4 times
# Ipkiss: 4 times
#
# ========================================
#
# Movie ID: tt0110478 - Most Common PERSON Entities:
# James Garner: 4 times
# Maverick: 4 times
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0110598 - Most Common PERSON Entities:
# Muriel: 5 times
# Lynn Salmon Muriel: 3 times
# Lynn Salmon: 1 times
#
# ========================================
#
# Movie ID: tt0110632 - Most Common PERSON Entities:
# Mickey Knox: 4 times
# Mallory Wilson: 4 times
#
# ========================================
#
# Movie ID: tt0110729 - Most Common PERSON Entities:
# Jake: 8 times
# Heke: 4 times
# Jake Heke: 4 times
# Chris Maslin: 4 times
#
# ========================================
#
# Movie ID: tt0110763 - Most Common PERSON Entities:
# Richard: 8 times
# Richard Tyler: 4 times
# Anthony Pereyra: 4 times
#
# ========================================
#
# Movie ID: tt0110912 - Most Common PERSON Entities:
# Wallace: 12 times
# Jules Winnfield: 4 times
# Samuel L. Jackson: 4 times
# Vincent Vega: 4 times
# John Travolta: 4 times
#
# ========================================
#
# Movie ID: tt0110989 - Most Common PERSON Entities:
# Rich: 2 times
# Laurence Van Dough: 2 times
# Mark J. Popp: 2 times
#
# ========================================
#
# Movie ID: tt0110997 - Most Common PERSON Entities:
# Gail: 12 times
# Wade: 12 times
# Terry: 12 times
# Gail Hartman: 4 times
# Tom Hartman: 4 times
#
# ========================================
#
# Movie ID: tt0111070 - Most Common PERSON Entities:
# Charlie: 8 times
# Scott: 4 times
# Anonymous Divorcee Scott Calvin: 3 times
# Scott Calvin: 1 times
#
# ========================================
#
# Movie ID: tt0111161 - Most Common PERSON Entities:
# Shawshank: 4 times
#
# ========================================
#
# Movie ID: tt0111257 - Most Common PERSON Entities:
# Jack: 8 times
# Joe Morton: 4 times
# Jeff Daniels: 4 times
# Kris Hopson: 4 times
#
# ========================================
#
# Movie ID: tt0111282 - Most Common PERSON Entities:
# Daniel Jackson: 4 times
# Jackson: 4 times
# Jonathan ': 4 times
# Claudio Carvalho: 4 times
#
# ========================================
#
# Movie ID: tt0111438 - Most Common PERSON Entities:
# Max: 16 times
# McComb: 8 times
# Max Walker: 4 times
#
# ========================================
#
# Movie ID: tt0111495 - Most Common PERSON Entities:
# Valentine: 9 times
# Yepok Valentine: 3 times
# Yepok: 1 times
#
# ========================================
#
# Movie ID: tt0111503 - Most Common PERSON Entities:
# Harry: 8 times
# Harry Tasker: 4 times
# Arnold Schwarzenegger: 4 times
# Bill Paxton: 4 times
# John Vogel: 4 times
#
# ========================================
#
# Movie ID: tt0112281 - Most Common PERSON Entities:
# Wachootoo: 4 times
# Wachati: 4 times
# Ace: 4 times
# Jonathan Broxton: 4 times
# Ace Ventura: 1 times
#
# ========================================
#
# Movie ID: tt0112384 - Most Common PERSON Entities:
# Astronauts Lovell: 4 times
# Haise: 4 times
# Rob Hartill Based: 3 times
# Rob Hartill: 1 times
#
# ========================================
#
# Movie ID: tt0112442 - Most Common PERSON Entities:
# Marcus Burnett: 4 times
# Mike Lowry: 4 times
# James Hastie: 4 times
#
# ========================================
#
# Movie ID: tt0112462 - Most Common PERSON Entities:
# Gotham: 8 times
# Harvey Dent: 4 times
# Edward Nygma: 4 times
# Bruce Wayne: 4 times
# Bruce Wayne's: 4 times
#
# ========================================
#
# Movie ID: tt0112471 - Most Common PERSON Entities:
# Jesse: 12 times
#
# ========================================
#
# Movie ID: tt0112508 - Most Common PERSON Entities:
# Billy: 20 times
# Brian: 8 times
# Eric Gordon: 4 times
# Eric: 4 times
# Sam Billy Madison: 3 times
#
# ========================================
#
# Movie ID: tt0112573 - Most Common PERSON Entities:
# William Wallace: 5 times
# Edward the Longshanks: 4 times
# William Wallace's: 4 times
# Robert the Bruce.                : 4 times
# Anonymous William Wallace: 3 times
#
# ========================================
#
# Movie ID: tt0112641 - Most Common PERSON Entities:
# Nicky: 8 times
# Ace Rothstein: 4 times
# Nicky Santoro: 4 times
# Ginger: 4 times
# Tad Dibbern: 4 times
#
# ========================================
#
# Movie ID: tt0112642 - Most Common PERSON Entities:
# Crittenden: 4 times
# James Harvey: 4 times
# Stretch: 4 times
# Fatso: 4 times
# Joshua Davis: 4 times
#
# ========================================
#
# Movie ID: tt0112697 - Most Common PERSON Entities:
# Michael Kaminsky: 4 times
# Cher: 1 times
#
# ========================================
#
# Movie ID: tt0112760 - Most Common PERSON Entities:
# William Shaw: 4 times
# Dawg: 4 times
# Stern Morgan Adams: 3 times
#
# ========================================
#
# ...
# Nick Dunne: 8 times
# Amy: 4 times
#
# ========================================
#
# Movie ID: tt2278388 - Most Common PERSON Entities:
# Zero Moustafa: 4 times
#
# ========================================
#
# Movie ID: tt2278871 - Most Common PERSON Entities:
# Emma: 8 times
# Adèle: 8 times
#
# ========================================
#
# Movie ID: tt2283362 - Most Common PERSON Entities:
# Alan Parrish: 4 times
#
# ========================================
#
# Movie ID: tt2293640 - Most Common PERSON Entities:
# Kevin: 4 times
# Bob: 4 times
# Minionkind: 4 times
#
# ========================================
#
# Movie ID: tt2294449 - Most Common PERSON Entities:
# Schmidt: 8 times
# Jenko: 8 times
# Jonah Hill: 4 times
#
# ========================================
#
# Movie ID: tt2294629 - Most Common PERSON Entities:
# Anna: 12 times
# Elsa: 12 times
# Kristoff: 8 times
#
# ========================================
#
# Movie ID: tt2304933 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt2305051 - Most Common PERSON Entities:
# Cheryl Strayed: 4 times
# Cheryl: 4 times
# Spencer Higham: 4 times
#
# ========================================
#
# Movie ID: tt2310332 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt2316411 - Most Common PERSON Entities:
# Claire: 16 times
# Adam: 12 times
# Adam Bell: 4 times
# Mary: 4 times
# Daniel Saint Claire: 4 times
#
# ========================================
#
# Movie ID: tt2322441 - Most Common PERSON Entities:
# Christian Grey: 8 times
# Anastasia Steele: 4 times
# Kate Kavanagh: 4 times
# Christian Grey - despite: 4 times
# Grey: 4 times
#
# ========================================
#
# Movie ID: tt2338151 - Most Common PERSON Entities:
# P. K.'s: 4 times
# Abhijat Joshi P. K.: 3 times
# P. K.: 1 times
# Abhijat Joshi: 1 times
#
# ========================================
#
# Movie ID: tt2356777 - Most Common PERSON Entities:
# Martin Hart: 4 times
#
# ========================================
#
# Movie ID: tt2379713 - Most Common PERSON Entities:
# James Bond: 4 times
# Lucia: 4 times
# Max Denbigh: 4 times
# MI6: 4 times
# Moneypenny: 4 times
#
# ========================================
#
# Movie ID: tt2381249 - Most Common PERSON Entities:
# Hunley: 8 times
# Baldwin: 4 times
# Ethan Hunt: 4 times
# Hunt: 4 times
#
# ========================================
#
# Movie ID: tt2395427 - Most Common PERSON Entities:
# applenatalia9 Tony Stark: 3 times
# Tony Stark: 1 times
# applenatalia9: 1 times
#
# ========================================
#
# Movie ID: tt2397535 - Most Common PERSON Entities:
# Anonymous PREDESTINATION: 3 times
#
# ========================================
#
# Movie ID: tt2402927 - Most Common PERSON Entities:
# Patricia Highsmith's: 4 times
# Rooney Mara: 4 times
# Carol: 4 times
# Kyle Chandler: 4 times
# Abby: 4 times
#
# ========================================
#
# Movie ID: tt2404233 - Most Common PERSON Entities:
# James Pasier Set: 3 times
# James Pasier: 1 times
#
# ========================================
#
# Movie ID: tt2404435 - Most Common PERSON Entities:
# Antoine Fuqua: 4 times
# Bartholomew Bogue: 4 times
#
# ========================================
#
# Movie ID: tt2404463 - Most Common PERSON Entities:
# Larkin: 20 times
# Rojas: 12 times
# Mullins: 12 times
# Ashburn: 12 times
# Sarah Ashburn: 4 times
#
# ========================================
#
# Movie ID: tt2488496 - Most Common PERSON Entities:
# Rey: 8 times
# Darth Vader: 4 times
# Jakku: 4 times
# Luke Skywalker: 4 times
# Noah: 3 times
#
# ========================================
#
# Movie ID: tt2527336 - Most Common PERSON Entities:
# Rey: 4 times
# Luke Skywalker: 4 times
#
# ========================================
#
# Movie ID: tt2543164 - Most Common PERSON Entities:
# Louise Banks: 4 times
# Banks: 4 times
# Jwelch5742 Linguistics: 3 times
#
# ========================================
#
# Movie ID: tt2554274 - Most Common PERSON Entities:
# Thomas Sharpe: 4 times
# Thomas: 4 times
# Lady Lucille Sharpe: 4 times
# gore: 4 times
#
# ========================================
#
# Movie ID: tt2562232 - Most Common PERSON Entities:
# Riggan Thomson: 8 times
# Birdman: 8 times
# Riggan: 8 times
#
# ========================================
#
# Movie ID: tt2582782 - Most Common PERSON Entities:
# Toby Howard: 4 times
# Tanner Howard: 4 times
# Alberto Parker: 4 times
# Claudio Carvalho: 4 times
#
# ========================================
#
# Movie ID: tt2582802 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt2582846 - Most Common PERSON Entities:
# Hazel: 5 times
# Augustus: 4 times
# Gus: 4 times
# Anonymous Hazel: 3 times
#
# ========================================
#
# Movie ID: tt2632424 - Most Common PERSON Entities:
# Klaus: 16 times
# Mikaelson: 4 times
# Joseph Morgan: 4 times
# Rebekah: 4 times
# Charles Michael Davis: 4 times
#
# ========================================
#
# Movie ID: tt2660888 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt2661044 - Most Common PERSON Entities:
# wenis galore: 4 times
# Ark: 4 times
# Thomas O'Darren: 4 times
#
# ========================================
#
# Movie ID: tt2674426 - Most Common PERSON Entities:
# Lou: 8 times
# Patrick: 4 times
# Will Traynor: 4 times
# nattattck-11 Lou Clark: 3 times
# Lou Clark: 1 times
#
# ========================================
#
# Movie ID: tt2692250 - Most Common PERSON Entities:
# Ahkmenrah: 12 times
# Larry: 12 times
# Larry Daley: 4 times
# Pharaoh: 4 times
# McPhee: 4 times
#
# ========================================
#
# Movie ID: tt2713180 - Most Common PERSON Entities:
# Gordo': 4 times
# Garcia: 4 times
# Norman Ellison: 4 times
# Claudio Carvalho: 4 times
#
# ========================================
#
# Movie ID: tt2719848 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt2802144 - Most Common PERSON Entities:
# Harry: 16 times
# Kingsman: 4 times
# Valentine: 4 times
#
# ========================================
#
# Movie ID: tt2820852 - Most Common PERSON Entities:
# Owen Shaw: 4 times
# Deckard Shaw: 4 times
# Jakarde: 4 times
# Nobody: 4 times
#
# ========================================
#
# Movie ID: tt2848292 - Most Common PERSON Entities:
# Chris Greenleaf: 4 times
#
# ========================================
#
# Movie ID: tt2872718 - Most Common PERSON Entities:
# Lou: 8 times
# Jake Gyllenhaal: 4 times
# Lou Bloom: 4 times
# Rene Russo: 4 times
#
# ========================================
#
# Movie ID: tt2872732 - Most Common PERSON Entities:
# Lucy: 16 times
# Jang: 4 times
# Norman: 4 times
# Pierre Del Rio: 4 times
#
# ========================================
#
# Movie ID: tt2911666 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt2948356 - Most Common PERSON Entities:
# Judy Hopps: 4 times
# Judy: 4 times
# Nick Wilde: 4 times
#
# ========================================
#
# Movie ID: tt2975590 - Most Common PERSON Entities:
# Superman: 8 times
# Gotham: 4 times
# ,Meanwhile Superman: 4 times
# Lex Luthor: 4 times
#
# ========================================
#
# Movie ID: tt2980516 - Most Common PERSON Entities:
# Stephen Hawking: 8 times
# Jane Wilde: 8 times
# Einstein: 4 times
# Spencer Higham: 4 times
#
# ========================================
#
# Movie ID: tt3076658 - Most Common PERSON Entities:
# Adonis: 8 times
# Rocky: 8 times
# Adonis Johnson: 4 times
# Apollo Creed: 4 times
# Rocky Balboa: 4 times
#
# ========================================
#
# Movie ID: tt3079380 - Most Common PERSON Entities:
# Susan Cooper: 4 times
#
# ========================================
#
# Movie ID: tt3152624 - Most Common PERSON Entities:
# Amy: 20 times
# Dianna: 8 times
# Gordon Townsend: 4 times
# Amy Townsend: 4 times
# Steven: 4 times
#
# ========================================
#
# Movie ID: tt3170832 - Most Common PERSON Entities:
# Jack: 20 times
# Ma: 16 times
#
# ========================================
#
# Movie ID: tt3183660 - Most Common PERSON Entities:
# Newt: 8 times
# Newt Scamander: 4 times
# Mary Lou Barebone: 4 times
# Gellert Grindelwald: 4 times
# Jacob Kowalski: 4 times
#
# ========================================
#
# Movie ID: tt3205802 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt3235888 - Most Common PERSON Entities:
# Jay: 4 times
# Jose Tamayo: 4 times
#
# ========================================
#
# Movie ID: tt3315342 - Most Common PERSON Entities:
# Laura: 8 times
# Wolverine: 4 times
#
# ========================================
#
# Movie ID: tt3322364 - Most Common PERSON Entities:
# David: 4 times
# Goliath: 4 times
# Bennet Omalu: 4 times
# Omalu: 4 times
# Will Smith: 1 times
#
# ========================================
#
# Movie ID: tt3332064 - Most Common PERSON Entities:
# Peter: 4 times
# Peter Pan: 4 times
#
# ========================================
#
# Movie ID: tt3385516 - Most Common PERSON Entities:
# Magneto: 4 times
# Raven: 4 times
#
# ========================================
#
# Movie ID: tt3397884 - Most Common PERSON Entities:
# Kate Macer: 4 times
# Emily Blunt: 4 times
# Gusde: 4 times
#
# ========================================
#
# Movie ID: tt3402236 - Most Common PERSON Entities:
# Hercule Poirot: 4 times
#
# ========================================
#
# Movie ID: tt3416742 - Most Common PERSON Entities:
# Viago: 4 times
# Taika Waititi: 4 times
# Jonathan Brugh: 4 times
# Vladislav: 4 times
#
# ========================================
#
# Movie ID: tt3460252 - Most Common PERSON Entities:
# John Ruth: 4 times
# Daisy Domergue: 4 times
# Ruth: 4 times
# Daisy: 4 times
# Marquis Warren: 4 times
#
# ========================================
#
# Movie ID: tt3464902 - Most Common PERSON Entities:
# R. Byma: 4 times
#
# ========================================
#
# Movie ID: tt3470600 - Most Common PERSON Entities:
# koala: 4 times
# Buster Moon: 4 times
# Nick Nevi: 4 times
#
# ========================================
#
# Movie ID: tt3498820 - Most Common PERSON Entities:
# America: 4 times
# Spider-Man: 4 times
# Bucky Barnes: 4 times
# Hawkeye: 4 times
# Ant Man: 4 times
#
# ========================================
#
# Movie ID: tt3501632 - Most Common PERSON Entities:
# Ragnarok: 4 times
# Hela: 4 times
# Thor: 3 times
#
# ========================================
#
# Movie ID: tt3521164 - Most Common PERSON Entities:
# Moana Waialiki: 4 times
# Maui: 4 times
# Moana: 4 times
#
# ========================================
#
# Movie ID: tt3530002 - Most Common PERSON Entities:
# Ethan: 4 times
# Joseph Gordon-Levitt: 4 times
# Isaac: 4 times
# Seth Rogen: 4 times
# Chris: 4 times
#
# ========================================
#
# Movie ID: tt3532216 - Most Common PERSON Entities:
# Barry Seal: 4 times
# Barry: 4 times
# Viir khubchandani: 4 times
#
# ========================================
#
# Movie ID: tt3631112 - Most Common PERSON Entities:
# Megan: 8 times
# Rachel Watson's: 4 times
# Scott Hipwell: 4 times
# Megan Hipwell: 4 times
# Rachel: 4 times
#
# ========================================
#
# Movie ID: tt3640424 - Most Common PERSON Entities:
# Max: 8 times
# Max Vatan: 4 times
# Marianne: 4 times
# Nick Riganas: 4 times
#
# ========================================
#
# Movie ID: tt3647998 - Most Common PERSON Entities:
# James Keziah Delaney: 4 times
#
# ========================================
#
# Movie ID: tt3659388 - Most Common PERSON Entities:
# Mark Watney: 4 times
#
# ========================================
#
# Movie ID: tt3682448 - Most Common PERSON Entities:
# James B. Donovan: 4 times
# Francis G. Powers: 4 times
# Rudolf Abel: 4 times
# Gusde: 4 times
#
# ========================================
#
# Movie ID: tt3741834 - Most Common PERSON Entities:
# Saroo: 20 times
# Brierley: 4 times
# Kenneth Chisholm: 4 times
#
# ========================================
#
# Movie ID: tt3748528 - Most Common PERSON Entities:
# Ryan Cullmann: 4 times
#
# ========================================
#
# Movie ID: tt3783958 - Most Common PERSON Entities:
# Sebastian: 4 times
#
# ========================================
#
# Movie ID: tt3850590 - Most Common PERSON Entities:
# Max: 4 times
# Krampus: 4 times
#
# ========================================
#
# Movie ID: tt3896198 - Most Common PERSON Entities:
# Xandar: 4 times
# Ronan: 4 times
# Star Lord: 4 times
# Chris Pratt: 4 times
#
# ========================================
#
# Movie ID: tt4016934 - Most Common PERSON Entities:
# Sookee: 8 times
# Uncle: 4 times
# Kouzuki: 4 times
# Lady: 4 times
#
# ========================================
#
# Movie ID: tt4034228 - Most Common PERSON Entities:
# Lee Chandler: 4 times
#
# ========================================
#
# Movie ID: tt4046784 - Most Common PERSON Entities:
# Gladers: 8 times
# Maze Runner: 4 times
# Thomas: 4 times
# Dylan O'Brien: 4 times
#
# ========================================
#
# Movie ID: tt4263482 - Most Common PERSON Entities:
# William: 4 times
# Katherine: 4 times
#
# ========================================
#
# Movie ID: tt4501244 - Most Common PERSON Entities:
# Ned: 8 times
# Laird: 8 times
#
# ========================================
#
# Movie ID: tt4550098 - Most Common PERSON Entities:
# Susan: 8 times
#
# ========================================
#
# Movie ID: tt4555426 - Most Common PERSON Entities:
# Winston Churchill: 4 times
# Gary Oldman: 4 times
# King: 4 times
# Churchill: 4 times
#
# ========================================
#
# Movie ID: tt4574334 - Most Common PERSON Entities:
# Charles J. In: 3 times
# Charles J.: 1 times
#
# ========================================
#
# Movie ID: tt4622512 - Most Common PERSON Entities:
# Billie Jean King: 4 times
# Emma Stone: 4 times
# Bobby Riggs: 4 times
# Steve Carell: 4 times
# King: 4 times
#
# ========================================
#
# Movie ID: tt4649466 - Most Common PERSON Entities:
# Poppy Adams: 4 times
# Statesman: 4 times
# Viir khubchandani: 4 times
#
# ========================================
#
# Movie ID: tt4651520 - Most Common PERSON Entities:
# Amy: 4 times
#
# ========================================
#
# Movie ID: tt4682786 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt4731136 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt4765284 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt4846340 - Most Common PERSON Entities:
# John Glenn: 4 times
# Dorothy Vaughan: 4 times
# Mary Jackson: 4 times
# Katherine Johnson: 4 times
#
# ========================================
#
# Movie ID: tt4925292 - Most Common PERSON Entities:
# Dehlia: 1 times
#
# ========================================
#
# Movie ID: tt4972582 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt4975722 - Most Common PERSON Entities:
# Paula: 8 times
# Juan: 8 times
# Kevin: 4 times
#
# ========================================
#
# Movie ID: tt5013056 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt5027774 - Most Common PERSON Entities:
# Martin McDonagh: 4 times
# Mildred Hayes: 4 times
# Frances McDormand: 4 times
# William Willoughby: 4 times
# Woody Harrelson: 4 times
#
# ========================================
#
# Movie ID: tt5052448 - Most Common PERSON Entities:
# Chris: 5 times
# Rose: 4 times
# Anonymous Chris: 3 times
#
# ========================================
#
# Movie ID: tt5074352 - Most Common PERSON Entities:
# Babita Kumari: 8 times
# Geeta Phogat: 8 times
# Mahavir Singh Phogat: 4 times
#
# ========================================
#
# Movie ID: tt5109784 - Most Common PERSON Entities:
#
# ========================================
#
# Movie ID: tt5311514 - Most Common PERSON Entities:
# Happy_Evil_Dude Mitsuha: 3 times
#
# ========================================
#
# Movie ID: tt5362988 - Most Common PERSON Entities:
# Elizabeth Olsen: 4 times
# Jeremy Renner: 4 times
#
# ========================================
#
# Movie ID: tt5439796 - Most Common PERSON Entities:
# Joe: 8 times
# Jimmy Logan: 4 times
# Clyde: 4 times
# Adam Driver: 4 times
# Mellie: 4 times
#
# ========================================
#
# Movie ID: tt5519340 - Most Common PERSON Entities:
# Dayl Ward: 4 times
# Nick Jakoby: 4 times
# Ward: 4 times
# Shield: 4 times
# Leilah: 4 times
#
# ========================================
#
# Movie ID: tt5580036 - Most Common PERSON Entities:
# Tonya Harding: 2 times
#
# ========================================
#
# Movie ID: tt5580390 - Most Common PERSON Entities:
# Elisa: 8 times
# Guillermo del Toro: 4 times
# Sally Hawkins: 4 times
# Zelda: 4 times
# Michael Shannon: 4 times
#
# ========================================
#
# Movie ID: tt5726616 - Most Common PERSON Entities:
# Luca Guadagnino: 4 times
# André Aciman: 4 times
# Elio Perlman: 4 times
# Marzia: 4 times
# Esther Garrel: 4 times
#
# ========================================

# %% [markdown]
# ##### The small model gives accurate results but we may also use the large one in a similar manner - for runtime purposes I will not run the following cells.

# %%
#!python -m spacy download en_core_web_lg

# %%
'''
# Load spaCy model
nlp = spacy.load("en_core_web_lg")  # Changed to a larger model for better accuracy

# Group reviews by movie_id
grouped_reviews = sampled_data.groupby("movie_id")["plot_summary"].apply(lambda x: " ".join(x))

# Dictionary to store PERSON entity counts per movie
person_entities_by_movie = {}

# Process each movie's reviews separately
for movie_id, text in grouped_reviews.items():
    doc = nlp(text)  # Apply spaCy NER directly without tokenization
    person_entities = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]  # Extract only PERSON entities
    
    # Count occurrences of each PERSON entity
    person_counts = Counter(person_entities)
    
    # Store results
    person_entities_by_movie[movie_id] = person_counts

# Print the most common PERSON entities per movie
for movie_id, person_counts in person_entities_by_movie.items():
    print(f"Movie ID: {movie_id} - Most Common PERSON Entities:")
    for entity, count in person_counts.most_common(5):  # Top 5 most common PERSON names
        print(f"{entity}: {count} times")
    print("\n" + "="*40 + "\n")  # Separator for readability
'''

# %%
#remove starting and trailing white spaces from strings
columns_to_strip = ['movie_id','plot_summary','duration','genre','release_date','plot_synopsis',
                            'review_date','user_id','review_text','review_summary']
sampled_data[columns_to_strip] = original_data[columns_to_strip].apply(lambda col: col.str.strip())

# %%
# Check for missing values
sampled_data.isna().any()

# %% [markdown]
# There are no missing values.

# %%
# Check for empty strings
(sampled_data == '').sum()

# %% [markdown]
# There are no empty strings.

# %%
genre = sampled_data['genre']
genre

# %%
# Check if every element of genre feature is a string in order to make them lists
sampled_data['genre'].apply(lambda x: isinstance(x, str)).all()

# %%
# split the genres and remove the "[" "]" characters
sampled_data["genre"] = sampled_data["genre"].str.split(",")

sampled_data_exploded = sampled_data.explode('genre')
sampled_data_exploded['genre'] = sampled_data_exploded['genre'].str.replace(r"[\[\]' ]", "", regex=True)

# Apply one-hot encoding using get_dummies
sampled_data_encoded = pd.get_dummies(sampled_data_exploded['genre'])

# merge with the original dataframe
sampled_data_final = sampled_data.merge(sampled_data_encoded.groupby(sampled_data_exploded.index).sum(), left_index= True, right_index = True)

#  Drop the original 'genre' column if it's no longer needed
sampled_data_final = sampled_data_final.drop(columns=['genre'])
sampled_data = sampled_data_final

sampled_data

# %%
sampled_data.columns

# %% [markdown]
# The number of records does not change.

# %%
# Convert duration to minutes

def convert_to_minutes(duration):
    parts = duration.replace("h", "").replace("min", "").strip().split()
    
    hours = int(parts[0]) if "h" in duration else 0
    minutes = int(parts[1]) if len(parts) > 1 else 0
    
    return hours * 60 + minutes

sampled_data['duration_minutes'] = sampled_data['duration'].apply(convert_to_minutes)
sampled_data

# %%
sampled_data.columns

# %%
# Rename rating_x, rating_y
sampled_data.rename(columns={'rating_x': 'IMDB_rating', 'rating_y': 'user_rating'}, inplace=True)

# %%
# Create new features that only have the year of release and the year of the review

sampled_data['release_year'] = sampled_data['release_date'].str[:4]
sampled_data['review_year'] = sampled_data['review_date'].str[-4:]

sampled_data

# %%
# Convert True to 1 and False to 0 in the response variable
sampled_data['is_spoiler'] = sampled_data['is_spoiler'].astype(int)
sampled_data['is_spoiler']

# %% [markdown]
# ### Text Pre-processing

# %%
# Create new dataframe for spoiler and not spoiler class
df_spoiler = sampled_data[sampled_data['is_spoiler'] == 1]
df_not_spoiler = sampled_data[sampled_data['is_spoiler'] == 0]

# %% [markdown]
# #### Uncontract

# %%
# Define the uncontract function which converts short forms to the full word. For example: 'isn't' to 'is not'.
def uncontract(text):
    text = re.sub(r"(\b)([Aa]re|[Cc]ould|[Dd]id|[Dd]oes|[Dd]o|[Hh]ad|[Hh]as|[Hh]ave|[Ii]s|[Mm]ight|[Mm]ust|[Ss]hould|[Ww]ere|[Ww]ould)n't", r"\1\2 not", text)
    text = re.sub(r"(\b)([Hh]e|[Ii]|[Ss]he|[Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Yy]ou)'ll", r"\1\2 will", text)
    text = re.sub(r"(\b)([Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Yy]ou)'re", r"\1\2 are", text)
    text = re.sub(r"(\b)([Ii]|[Ss]hould|[Tt]hey|[Ww]e|[Ww]hat|[Ww]ho|[Ww]ould|[Yy]ou)'ve", r"\1\2 have", text)

    text = re.sub(r"(\b)([Cc]a)n't", r"\1\2n not", text)
    text = re.sub(r"(\b)([Ii])'m", r"\1\2 am", text)
    text = re.sub(r"(\b)([Ll]et)'s", r"\1\2 us", text)
    text = re.sub(r"(\b)([Tt]here)'s", r"\1\2 is", text)
    text = re.sub(r"(\b)([Ww])on't", r"\1\2ill not", text)
    text = re.sub(r"(\b)([Ss])han't", r"\1\2hall not", text)
    text = re.sub(r"(\b)([Yy])(?:'all|a'll)", r"\1\2ou all", text)

    return text

# %%
sampled_data['review_text'] = [uncontract(t) for t in sampled_data['review_text']]
sampled_data['review_summary'] = [uncontract(t) for t in sampled_data['review_summary']]

# %%
# Create new dataframe for spoiler and not spoiler class
df_spoiler = sampled_data[sampled_data['is_spoiler'] == 1]
df_not_spoiler = sampled_data[sampled_data['is_spoiler'] == 0]

# %% [markdown]
# #### Tokenization

# %%
spoiler_tokens = [word_tokenize(t) for t in df_spoiler['whole_review']]

not_spoiler_tokens = [word_tokenize(t) for t in df_not_spoiler['whole_review']]

# %%
# Convert to a single list
spoiler_tokens = list(itertools.chain.from_iterable(spoiler_tokens))

not_spoiler_tokens = list(itertools.chain.from_iterable(not_spoiler_tokens))

# %%
# Check the number of unique tokens
print('Number of Unique Spoiler Tokens:', len(set(spoiler_tokens)))
print('Number of Unique Non-spoiler Tokens:', len(set(not_spoiler_tokens)))
# Out:
# Number of Unique Spoiler Tokens: 50505
# Number of Unique Non-spoiler Tokens: 40262

# %%
# Check the most frequent tokens for Spoilers and Non-spoilers
print('Spoiler Tokens:\n')

for t, f in Counter(spoiler_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
#------------------------------------
print('Non Spoiler Tokens:\n')

for t, f in Counter(not_spoiler_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Tokens:
#
# the                       46382
# ,                         42739
# .                         34238
# and                       25402
# a                         23422
# to                        21460
# of                        21416
# is                        17486
# in                        13383
# that                      11254
#
# Non Spoiler Tokens:
#
# the                       32025
# ,                         30217
# .                         25088
# and                       18750
# a                         16877
# of                        15589
# to                        14373
# is                        13083
# I                         9328
# in                        9128

# %%
def dimensionality_info(spoilertext ,nonspoilertext):

    print('Number of Spoiler Tokens:    ', len(spoilertext),     '/', len(spoiler_tokens))
    print('Number of Non Spoiler Tokens:', len(nonspoilertext), '/', len(not_spoiler_tokens))

    print()

    print('Number of Unique Spoiler Tokens:    ', len(set(spoilertext)),     '/', len(spoiler_tokens))
    print('Number of Unique Non Spoiler Tokens:', len(set(nonspoilertext)), '/', len(not_spoiler_tokens))

    print()
    print('|V|/|Tokens|:            ', len(set(spoilertext)) / len(set(spoiler_tokens)))
    print('|V|/|Tokens|:            ', len(set(nonspoilertext)) / len(set(not_spoiler_tokens)))

# %% [markdown]
# We observe that the most frequent tokens are stopwords. For that reason we will remvove them to get more informative result.

# %% [markdown]
# #### Remove Punctuation and Stopwords

# %% [markdown]
# ##### Remove Punctuation

# %%
spoiler_punctuations = list(
    filter(
        lambda t: all(c.isdigit() or c in string.punctuation for c in t),
        spoiler_tokens
    )
)
#--------------------------------------
non_spoiler_punctuations = list(
    filter(
        lambda t: all(c.isdigit() or c in string.punctuation for c in t),
        not_spoiler_tokens
    )
)

# %%
spoiler_punctuations = set(spoiler_punctuations)

non_spoiler_punctuations = set(non_spoiler_punctuations)

# %%
# Remove punctuation
spoiler_clean_tokens = [t for t in spoiler_tokens if t not in spoiler_punctuations]

non_spoiler_clean_tokens = [t for t in not_spoiler_tokens if t not in non_spoiler_punctuations]

# %% [markdown]
# ##### Remove Stopwords

# %%
stop_word_regex = '|'.join(['^{}$'.format(s) for s in stopwords.words('english')])

stop_word_regex = re.compile(stop_word_regex)

# %%
spoiler_stop_words = list(filter(stop_word_regex.match, spoiler_clean_tokens))

non_spoiler_stop_words = list(filter(stop_word_regex.match, non_spoiler_clean_tokens))
#----------------------------------------------------
spoiler_stop_words = set(spoiler_stop_words)

non_spoiler_stop_words = set(non_spoiler_stop_words)

# %%
# Remove stopwords
spoiler_clean_tokens = [t for t in spoiler_clean_tokens if t not in spoiler_stop_words]

non_spoiler_clean_tokens = [t for t in non_spoiler_clean_tokens if t not in non_spoiler_stop_words]

# %% [markdown]
# Check the most frequent tokens after removing punctuation and stopwords.

# %%
# Check again the most frequent tokens for Spoilers and Non-spoilers
print('Clean Spoiler Tokens:\n')

for t, f in Counter(spoiler_clean_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
#------------------------------------
print('Clean Non Spoiler Tokens:\n')

for t, f in Counter(non_spoiler_clean_tokens).most_common(10):

    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Clean Spoiler Tokens:
#
# I                         10988
# 's                        9686
# movie                     6808
# The                       5916
# film                      5624
# n't                       4986
# one                       3203
# like                      2896
# It                        2405
# good                      2063
#
# Clean Non Spoiler Tokens:
#
# I                         9328
# 's                        6743
# movie                     6358
# film                      4835
# The                       4344
# n't                       3787
# one                       2588
# like                      2148
# It                        2076
# good                      1843

# %% [markdown]
# We can observe that the possesive s does not give much information. Therefore we decided to consider it as a stopword and remove it.

# %%
spoiler_clean_tokens = [t for t in spoiler_clean_tokens if t != "'s"]

non_spoiler_clean_tokens = [t for t in non_spoiler_clean_tokens if t != "'s"]

# %% [markdown]
# #### Normalization

# %% [markdown]
# ##### Lowercasing

# %%
spoiler_clean_tokens     = [t.lower() for t in spoiler_clean_tokens]

non_spoiler_clean_tokens     = [t.lower() for t in non_spoiler_clean_tokens]

# %% [markdown]
# ##### Stemming

# %%
ps = PorterStemmer()

stems_spoiler = [ps.stem(t) for t in spoiler_clean_tokens]
stems_non_spoiler = [ps.stem(t) for t in non_spoiler_clean_tokens]

# %%
print('Spoiler Stems:\n')

for t, f in Counter(stems_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
#-----------------------------
print('Non Spoiler Stems:\n')

for t, f in Counter(stems_non_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Stems:
#
# i                         10989
# movi                      8033
# film                      6683
# the                       6046
# n't                       5004
# one                       3643
# like                      3454
# charact                   2712
# it                        2548
# time                      2453
#
# Non Spoiler Stems:
#
# i                         9329
# movi                      7570
# film                      5814
# the                       4448
# n't                       3799
# one                       2917
# like                      2581
# it                        2175
# charact                   2047
# good                      1966

# %%
dimensionality_info(stems_spoiler, stems_non_spoiler)
# Out:
# Number of Spoiler Tokens:     506174 / 1021153
# Number of Non Spoiler Tokens: 364236 / 730968
#
# Number of Unique Spoiler Tokens:     33314 / 1021153
# Number of Unique Non Spoiler Tokens: 26725 / 730968
#
# |V|/|Tokens|:             0.6596178596178596
# |V|/|Tokens|:             0.6637772589538523

# %% [markdown]
# ##### Lemmatizing

# %%
lemmatizer = WordNetLemmatizer()

lemmas_spoiler = [lemmatizer.lemmatize(t) for t in spoiler_clean_tokens]
lemmas_non_spoiler = [lemmatizer.lemmatize(t) for t in non_spoiler_clean_tokens]

# %%
print('Spoiler Lemmas:\n')

for t, f in Counter(lemmas_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
#-----------------------------
print('Non Spoiler Lemmas:\n')

for t, f in Counter(lemmas_non_spoiler).most_common(10):
    print('{0:25} {1}'.format(t, f))

print()
# Out:
# Spoiler Lemmas:
#
# i                         10988
# movie                     8033
# film                      6599
# the                       6046
# n't                       5004
# one                       3643
# like                      3082
# character                 2712
# it                        2548
# time                      2428
#
# Non Spoiler Lemmas:
#
# i                         9328
# movie                     7570
# film                      5718
# the                       4448
# n't                       3799
# one                       2917
# like                      2290
# it                        2175
# character                 2047
# good                      1952

# %%
dimensionality_info(lemmas_spoiler, lemmas_non_spoiler)
# Out:
# Number of Spoiler Tokens:     506174 / 1021153
# Number of Non Spoiler Tokens: 364236 / 730968
#
# Number of Unique Spoiler Tokens:     40430 / 1021153
# Number of Unique Non Spoiler Tokens: 32250 / 730968
#
# |V|/|Tokens|:             0.8005148005148005
# |V|/|Tokens|:             0.8010034275495505

# %%
#Many of the spoiler and non-spoiler most common words are the same - therefore we can try to isolate the 
#most common words that appear *only* in spoiler reviews and *only* in negative reviews

# %%
##############################################
# Define an informative function to view the #
# information of frequencies between the two #
# sets of tokens passed as input.            #
##############################################

def comparison_info(spoiler, nonspoiler, desc=None, n=10):

    print(f'{desc.capitalize()} only in Spoiler reviews:')
    print()

    spoilerfreq = dict(Counter(spoiler))
    nonspoilerfreq = dict(Counter(nonspoiler))

    onlyspoiler = set(spoilerfreq).difference(set(nonspoilerfreq))
    onlynonspoiler = set(nonspoilerfreq).difference(set(spoilerfreq))
    common   = set(spoilerfreq).intersection(set(nonspoilerfreq))

    for u in sorted(onlyspoiler, key=lambda t: spoilerfreq[t], reverse=True)[:n]: print('- {0:35} {1}'.format(u, spoilerfreq[u]))

    print()
    print(f'{desc.capitalize()} only in Non-Spoiler Reviews:')
    print()

    for u in sorted(onlynonspoiler, key=lambda t: nonspoilerfreq[t], reverse=True)[:n]: print('- {0:35} {1}'.format(u, nonspoilerfreq[u]))

    print()
    print(f'{desc.capitalize()} common in Spoiler and Non spoiler reviews:')
    print()

    print('{0:37} {1:10} {2:10}'.format('Token', 'Spoiler', 'Non Spoiler'))
    print('------------------------------------------------------------')

    for u in sorted(common, key=lambda t: spoilerfreq[t] + nonspoilerfreq[t], reverse=True)[:n]:

        print('- {0:35} {1:<10} {2:<10}'.format(u, spoilerfreq[u], nonspoilerfreq[u]))

# %%
comparison_info(
  lemmas_spoiler,
  lemmas_non_spoiler,
  desc = 'Lemmas',
  n    = 10
)
# Out:
# Lemmas only in Spoiler reviews:
#
# - dir                                 30
# - edmond                              26
# - ant                                 25
# - sheeta                              21
# - pazu                                19
# - backdraft                           19
# - atticus                             18
# - susanna                             17
# - nzt                                 16
# - alvy                                16
#
# Lemmas only in Non-Spoiler Reviews:
#
# - algren                              15
# - spiderwick                          12
# - harding                             11
# - ivy                                 10
# - shu                                 10
# - percy                               10
# - feig                                9
# - drillbit                            9
# - katsumoto                           9
# - tadashi                             9
#
# Lemmas common in Spoiler and Non spoiler reviews:
#
# Token                                 Spoiler    Non Spoiler
# ------------------------------------------------------------
# - i                                   10988      9328
# - movie                               8033       7570
# - film                                6599       5718
# - the                                 6046       4448
# - n't                                 5004       3799
# - one                                 3643       2917
# - like                                3082       2290
# - character                           2712       2047
# - it                                  2548       2175
# - time                                2428       1874

# %% [markdown]
# Comment: mallon ta results pano ennen toso useful : perhaps removing ALL common words in both spoiler and non spoiler is a bit harsh and removes way too many words/ much info.
#
# Another approach we can follow is:, we remove the top 10 common in both lemmas (ie movie, a, film, the, i, good, great etc. since they dont give much information on whether a review contains a spoiler or not.
#
# After doing so we can check the results and filter more words out if needed.
